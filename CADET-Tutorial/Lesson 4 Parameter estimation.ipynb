# %% [markdown]
# # Lesson 4
#
# Our goal is to match computer simulations to real experiments. Computer simulations are also cheaper to do and can be used to tell us if the real experiment can even answer the question we want to ask. The idea is to build the experiment synthetically first and then try to match against the synthetic data and see if under ideal circumstances if you can identify the parameters of interest. If you can't do it synthetically you can't do it in real life either which has many sources of error. Many times I have seen experiments run which turned out to have no chance of providing the required information because the experiment was run before figuring out what experiment should be run.
#
# ## Purpose
#
# The goal of this section is to learn how to setup, run and analyze a parameter estimation run.
#
# The example used is from Lesson 1 which is a simple Dextran pulse through a column. This lesson will cover the the common variable transforms, scores and search algorithms.
#
# ## Standard imports

# %%
#from IPython.core.display import display, HTML
from IPython.display import display, HTML, clear_output
display(HTML("<style>.container { width:100% !important; }</style>"))

#Python path library support
from pathlib import Path

#python numeric library
import numpy

#python math library
import math

#scientific library for python
import scipy

#pandas is python library for data analysis
import pandas

#addict is a library that makes it easier to create nested dictionaries
from addict import Dict

#json is a standard text based format and it used in CADETMatch for the configuration file
import json

#python plotting library
import matplotlib.pyplot as plt

#cadet python interface
from cadet import Cadet

#jupyter widget support
from ipywidgets import interact
import ipywidgets as widgets

from CADETMatch.jupyter import Match

#This is just a support function to make running the examples a bit easier later
def deleteResultDir(path):
    #This is to try and make sure that only an actual result directory can be removed
    #And only if no other files have been added to the directory, just in case
    if not path.exists():
        return
    allowed = {'evo', 'grad', 'log', 'mcmc', 'meta', 'misc', 'progress', 
               'space', 'error.csv', 'result.h5', 'progress.csv'}
    allowed.add(match.csv)
    allowed.add(match_file.name)
    okayToRemove = False
    for child in path.iterdir():
        if child.name not in allowed:
            break
    else:
        okayToRemove = True
    if okayToRemove:
        import shutil
        shutil.rmtree(path)
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Setup CADET path
#
# In order to run examples we need to specify where CADET is.
#
# On Windows just change the cadet_bin_path to the bin directory of CADET
#
# On Linux you need to change the cadet_bin_path and also change cadet-cli.exe to cadet-cli on the following line.

# %%
#put in the path to the bin folder
cadet_bin_path = Path(r"C:\Users\kosh_000\cadet_build\CADET\VCPKG\bin")

cadet_path = cadet_bin_path / "cadet-cli.exe"

if cadet_path.exists():
    print("CADET was found. Continue to the next step.")
    Cadet.cadet_path = cadet_path.as_posix()
else:
    print('CADET could not be found. Please check the bin path')
    
print(cadet_path.as_posix())
# Out:
# CADET was found. Continue to the next step.
# C:/Users/kosh_000/cadet_build/CADET/VCPKG/bin/cadet-cli.exe

# %% [markdown]
# ## Create lesson folders and create lesson variables
#
# This will create all the lesson folders we need and make it easier to refer to previous lessons

# %%
#set this to a directory on your computer where the cadet tutorial files can be saved
cadet_tutorial = Path('F:/temp/cadet_tutorial')
lesson_1 = cadet_tutorial / "lesson_1"
lesson_2 = cadet_tutorial / "lesson_2"
lesson_3 = cadet_tutorial / "lesson_3"
lesson_4 = cadet_tutorial / "lesson_4"
lesson_4.mkdir(exist_ok = True, parents=True)

# %% [markdown]
# ## Load simple example from Lesson 1
# This code is pretty much the same as what we have looked at before. We open the file from Lesson 1 and then resave it to the Lesson 4 folder. We also run the simulation and save the output of the chromatogram as a CSV file to use in the matching process.

# %%
simple_example = lesson_1 / "simple_example"
simple_example.mkdir(exist_ok = True)

simple = Cadet()

#give a filename for where the simulation should be saved
simple.filename = (simple_example / 'example.h5').as_posix()

simple.load()

simple.filename = (lesson_4 / 'example.h5').as_posix()

#save the simulation
simple.save()

#run the simulation
data = simple.run()

print(data)

if data.returncode == 0:
    print("Simulation completed successfully")
    
    #load the data from the simulation so we can view the results
    simple.load()
    
    #plot the simulation
    plt.figure(figsize=[10,10])
    plt.plot(simple.root.output.solution.solution_times,
        simple.root.output.solution.unit_002.solution_outlet_comp_000)
    plt.xlabel('Time(s)')
    plt.ylabel('Concentration (mM)')
    
    #write the chromatogram data out to a csv file
    data = pandas.DataFrame([simple.root.output.solution.solution_times,
                        simple.root.output.solution.unit_001.solution_outlet_comp_000]).transpose()
    data.to_csv((lesson_4 / 'example.csv').as_posix(), index=False, header=False)
    
else:
    print("Simulation failed")
# Out:
# CompletedProcess(args=['C:/Users/kosh_000/cadet_build/CADET/VCPKG/bin/cadet-cli.exe', 'F:/temp/cadet_tutorial/lesson_4/example.h5'], returncode=0, stdout=b'', stderr=b'')
# Simulation completed successfully

# %% [markdown]
# ## Create CADETMatch configuration
#
# ### Search Method
# There are 4 main search methods and only 3 of them are directly used.
# 1. NSGA3
#   This is the default evolutionary algorithm and the best choice to use when you don't know anything about your search space.
# 2. Multistart
#   This is a multistart gradient descent algorithm. If your problem can be solved with gradient descent then this can be a very good choice. It creates an initial population the same way that NSGA3 does so that you don't have to worry about starting point.
# 3. GraphSpace
#   This is not for optimization and instead it is just for sampling the space. If you have a new problem and you have no idea what the range of any of the parameters are you can use this with a very large population and it will just evaluate the entire starting population and then terminate. This allows you to figure out what are plausiable ranges for your variables before using one of the search algorithms. When dealing with many variables it is still possible to miss regions of viable solutions inside large non-viable regions but in practice this has rarely been a problem.
# 4. MCMC
#   This performans the error modeling and sampling. It is not an optimization algorithm and while it will probably find the optimum value while it runs it is very slow to do so and won't stop even if it finds the optimal value. This should also not be used directly. Normally NSGA3 is used and an option is set to continue with MCMC after NSGA3 has completed. This allows MCMC to be seeded with the best values from NSGA3 which dramatically improves convergence. If you have many variables and you run this directly it may never converge since it may never find high probability regions, much less sample from them effectively.

# %%
match = Dict()
match.CADETPath = cadet_path.as_posix()
match.baseDir = lesson_4.as_posix()
match.resultsDir = 'fit_nsga3'
match.csv = 'fit_results.csv'
match.checkpointFile = "check"
match.stopAverage = 1
match.stopBest = 1
match.gradCheck = 1
match.gradVector = 1
match.searchMethod = 'NSGA3'
match.mutationRate = 1.0
match.crossoverRate = 1.0
match.generations = 1000
match.population = 12
match.minPopulation = 12
match.maxPopulation = 12
match.finalGradRefinement = 1
match.stallGenerations = 10

# %% [markdown]
# ### Variable transforms
# Search algorithms don't work well when the parameters have very different ranges. For example if one parmeter varies from 1e-5 to 1e-10 and the other varies from 1-10. Another problem is when parameters are tightly coupled together but presented to the optimizer as indepdent variables. This is true with kA and kD for the adsorption and desorption rates. The parameters kA and kD are coupled together but given as two different variables while they do not freely vary from each other. To solve this problem variable transforms are available. I will cover the most common and useful transformations. There are some other variable transforms available that you can see at https://github.com/modsim/CADET-Match/tree/master/CADETMatch/transform
#
# 1. norm
#
#   This is a simple transform that normalizes a variable from 0 to 1. This is best used when you have a variable that varies over less then 3 orders of magnitude.
#
#   ```json
# {
#       "transform": "norm",
#       "component": -1,
#       "bound": -1,
#       "location": "/input/model/unit_001/COL_POROSITY",
#       "min": 0.2,
#       "max": 0.5
#     }
# ```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm'
# parameter.component = -1
# parameter.bound = -1
# parameter.location = "/input/model/unit_001/COL_POROSITY"
# parameter.min = 0.2
# parameter.max = 0.5
# ```
#
# 2. norm_log
#
#   This transform takes the log before normalizing the variable from 0 to 1. Use this transform when your variable spans more than 3 orders of magnitude.
#
#     ```json
# {
#       "transform": "norm_log",
#       "component": -1,
#       "bound": -1,
#       "location": "/input/model/unit_001/COL_DISPERSION",
#       "min": 1e-12,
#       "max": 1e-5
#     }
# ```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_log'
# parameter.component = -1
# parameter.bound = -1
# parameter.location = "/input/model/unit_001/COL_DISPERSION"
# parameter.min = 1e-12
# parameter.max = 1e-5
# ```
#
# 3. norm_keq
#
#    This transform turns ka, kd in ka and keq=ka/kd and then takes a log transform and normalizes from 0 to 1.
#
#    ```json
# {
#     "transform": "norm_keq",
#     "component": 0,
#     "bound": 0,
#     "location": [
#         "/input/model/unit_001/adsorption/LIN_KA",
#         "/input/model/unit_001/adsorption/LIN_KD"
#     ],
#     "minKA": 1e-8,
#     "maxKA": 1e8,
#     "minKEQ": 1e-4,
#     "maxKEQ": 1e4
# }
# ```
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_keq'
# parameter.component = 0
# parameter.bound = 0
# parameter.location = ["/input/model/unit_001/adsorption/LIN_KA",
#                       "/input/model/unit_001/adsorption/LIN_KD"]
# parameter.minKA = 1e-8
# parameter.maxKA = 1e8
# parameter.minKEQ = 1e-4
# parameter.maxKEQ = 1e4
# ```
#
#
# 4. norm_volume_area
#
#     This transform and the following one where created to solve the same common problem. When fitting bypass data and you model the tubing you are fitting the length, crosssectional area and dispersion of the tubing. Dispersion though is tied to the length such that a shorter length can just be compensated for with a higher diffusion. Basically we have fewer degrees of freedom that we are fitting with and since this is not a fluid dynamics model it is not physically accurate. This transformation couples the length and area together through the volume since volume is an identfiable quantity (since water is incompressible). We don't actually care much about the parameters for the tubing, it is just there to fill in for the real tubing so that fewer errors are carried into the column. Use this version if it is easier to measure the diameter of the tubing and use the other transform if measuring the length is easier. I just depends on your experimental setup.
#
#
#
# ```json
# {
#   "transform": "norm_volume_area",
#   "area_location": "/input/model/unit_003/COL_DISPERSION",
#   "length_location": "/input/model/unit_004/COL_DISPERSION",
#   "component": -1,
#   "bound": -1,
#   "minVolume":1e-6,
#   "maxVolume":1e-5,
#   "minArea":1e-4,
#   "maxArea":1e-3
# }```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_volume_area'
# parameter.area_location = "/input/model/unit_003/COL_DISPERSION"
# parameter.length_location = "/input/model/unit_004/COL_DISPERSION"
# parameter.component = -1
# parameter.bound = -1
# parameter.minVolume = 1e-6
# parameter.maxVolume = 1e-5
# parameter.minArea = 1e-4
# parameter.maxArea = 1e-3
# ```
#
#
# 5. norm_volume_length
#
#     Use this transform if measuring the length accurately is easier than measuring the diameter of the tubing. If you are lumping together all the tubing in front of the column or after the column together and you have multiple diameters it doesn't matter which of these transforms you choose.
#
# ```json
# {
#   "transform": "norm_volume_length",
#   "area_location": "/input/model/unit_003/COL_DISPERSION",
#   "length_location": "/input/model/unit_004/COL_DISPERSION",
#   "component": -1,
#   "bound": -1,
#   "minVolume":1e-6,
#   "maxVolume":1e-5,
#   "minLength":0.25,
#   "maxLength":0.75
# }```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_volume_area'
# parameter.area_location = "/input/model/unit_003/COL_DISPERSION"
# parameter.length_location = "/input/model/unit_004/COL_DISPERSION"
# parameter.component = -1
# parameter.bound = -1
# parameter.minVolume = 1e-6
# parameter.maxVolume = 1e-5
# parameter.minLength = 0.25
# parameter.maxLength = 0.75
# ```
#
#
# 6. set_value
#
#     This is a different kind of transform. What it allows you to do is copy a value from place to another. This is important if you are estimating axial dispersion for identical tubing in front of and behind the column. You want the same axial dispersion for both pieces of tubing but you only want to estimate one variable. With this you can estimate axial dispersion for the first piece of tubing and then copy the value over to the other piece of tubing. This is also required if you want to estimate SMA_LAMDA. Whenever SMA_LAMBDA change the initial bound salt concentration also much change or electronuetrality would be violated.
#
# ```json
# {
#   "transform": "set_value",
#   "componentFrom": -1,
#   "boundFrom": -1,
#   "locationFrom": "/input/model/unit_003/COL_DISPERSION",
#   "componentTo": -1,
#   "boundTo": -1,
#   "locationTo": "/input/model/unit_004/COL_DISPERSION"
# }```
#
# ```python
# parameter = Dict()
# parameter.transform = 'set_value'
# parameter.componentFrom = -1
# parameter.boundFrom = -1
# parameter.locationFrom = "/input/model/unit_001/COL_DISPERSION"
# parameter.componentTo = -1
# parameter.boundTo = -1
# parameter.locationTo = "/input/model/unit_001/COL_DISPERSION"
# ```

# %%
parameter1 = Dict()
parameter1.transform = 'norm_log'
parameter1.component = -1
parameter1.bound = -1
parameter1.location = "/input/model/unit_001/COL_DISPERSION"
parameter1.min = 1e-10
parameter1.max = 1e-6

parameter2 = Dict()
parameter2.transform = 'norm'
parameter2.component = -1
parameter2.bound = -1
parameter2.location = "/input/model/unit_001/COL_POROSITY"
parameter2.min = 0.2
parameter2.max = 0.5

match.parameters = [parameter1, parameter2]

# %% [markdown]
# ### Scores
#
# Scores are how the search algorithm measures if a solution is better or worse than what it had before. Without a good score system an optimizer can't work. There are many scores available and I am going to cover the most commonly used ones and when you should use them. You can see all of them at https://github.com/modsim/CADET-Match/tree/master/CADETMatch/scores . Most of these scores are based on physical understanding of the problem and it is pretty easy to add new scores. If there is a feature you can identify in your problem that ties to one of the variables being estimated then go ahead and make a score for it. Maybe for your isotherm the width of the peak or some other feature reveals important information.
#
# 1. Shape
#
#   This is the default score used when fitting an isotherm. It looks at the shape, position, and height of the peak. It has a small initial penalty for the peak being out of position in time and increases as the peak gets further away. This is to deal with the problem of pump delays and other experimental errors. The best fit may not be and often is not the peak that is in exactly the right location but it is the one with the right shape. The shape is determined by the physics which is why it is so heavily emphasied in the score system.
#
# 2. ShapeDecay
#
#   This is the default score to use when fitting transport parameters. Transport experiments are more difficult because you MUST make sure that as few errors as possible happened in the physical experiment. On most AKTA type systems if there is an alarm the timer for data collection is also paused until the alarm is cleared and the system resumes. This results in data that has no gap in the time. However, the chemicals are still reacting and moving even if the pumps are off and data collection stops. Any such error that occurs will result in the diffusion being wrong and the longer the error persists before being fixed the more wrong the estimate for diffusion will be. Things like pump delays or other pauses in the system can cause problems with estimating volume or porosity. Any errors that occur in transport experiments will be carried through to isotherm parameters which harms scaleup later.
#
# 3. DextranShape
#
#   Dextran is a nice tracer overall but it has no ideal behavior in most systems. You normally see this in strange tailing behavior. What this means is that only the front side of the peak can be used. This score specifically looks only at the front side of the peak.
#
# 4. fractionationSlide
#
#   If you have a fractionation proble use this score. Internally it is a little complex. After each simulation for each species it numerically slides the chromatogram back and forward in time and refactionates at each time to find which location best matches the experimental data to find the time difference between the synthetic and experimental peak along with a shape comparison at that time.
#
# 5. SSE
#
#   This is the Sum of Squared Errors. This score can not be combined with any of the other scores since it does not range from 0 to 1.
#
# 6. AbsoluteHeight and AbsoluteTime
#
#   These scores are needed by the MCMC system. They are absolute measurements of height and time since the beginning of the simulation. They are used to capture the impact of errors that have an assymetric impact on the peaks.

# %%
experiment1 = Dict()
experiment1.csv = "example.csv"
experiment1.isotherm = "/output/solution/unit_001/SOLUTION_OUTLET_COMP_000"
experiment1.HDF5 = "example.h5"
experiment1.name = "main"
experiment1.timeout = 30.0

feature1 = Dict()
feature1.name = "Pulse"
feature1.type = 'DextranShape'

experiment1.features = [feature1,]

match.experiments = [experiment1,]

match_file = lesson_4 / 'example_nsga3.json'

with (match_file).open('w') as json_file:
    json.dump(match.to_dict(), json_file, indent='\t')

# %% [markdown]
# ## Create match using jupyter interface
# This creates a simple Match object to use for parameter estimation. This is useful when running a match from inside Jupyter notebook. Most of the time this is only done for small matches or when you are running a jupyter notebook on a more powerful server. All of the same results are generated as when the matching software is run directly on the command line and the full results can still be viewed. The jupyter notebook interface just shows a few highlights.

# %%
sim = Match((lesson_4 / 'example_nsga3.json').as_posix())

# %% [markdown]
# ## Start parameter estimation
# Once the Match object has been created all that you need to use is call .start_sim() and the output will be written to the notebook as the matching process runs.
#
# The first few lines tell you what version of python is being used and how many workers are being used. After that the system provides some output at the end of each generation.
#
# > [2019-09-27 12:29:34,593] util      (b'127.0.0.1:61306') INFO    Generation: 0 	Population: 24 	Average Score: 0.968 	Best: 0.981 	Minimum Score: 0.942 	Best: 0.973 	Product Score: 0.967 	Best: 0.981
#
# The above line gives information for when the line was created, what generation the system is on, how long the population is and score information. For most scores the best value is 1.0. The Average, Minimum and Products scores are the values based on the entire population while the Best versions are the scores for only the items on the pareto front. When first starting out the normal scores are usually much lower then the best scores and as the system converges they also tend to get closer.

# %%
resultDir = Path(match.baseDir) / match.resultsDir
print("Your results are located at", resultDir.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDir)

sim.start_sim()
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_nsga3
#
#
# [2019-10-02 11:05:53,246] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-02 11:05:53,246] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-10-02 11:05:53,246] launcher  INFO    Worker distribution:
#
# [2019-10-02 11:05:53,246] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-10-02 11:05:59,058] util      (b'127.0.0.1:54594') INFO    Generation: -1 	Population: 24 	Average Score: 0.908 	Best: 0.977 	Minimum Score: 0.817 	Best: 0.957 	Product Score: 0.901 	Best: 0.977
#
# [2019-10-02 11:06:00,213] util      (b'127.0.0.1:54594') INFO    Generation: 0 	Population: 24 	Average Score: 0.989 	Best: 0.989 	Minimum Score: 0.977 	Best: 0.977 	Product Score: 0.988 	Best: 0.988
#
# [2019-10-02 11:06:01,328] util      (b'127.0.0.1:54594') INFO    Generation: 1 	Population: 24 	Average Score: 0.989 	Best: 0.989 	Minimum Score: 0.977 	Best: 0.977 	Product Score: 0.988 	Best: 0.988
#
# [2019-10-02 11:06:02,354] util      (b'127.0.0.1:54594') INFO    Generation: 2 	Population: 24 	Average Score: 0.947 	Best: 0.989 	Minimum Score: 0.893 	Best: 0.977 	Product Score: 0.944 	Best: 0.988
#
# [2019-10-02 11:06:03,554] util      (b'127.0.0.1:54594') INFO    Generation: 3 	Population: 24 	Average Score: 0.957 	Best: 0.989 	Minimum Score: 0.917 	Best: 0.981 	Product Score: 0.955 	Best: 0.988
#
# [2019-10-02 11:06:04,667] util      (b'127.0.0.1:54594') INFO    Generation: 4 	Population: 24 	Average Score: 0.968 	Best: 0.999 	Minimum Score: 0.936 	Best: 0.999 	Product Score: 0.967 	Best: 0.999
#
# [2019-10-02 11:06:05,741] util      (b'127.0.0.1:54594') INFO    Generation: 5 	Population: 24 	Average Score: 0.996 	Best: 0.999 	Minimum Score: 0.992 	Best: 0.999 	Product Score: 0.996 	Best: 0.999
#
# [2019-10-02 11:06:06,829] util      (b'127.0.0.1:54594') INFO    Generation: 6 	Population: 24 	Average Score: 0.987 	Best: 0.999 	Minimum Score: 0.975 	Best: 0.999 	Product Score: 0.987 	Best: 0.999
#
# [2019-10-02 11:06:07,898] util      (b'127.0.0.1:54594') INFO    Generation: 7 	Population: 24 	Average Score: 0.99 	Best: 0.999 	Minimum Score: 0.981 	Best: 0.999 	Product Score: 0.99 	Best: 0.999
#
# [2019-10-02 11:06:08,846] util      (b'127.0.0.1:54594') INFO    Generation: 8 	Population: 24 	Average Score: 0.991 	Best: 0.999 	Minimum Score: 0.982 	Best: 0.999 	Product Score: 0.991 	Best: 0.999
#
# [2019-10-02 11:06:09,891] util      (b'127.0.0.1:54594') INFO    Generation: 9 	Population: 24 	Average Score: 0.991 	Best: 0.999 	Minimum Score: 0.982 	Best: 0.999 	Product Score: 0.991 	Best: 0.999
#
# [2019-10-02 11:06:10,981] util      (b'127.0.0.1:54594') INFO    Generation: 10 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
#
# [2019-10-02 11:06:11,963] util      (b'127.0.0.1:54594') INFO    Generation: 11 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
#
# [2019-10-02 11:06:12,928] util      (b'127.0.0.1:54594') INFO    Generation: 12 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
#
# [2019-10-02 11:06:13,890] util      (b'127.0.0.1:54594') INFO    Generation: 13 	Population: 24 	Average Score: 0.994 	Best: 1 	Minimum Score: 0.989 	Best: 1 	Product Score: 0.994 	Best: 1
#
# [2019-10-02 11:06:14,854] util      (b'127.0.0.1:54594') INFO    Generation: 14 	Population: 24 	Average Score: 0.994 	Best: 1 	Minimum Score: 0.989 	Best: 1 	Product Score: 0.994 	Best: 1
#
# [2019-10-02 11:06:15,886] util      (b'127.0.0.1:54594') INFO    Generation: 15 	Population: 24 	Average Score: 0.994 	Best: 1 	Minimum Score: 0.989 	Best: 1 	Product Score: 0.994 	Best: 1
#
# [2019-10-02 11:06:16,845] util      (b'127.0.0.1:54594') INFO    Generation: 16 	Population: 24 	Average Score: 0.994 	Best: 1 	Minimum Score: 0.989 	Best: 1 	Product Score: 0.994 	Best: 1
#
# [2019-10-02 11:06:17,829] util      (b'127.0.0.1:54594') INFO    Generation: 17 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.985 	Best: 1 	Product Score: 0.992 	Best: 1
#
# [2019-10-02 11:06:18,794] util      (b'127.0.0.1:54594') INFO    Generation: 18 	Population: 24 	Average Score: 0.991 	Best: 1 	Minimum Score: 0.983 	Best: 1 	Product Score: 0.991 	Best: 1
#
# [2019-10-02 11:06:19,729] util      (b'127.0.0.1:54594') INFO    Generation: 19 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.985 	Best: 1 	Product Score: 0.992 	Best: 1
#
# [2019-10-02 11:06:20,682] util      (b'127.0.0.1:54594') INFO    Generation: 20 	Population: 24 	Average Score: 0.991 	Best: 1 	Minimum Score: 0.983 	Best: 1 	Product Score: 0.991 	Best: 1
#
# [2019-10-02 11:06:21,580] util      (b'127.0.0.1:54594') INFO    Generation: 21 	Population: 24 	Average Score: 0.991 	Best: 1 	Minimum Score: 0.983 	Best: 1 	Product Score: 0.991 	Best: 1
#
# [2019-10-02 11:06:22,660] util      (b'127.0.0.1:54594') INFO    Generation: 22 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.985 	Best: 1 	Product Score: 0.993 	Best: 1
#
# [2019-10-02 11:06:23,516] util      (b'127.0.0.1:54594') INFO    Generation: 23 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.985 	Best: 1 	Product Score: 0.993 	Best: 1
#
# [2019-10-02 11:06:24,414] util      (b'127.0.0.1:54594') INFO    Generation: 24 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.987 	Best: 1 	Product Score: 0.993 	Best: 1
#
# [2019-10-02 11:06:25,327] util      (b'127.0.0.1:54594') INFO    Generation: 25 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-02 11:06:26,351] util      (b'127.0.0.1:54594') INFO    Generation: 26 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-02 11:06:27,361] util      (b'127.0.0.1:54594') INFO    Generation: 27 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-02 11:06:28,294] util      (b'127.0.0.1:54594') INFO    Generation: 28 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-02 11:06:29,153] util      (b'127.0.0.1:54594') INFO    Generation: 29 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-02 11:06:30,067] util      (b'127.0.0.1:54594') INFO    Generation: 30 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-02 11:06:30,891] util      (b'127.0.0.1:54594') INFO    Generation: 31 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-02 11:06:31,921] util      (b'127.0.0.1:54594') INFO    Generation: 32 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.987 	Best: 1 	Product Score: 0.993 	Best: 1
#
# [2019-10-02 11:06:38,156] util      (b'127.0.0.1:54594') INFO    Generation: 33 	Population: 2 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.987 	Best: 1 	Product Score: 0.993 	Best: 1
#
# [2019-10-02 11:06:45,176] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-02 11:06:45,176] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-10-02 11:06:45,176] launcher  INFO    Worker distribution:
#
# [2019-10-02 11:06:45,176] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-10-02 11:06:48,129] generate_corner_graphs (b'127.0.0.1:60364') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-10-02 11:06:48,129] generate_corner_graphs (b'127.0.0.1:60364') INFO    plotting corner plots
#
# [2019-10-02 11:06:48,134] generate_corner_graphs (b'127.0.0.1:60364') INFO    graphing remove 0 points
#
# [2019-10-02 11:06:48,185] loggerwriter (b'127.0.0.1:60364') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:06:50,624] loggerwriter (b'127.0.0.1:60364') WARNING WARNING:root:Too few points to create valid contours
# [2019-10-02 11:06:52,933] loggerwriter (b'127.0.0.1:60364') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:07:02,101] launcher  (127.0.0.1:52738) INFO    Root process is done.
#
# [2019-10-02 11:07:02,101] launcher  (127.0.0.1:52738) INFO    Finished cleaning spawned subprocesses.
#
# [2019-10-02 11:07:02,118] match     (b'127.0.0.1:54594') INFO    altFeatures False
#
# [2019-10-02 11:07:02,119] match     (b'127.0.0.1:54594') INFO    altFeatureNames []
#
# [2019-10-02 11:07:02,119] match     (b'127.0.0.1:54594') INFO    Sysem has finished
#
# [2019-10-02 11:07:02,119] match     (b'127.0.0.1:54594') INFO    The total runtime was 64.8942220211029 seconds
#
# [2019-10-02 11:07:02,877] launcher  (127.0.0.1:52458) INFO    Root process is done.
#
# [2019-10-02 11:07:02,878] launcher  (127.0.0.1:52458) INFO    Finished cleaning spawned subprocesses.

# %% [markdown]
# ## Parameter estimation from the command line
# Most of the time paramter estimation is run from the command line. This makes it easy to run it on a remote computer and restart if something goes wrong. You can also run this under the control of a batch system and is how the software is typically used. Complex parameter estimation with multiple experiments and many variables can take a week or more to run to completion. The matching software peridically writes out graphs and other information as it runs. If you notice that the answer is good enough you can end matching early. I have seen systems get 99% of the final answer within a day and spend another week refining it with minor improvements. There is no absolute rule for this.
#
# For almost all cases what you want to run is
#
# > python -m CADETMatch --match -j /path/to/file.json
#
# It is possible that you will need to change python to python3 depending on your system
#
# If you want to force the system to generate graphs for all the simulations it has so far immediately you can run
#
# > python -m CADETMatch --generate_graphs -j /path/to/file.json
#
# If you have not passed the first generation some graphs won't be generated since the data won't be available yet.
#
# If you run this version from inside a jupyter notebook by use ! to run an external program the output won't show up until the whole estimation finishes. If you are going to run this from inside a jupyter notebok use the jupyter interface covered above. This is here as an example to show how to run the software from the command line.

# %%
#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDir)

json_path = (lesson_4 / 'example_nsga3.json').as_posix()

command = 'python -m CADETMatch --match -j "%s"' % json_path

print(command)

# !{command}
# Out:
# python -m CADETMatch --match -j "F:/temp/cadet_tutorial/lesson_4/example_nsga3.json"
# [2019-10-02 11:07:06,346] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
# [2019-10-02 11:07:06,346] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
# [2019-10-02 11:07:06,346] launcher  INFO    Worker distribution:
# [2019-10-02 11:07:06,347] launcher  INFO       127.0.0.1:	11 + origin
# [2019-10-02 11:07:11,620] util      (b'127.0.0.1:56135') INFO    Generation: -1 	Population: 24 	Average Score: 0.957 	Best: 0.976 	Minimum Score: 0.924 	Best: 0.974 	Product Score: 0.956 	Best: 0.976
# [2019-10-02 11:07:12,547] util      (b'127.0.0.1:56135') INFO    Generation: 0 	Population: 24 	Average Score: 0.932 	Best: 0.976 	Minimum Score: 0.872 	Best: 0.974 	Product Score: 0.927 	Best: 0.976
# [2019-10-02 11:07:13,546] util      (b'127.0.0.1:56135') INFO    Generation: 1 	Population: 24 	Average Score: 0.968 	Best: 0.976 	Minimum Score: 0.942 	Best: 0.974 	Product Score: 0.967 	Best: 0.976
# [2019-10-02 11:07:14,425] util      (b'127.0.0.1:56135') INFO    Generation: 2 	Population: 24 	Average Score: 0.961 	Best: 0.989 	Minimum Score: 0.923 	Best: 0.98 	Product Score: 0.96 	Best: 0.989
# [2019-10-02 11:07:15,403] util      (b'127.0.0.1:56135') INFO    Generation: 3 	Population: 24 	Average Score: 0.971 	Best: 0.993 	Minimum Score: 0.945 	Best: 0.987 	Product Score: 0.97 	Best: 0.993
# [2019-10-02 11:07:16,211] util      (b'127.0.0.1:56135') INFO    Generation: 4 	Population: 24 	Average Score: 0.988 	Best: 0.993 	Minimum Score: 0.981 	Best: 0.987 	Product Score: 0.988 	Best: 0.993
# [2019-10-02 11:07:17,028] util      (b'127.0.0.1:56135') INFO    Generation: 5 	Population: 24 	Average Score: 0.987 	Best: 0.993 	Minimum Score: 0.977 	Best: 0.987 	Product Score: 0.987 	Best: 0.993
# [2019-10-02 11:07:17,940] util      (b'127.0.0.1:56135') INFO    Generation: 6 	Population: 24 	Average Score: 0.989 	Best: 0.997 	Minimum Score: 0.98 	Best: 0.993 	Product Score: 0.989 	Best: 0.997
# [2019-10-02 11:07:18,713] util      (b'127.0.0.1:56135') INFO    Generation: 7 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:19,497] util      (b'127.0.0.1:56135') INFO    Generation: 8 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:20,276] util      (b'127.0.0.1:56135') INFO    Generation: 9 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:21,033] util      (b'127.0.0.1:56135') INFO    Generation: 10 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:21,834] util      (b'127.0.0.1:56135') INFO    Generation: 11 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:22,686] util      (b'127.0.0.1:56135') INFO    Generation: 12 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:23,422] util      (b'127.0.0.1:56135') INFO    Generation: 13 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:24,216] util      (b'127.0.0.1:56135') INFO    Generation: 14 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:25,610] util      (b'127.0.0.1:56135') INFO    Generation: 15 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:26,544] util      (b'127.0.0.1:56135') INFO    Generation: 16 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:27,340] util      (b'127.0.0.1:56135') INFO    Generation: 17 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:28,113] util      (b'127.0.0.1:56135') INFO    Generation: 18 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:28,888] util      (b'127.0.0.1:56135') INFO    Generation: 19 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:29,751] util      (b'127.0.0.1:56135') INFO    Generation: 20 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:30,591] util      (b'127.0.0.1:56135') INFO    Generation: 21 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:31,468] util      (b'127.0.0.1:56135') INFO    Generation: 22 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:32,263] util      (b'127.0.0.1:56135') INFO    Generation: 23 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:33,027] util      (b'127.0.0.1:56135') INFO    Generation: 24 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:33,925] util      (b'127.0.0.1:56135') INFO    Generation: 25 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:34,696] util      (b'127.0.0.1:56135') INFO    Generation: 26 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:35,524] util      (b'127.0.0.1:56135') INFO    Generation: 27 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:36,278] util      (b'127.0.0.1:56135') INFO    Generation: 28 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:37,045] util      (b'127.0.0.1:56135') INFO    Generation: 29 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:37,776] util      (b'127.0.0.1:56135') INFO    Generation: 30 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:38,564] util      (b'127.0.0.1:56135') INFO    Generation: 31 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:39,387] util      (b'127.0.0.1:56135') INFO    Generation: 32 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:40,160] util      (b'127.0.0.1:56135') INFO    Generation: 33 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:40,930] util      (b'127.0.0.1:56135') INFO    Generation: 34 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:41,709] util      (b'127.0.0.1:56135') INFO    Generation: 35 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:42,471] util      (b'127.0.0.1:56135') INFO    Generation: 36 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:43,230] util      (b'127.0.0.1:56135') INFO    Generation: 37 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:43,983] util      (b'127.0.0.1:56135') INFO    Generation: 38 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:44,743] util      (b'127.0.0.1:56135') INFO    Generation: 39 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:45,593] util      (b'127.0.0.1:56135') INFO    Generation: 40 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:46,372] util      (b'127.0.0.1:56135') INFO    Generation: 41 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:47,152] util      (b'127.0.0.1:56135') INFO    Generation: 42 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:47,927] util      (b'127.0.0.1:56135') INFO    Generation: 43 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:48,842] util      (b'127.0.0.1:56135') INFO    Generation: 44 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:49,597] util      (b'127.0.0.1:56135') INFO    Generation: 45 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:50,389] util      (b'127.0.0.1:56135') INFO    Generation: 46 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:51,152] util      (b'127.0.0.1:56135') INFO    Generation: 47 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:51,919] util      (b'127.0.0.1:56135') INFO    Generation: 48 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:52,736] util      (b'127.0.0.1:56135') INFO    Generation: 49 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:53,518] util      (b'127.0.0.1:56135') INFO    Generation: 50 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:54,317] util      (b'127.0.0.1:56135') INFO    Generation: 51 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:55,106] util      (b'127.0.0.1:56135') INFO    Generation: 52 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:55,856] util      (b'127.0.0.1:56135') INFO    Generation: 53 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:56,715] util      (b'127.0.0.1:56135') INFO    Generation: 54 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:57,481] util      (b'127.0.0.1:56135') INFO    Generation: 55 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:58,306] util      (b'127.0.0.1:56135') INFO    Generation: 56 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:59,041] util      (b'127.0.0.1:56135') INFO    Generation: 57 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:07:59,802] util      (b'127.0.0.1:56135') INFO    Generation: 58 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:08:00,583] util      (b'127.0.0.1:56135') INFO    Generation: 59 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:08:01,325] util      (b'127.0.0.1:56135') INFO    Generation: 60 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:08:02,136] util      (b'127.0.0.1:56135') INFO    Generation: 61 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:08:02,903] util      (b'127.0.0.1:56135') INFO    Generation: 62 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:08:13,202] util      (b'127.0.0.1:56135') INFO    Generation: 63 	Population: 6 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-02 11:08:19,781] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
# [2019-10-02 11:08:19,781] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
# [2019-10-02 11:08:19,782] launcher  INFO    Worker distribution:
# [2019-10-02 11:08:19,782] launcher  INFO       127.0.0.1:	0 + origin
# [2019-10-02 11:08:22,400] generate_corner_graphs (b'127.0.0.1:49900') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
# [2019-10-02 11:08:22,400] generate_corner_graphs (b'127.0.0.1:49900') INFO    plotting corner plots
# [2019-10-02 11:08:22,406] generate_corner_graphs (b'127.0.0.1:49900') INFO    graphing remove 0 points
# [2019-10-02 11:08:38,985] launcher  (127.0.0.1:53051) INFO    Root process is done.
# [2019-10-02 11:08:38,985] launcher  (127.0.0.1:53051) INFO    Finished cleaning spawned subprocesses.
# [2019-10-02 11:08:39,002] match     (b'127.0.0.1:56135') INFO    altFeatures False
# [2019-10-02 11:08:39,002] match     (b'127.0.0.1:56135') INFO    altFeatureNames []
# [2019-10-02 11:08:39,003] match     (b'127.0.0.1:56135') INFO    Sysem has finished
# [2019-10-02 11:08:39,003] match     (b'127.0.0.1:56135') INFO    The total runtime was 89.04902696609497 seconds
# [2019-10-02 11:08:39,756] launcher  (127.0.0.1:52770) INFO    Root process is done.
# [2019-10-02 11:08:39,757] launcher  (127.0.0.1:52770) INFO    Finished cleaning spawned subprocesses.

# %% [markdown]
# ## Complete results
# Sorry this next line only works on Windows. On your own system you can use whatever program you use for managing files to open up the result dir and see the same thing.
#
# The system creates a number of sub directories and depending on what settings are in the JSON file some will be empty.
#
# The import ones are
#
# 1. log
#   This contains all the log files from the system. If something goes wrong the information is usually here to find the problem and fix it. This is especialy useful for us to help with a problem.
# 2. meta
#   This contains all the results on the pareto front of meta scores. Your best results will be in this folder. There are simulations, images and results in csv and xlsx format to view.
# 3. progress
#   This folder watches the general progress of the algorithm. In this folder you can see if your variables are identifiable or the progress the search method is making.
# 4. space
#   This folder has plots for what the search space looks like. This is especially useful for debugging. Based on graphs in this folder you can expand or contract the search range for your variables which can improve the fits.
#
# There are also some important items in this folder
# 1. error.csv
#   If any simulation fails it will be recorded here
# 2. json file
#   This is the JSON used to create this simulation. It is a copy of the JSON file you started the matching process with
# 3. progress.csv
#   This file contains some information on algorithm progress. Of special interest are the last two columns that show the last generation where a new item was added to the pareto front of meta scores and how many generations in a row that progress has been made. If enough generations pass without progress the search will terminate.
# 4. result.h5
#   This is an HDF5 file that contains enormous information about the system. It has the entire population, the scores for all items, and other information. With HDFview you can easily view these files and with python you can read any information you want from these files.
# 5. csv file
#   There is one last csv file that is named based on the JSON configuration file and it shows every simulation the system has run along with the scores for that simulation.

# %%
# !explorer {resultDir}

# %% [markdown]
# ## Create corner plots
# These are frequency plots of each variable in your system along with their correlations. What you are looking for is a single peak and this indicates that your variable is identifiable. The peak may be more or less narrow depending on the ranges you gave to the optimizer. If you use an early stopping criteria these plots probably won't be accurate. What is happening is that as the system converges it searches around the best found values to try and find better ones. This means that there are many similar values and so the frequency goes up which shows up as a peak.

# %%
sim.plot_corner()
# Out:
# Corner plot in search space
# Corner plot in original space

# %% [markdown]
# ## Best plots
# This draws a selection of items from the meta folder. It will look in the folder and find the highest Product Root Score, Min Score and Mean Score and the lowest SSE and plot all of those entries. There may still be other items in those folders which are compromises between these scores. The plot will show the ID of the best found item, by what measurements it is the best and what its paramters are.

# %%
sim.plot_best()
# Out:
# Best item 7aa5b19441efd347948024fe63f4c665 for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Wed Oct  2 11:08:12 2019  7aa5b19441efd347948024fe63f4c665   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     1.999871e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_Shape  main_Pulse_Time  \
# 0                       0.369999               1.0              1.0
#
#    Product Root Score  Min Score  Mean Score           SSE
# 0                 1.0        1.0         1.0  6.991438e-13

# %% [markdown]
# ## Comparing to the correct answer
# After all of the fitting is done the results can be compared to the correct answer when doing synthetic experiments. In this case we can see the error is well under 0.1% for all variables which is very good. That would indicate that if we ran this experiment accurately in real life it could work. If a synthetic experiment can not recover the original value then the real experiment will not find those variables accurately either.

# %%
best ,score, best_score = sim.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0065%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.00029%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0065%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.00029%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0065%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.00029%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0065%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.00029%

# %% [markdown]
# ## Create a function to make it easier to run and view a matching process
# Now that we have gone through the process of setting up a model, writing the JSON file, matching and then viewing results lets turn that into a function to make it easier to do that in the future. This way we also don't make mistakes when running the code. In general if you find you are doing the same steps over and over again try and turn that into a function.

# %%
def run_match(match_obj, match_file, true_values, delete):
    "create the matching object, run it and then look at output"
    match = Match(match_file.as_posix())

    resultDir = Path(match_obj.baseDir) / match_obj.resultsDir
    print("Your results are located at", resultDir.as_posix(), '\n\n')

    #If you want to delete the fitting process to start over remove the # from the next line and re-run this cell\
    if delete:
        deleteResultDir(resultDir)

    match.start_sim()

    match.plot_best()
    best ,score, best_score = match.get_best()
    for key,value in best_score.items():
        print("Method: %s" % key)
        for name, val, true_value in zip(match.cache.parameter_headers, value, true_values):
            print("%s = %.2e  true_value = %.2e error: %.2g%%" % (name, val, true_value, numpy.abs(val-true_value)/val*100))
        print('\n')
    return match

# %% [markdown]
# ## Change the search method
# We can also take the exact same setup we just made and change the search method from NSGA3 to Multistart and store the results in a new folder. You can see how the different methods compare.

# %%
match_grad = match.copy()

match_grad.gradVector = 0
match_grad.resultsDir = 'fit_grad'
match_grad.searchMethod = 'Multistart'


match_file = lesson_4 / 'example_gradient.json'

with (match_file).open('w') as json_file:
    json.dump(match_grad.to_dict(), json_file, indent='\t')
    
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
    
sim_grad = run_match(match_grad,
                    match_file,
                    true_values,
                    delete=True)
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_grad
#
#
# [2019-10-02 11:08:41,138] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-02 11:08:41,138] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-10-02 11:08:41,138] launcher  INFO    Worker distribution:
#
# [2019-10-02 11:08:41,138] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-10-02 11:08:44,764] multistart (b'127.0.0.1:61145') INFO    Population [Individual('d', [0.505211847256593, 0.5523701440036917]), Individual('d', [0.0751441237906888, 0.6513825816019057]), Individual('d', [0.598807216888036, 0.9154425811512036]), Individual('d', [0.6757056712182989, 0.8461762429624137]), Individual('d', [0.3907257143165934, 0.05096929726482713]), Individual('d', [0.143186790811469, 0.8688235559891039]), Individual('d', [0.6838124122723231, 0.06514381132573444]), Individual('d', [0.13961393091971863, 0.7486121331904572]), Individual('d', [0.868889380248966, 0.3963057348085326]), Individual('d', [0.4459343910360932, 0.3179050003847145]), Individual('d', [0.1633321072015148, 0.926308320584081]), Individual('d', [0.7684251816016529, 0.8450082921815402]), Individual('d', [0.3439880298814043, 0.02838014543999645]), Individual('d', [0.1450185481888998, 0.8539125323989755]), Individual('d', [0.8695178758801348, 0.7331563466152762]), Individual('d', [0.6830098361383171, 0.3179860180023405]), Individual('d', [0.6103310067006705, 0.5186676413852058]), Individual('d', [0.5054902351108823, 0.5402132280109564]), Individual('d', [0.8404332279146676, 0.7548016749829997]), Individual('d', [0.9156355381230018, 0.355297676948531]), Individual('d', [0.08320446787200186, 0.538582957162034]), Individual('d', [0.3014319687375817, 0.42310024151805115]), Individual('d', [0.8510041736295932, 0.6999737797345038]), Individual('d', [0.6154999720259581, 0.34352985777905487])]
#
# [2019-10-02 11:09:28,500] multistart (b'127.0.0.1:61145') INFO    gradCheck 0.8999999729711573
#
# [2019-10-02 11:09:28,500] multistart (b'127.0.0.1:61145') INFO    newChildren [Individual('d', [0.6960673686804212, 0.48317360484994026]), Individual('d', [0.006101043006050039, 0.4388156483053151]), Individual('d', [0.689188560496444, 0.4662612876789312]), Individual('d', [0.6757102301633461, 0.84615080957112]), Individual('d', [0.3907801289856578, 0.05013259565472752]), Individual('d', [0.7201902272584688, 0.3717821605652611]), Individual('d', [0.6893310624725518, 0.06401012065016444]), Individual('d', [0.7946578851525435, 0.549573658642807]), Individual('d', [0.8013087568996677, 0.5521568851490114]), Individual('d', [0.446653574452066, 0.3167253212193211]), Individual('d', [0.996385197962439, 0.9991799523134671]), Individual('d', [0.7712910958701338, 0.8435079897508022]), Individual('d', [0.39501710537685214, 0.027059046353778086]), Individual('d', [0.07800790419682653, 0.7092202352125494]), Individual('d', [0.8241108288168196, 0.5650938218579246]), Individual('d', [0.6858140404599855, 0.31550875081942154]), Individual('d', [0.614730459726308, 0.5127929310069923]), Individual('d', [0.5353143805078142, 0.5082362822755797]), Individual('d', [0.8404494644637491, 0.7558839281067323]), Individual('d', [0.48639402647352714, 0.4100629392481629]), Individual('d', [0.2757785712265525, 0.489209077481462]), Individual('d', [0.3131344635729418, 0.4199529689917045]), Individual('d', [0.8941073300059783, 0.7136842204744748]), Individual('d', [0.6194456241977512, 0.34125766824193404])]
#
# [2019-10-02 11:09:28,507] util      (b'127.0.0.1:61145') INFO    Generation: -1 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-10-02 11:09:34,600] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-02 11:09:34,600] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-10-02 11:09:34,600] launcher  INFO    Worker distribution:
#
# [2019-10-02 11:09:34,600] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-10-02 11:09:37,245] generate_corner_graphs (b'127.0.0.1:57761') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-10-02 11:09:37,245] generate_corner_graphs (b'127.0.0.1:57761') INFO    plotting corner plots
#
# [2019-10-02 11:09:37,248] generate_corner_graphs (b'127.0.0.1:57761') INFO    graphing remove 0 points
#
# [2019-10-02 11:09:37,288] loggerwriter (b'127.0.0.1:57761') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:09:39,028] loggerwriter (b'127.0.0.1:57761') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:09:40,620] loggerwriter (b'127.0.0.1:57761') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:09:42,168] loggerwriter (b'127.0.0.1:57761') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:09:43,717] loggerwriter (b'127.0.0.1:57761') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:09:45,319] loggerwriter (b'127.0.0.1:57761') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:09:47,398] launcher  (127.0.0.1:53372) INFO    Root process is done.
#
# [2019-10-02 11:09:47,398] launcher  (127.0.0.1:53372) INFO    Finished cleaning spawned subprocesses.
#
# [2019-10-02 11:09:47,416] match     (b'127.0.0.1:61145') INFO    altFeatures False
#
# [2019-10-02 11:09:47,416] match     (b'127.0.0.1:61145') INFO    altFeatureNames []
#
# [2019-10-02 11:09:47,416] match     (b'127.0.0.1:61145') INFO    Sysem has finished
#
# [2019-10-02 11:09:47,416] match     (b'127.0.0.1:61145') INFO    The total runtime was 62.742366790771484 seconds
#
# [2019-10-02 11:09:48,188] launcher  (127.0.0.1:53091) INFO    Root process is done.
#
# [2019-10-02 11:09:48,188] launcher  (127.0.0.1:53091) INFO    Finished cleaning spawned subprocesses.
#
# Best item 4018eb7b991f9c55da574833e6062d9a for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Wed Oct  2 11:09:25 2019  4018eb7b991f9c55da574833e6062d9a   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     1.978989e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_Shape  main_Pulse_Time  \
# 0                       0.369528               1.0              1.0
#
#    Product Root Score  Min Score  Mean Score       SSE
# 0                 1.0        1.0         1.0  0.000006
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.98e-07  true_value = 2.00e-07 error: 1.1%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 0.13%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.98e-07  true_value = 2.00e-07 error: 1.1%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 0.13%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.98e-07  true_value = 2.00e-07 error: 1.1%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 0.13%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 1.98e-07  true_value = 2.00e-07 error: 1.1%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 0.13%

# %% [markdown]
# ## Change the population size
# Sometimes the population size is not large enough and needs to be increased to find better answers.

# %%
match_grad_large = match.copy()

match_grad_large.gradVector = 0
match_grad_large.resultsDir = 'fit_grad_large'
match_grad_large.searchMethod = 'Multistart'
match_grad_large.population = 24
match_grad_large.minPopulation = 24
match_grad_large.maxPopulation = 24


match_file_large = lesson_4 / 'example_gradient_large.json'

with (match_file_large).open('w') as json_file:
    json.dump(match_grad_large.to_dict(), json_file, indent='\t')
   
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
    
sim_grad_large = run_match(match_grad_large,
                    match_file_large,
                    true_values,
                    delete=True)
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_grad_large
#
#
# [2019-10-02 11:09:49,222] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-02 11:09:49,222] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-10-02 11:09:49,222] launcher  INFO    Worker distribution:
#
# [2019-10-02 11:09:49,222] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-10-02 11:09:52,812] multistart (b'127.0.0.1:50691') INFO    Population [Individual('d', [0.8589320556332247, 0.4655861792271361]), Individual('d', [0.6824492684571315, 0.6821101443420493]), Individual('d', [0.9245599827190878, 0.31644197443310795]), Individual('d', [0.5617707790106148, 0.6026623264164305]), Individual('d', [0.3317092943749832, 0.12089203347141253]), Individual('d', [0.008184930737334395, 0.6079765936176715]), Individual('d', [0.8798155568745017, 0.1902896160238402]), Individual('d', [0.05213217509355428, 0.8050094858207383]), Individual('d', [0.2726194124076078, 0.2774499686113603]), Individual('d', [0.13231464030860585, 0.006035436628981428]), Individual('d', [0.28847126409102986, 0.32802237452635863]), Individual('d', [0.2575628170711446, 0.6289855801514839]), Individual('d', [0.0008552418675894513, 0.5979553902818469]), Individual('d', [0.012374095136352015, 0.1979193723003404]), Individual('d', [0.37095682460261203, 0.4814562901874119]), Individual('d', [0.7480324901828346, 0.6846896803817103]), Individual('d', [0.7154903118895392, 0.46521961153114266]), Individual('d', [0.6455363662340186, 0.8473192234376443]), Individual('d', [0.49350998863231954, 0.0014746758965767937]), Individual('d', [0.026402760005026282, 0.667840270918308]), Individual('d', [0.05526492190330157, 0.20270657159330951]), Individual('d', [0.7578325643790241, 0.3664688651108001]), Individual('d', [0.40086255052566766, 0.611958534656282]), Individual('d', [0.6878688124992303, 0.39351653429773814]), Individual('d', [0.016552816339406418, 0.795861014458296]), Individual('d', [0.8583512059790532, 0.7026055046921024]), Individual('d', [0.8494159182517824, 0.2837809613204454]), Individual('d', [0.9272697941125277, 0.5948325013757696]), Individual('d', [0.8149644515527477, 0.7728176723439805]), Individual('d', [0.4784157333666804, 0.4862477947404824]), Individual('d', [0.6485391805805031, 0.4310586442040093]), Individual('d', [0.2900202777669275, 0.4694130953298312]), Individual('d', [0.02067259991424375, 0.6951232319651778]), Individual('d', [0.8032410327825313, 0.8822989331598973]), Individual('d', [0.21966624673419954, 0.6546232779405186]), Individual('d', [0.31634099580732666, 0.3212601655086751]), Individual('d', [0.9057392871859578, 0.3587410516660081]), Individual('d', [0.0724648003207361, 0.3622458533967188]), Individual('d', [0.3466513482463838, 0.8826696292842097]), Individual('d', [0.5895644949606457, 0.47393459579869646]), Individual('d', [0.6251309564922638, 0.8509154408984856]), Individual('d', [0.34605723713505765, 0.2278121543585775]), Individual('d', [0.8331283940532002, 0.5948465975046088]), Individual('d', [0.5819177667394574, 0.18372689774378737]), Individual('d', [0.964147685662047, 0.21066062802644325]), Individual('d', [0.7165958486872352, 0.3899752638598122]), Individual('d', [0.7460475368738955, 0.9273121672603968]), Individual('d', [0.31072763323719066, 0.7578420768296935])]
#
# [2019-10-02 11:11:20,015] multistart (b'127.0.0.1:50691') INFO    gradCheck 0.8999935590499926
#
# [2019-10-02 11:11:20,015] multistart (b'127.0.0.1:50691') INFO    newChildren [Individual('d', [0.8277700062455636, 0.567840699152581]), Individual('d', [0.7395134678607839, 0.5080113487523622]), Individual('d', [0.8121971344661953, 0.5566406290908285]), Individual('d', [0.8586274369290432, 0.5840169666162205]), Individual('d', [0.3330712164206721, 0.11935216483079507]), Individual('d', [0.002414962933806887, 0.49274848804500737]), Individual('d', [0.797684479865725, 0.35551863296706737]), Individual('d', [0.0072266174255131285, 0.4503764504790956]), Individual('d', [0.27289368667925096, 0.27722835779570026]), Individual('d', [0.3012433215475786, 0.004202415123675425]), Individual('d', [0.854500419724967, 0.594552108026054]), Individual('d', [0.2575347108553297, 0.6289938209258451]), Individual('d', [0.2993353391000207, 0.504711812223794]), Individual('d', [0.012309083901208911, 0.19613884218893363]), Individual('d', [0.3778015574722886, 0.47816937689491823]), Individual('d', [0.8306564232523792, 0.5692342369141897]), Individual('d', [0.7170250056384864, 0.4630069725577145]), Individual('d', [0.7517665128798933, 0.19709894848357995]), Individual('d', [0.5582574806740974, 0.0012481631517797516]), Individual('d', [0.026400917024569752, 0.6678430808823401]), Individual('d', [0.060946122011951175, 0.20016486596111027]), Individual('d', [0.7596038682132562, 0.36341968248251905]), Individual('d', [0.000301326543282373, 0.48504163481810975]), Individual('d', [0.6893683836382946, 0.3910061686551418]), Individual('d', [0.8479513404017733, 0.5780641102411539]), Individual('d', [0.7224500399840134, 0.44406581134609635]), Individual('d', [0.8188461991357218, 0.278319712126911]), Individual('d', [0.8804925303270661, 0.5975218720449875]), Individual('d', [0.7566981891006599, 0.5287612389959778]), Individual('d', [0.4797596041938633, 0.48340686430812857]), Individual('d', [0.6501508636080293, 0.42982023067391956]), Individual('d', [0.29915576878765243, 0.46616069992015025]), Individual('d', [0.9093088995742624, 0.6364063949651343]), Individual('d', [0.8141828849829389, 0.5574956393824789]), Individual('d', [0.9056761669597643, 0.6200459986128789]), Individual('d', [0.3211450715673159, 0.3197518248999676]), Individual('d', [0.0961869338198222, 0.4504062433736314]), Individual('d', [0.07433038406981836, 0.36179186261536805]), Individual('d', [0.8592994219694068, 0.6577861624077854]), Individual('d', [0.5907854971958251, 0.4720615754040378]), Individual('d', [0.03048887353246731, 0.2385106890660179]), Individual('d', [0.3448719874103286, 0.22731410472177824]), Individual('d', [0.8356601424075096, 0.5732277679316221]), Individual('d', [0.5799014852613216, 0.17997153611540356]), Individual('d', [0.00010041391799879048, 0.33480649720323175]), Individual('d', [0.6715940328134168, 0.5071821368298525]), Individual('d', [0.7012374229051468, 0.5238480829200854]), Individual('d', [0.31072763323719066, 0.7578420768296935])]
#
# [2019-10-02 11:11:20,024] util      (b'127.0.0.1:50691') INFO    Generation: -1 	Population: 48 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-10-02 11:11:26,204] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-02 11:11:26,204] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-10-02 11:11:26,204] launcher  INFO    Worker distribution:
#
# [2019-10-02 11:11:26,204] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-10-02 11:11:28,923] generate_corner_graphs (b'127.0.0.1:65518') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-10-02 11:11:28,923] generate_corner_graphs (b'127.0.0.1:65518') INFO    plotting corner plots
#
# [2019-10-02 11:11:28,926] generate_corner_graphs (b'127.0.0.1:65518') INFO    graphing remove 0 points
#
# [2019-10-02 11:11:40,077] launcher  (127.0.0.1:53691) INFO    Root process is done.
#
# [2019-10-02 11:11:40,077] launcher  (127.0.0.1:53691) INFO    Finished cleaning spawned subprocesses.
#
# [2019-10-02 11:11:40,095] match     (b'127.0.0.1:50691') INFO    altFeatures False
#
# [2019-10-02 11:11:40,095] match     (b'127.0.0.1:50691') INFO    altFeatureNames []
#
# [2019-10-02 11:11:40,095] match     (b'127.0.0.1:50691') INFO    Sysem has finished
#
# [2019-10-02 11:11:40,095] match     (b'127.0.0.1:50691') INFO    The total runtime was 107.36596155166626 seconds
#
# [2019-10-02 11:11:40,904] launcher  (127.0.0.1:53402) INFO    Root process is done.
#
# [2019-10-02 11:11:40,905] launcher  (127.0.0.1:53402) INFO    Finished cleaning spawned subprocesses.
#
# Best item 6b0c3141249d07da2f750cc8dd6b1259 for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Wed Oct  2 11:10:21 2019  6b0c3141249d07da2f750cc8dd6b1259   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     2.046822e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_Shape  main_Pulse_Time  \
# 0                       0.370352          0.999995         0.999991
#
#    Product Root Score  Min Score  Mean Score           SSE
# 0            0.999993   0.999991    0.999993  1.842608e-07
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.05e-07  true_value = 2.00e-07 error: 2.3%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 0.095%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.05e-07  true_value = 2.00e-07 error: 2.3%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 0.095%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.05e-07  true_value = 2.00e-07 error: 2.3%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 0.095%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 2.05e-07  true_value = 2.00e-07 error: 2.3%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 0.095%

# %% [markdown]
# ## Changing the score
# You can also change to an SSE based score and use gradient descent. For this problem it should provide very good results.

# %%
match_sse = match.copy()

match_sse.resultsDir = 'fit_sse'
match_sse.searchMethod = 'Multistart'
match_sse.experiments[0].features[0].type = 'DextranSSE'


match_file = lesson_4 / 'example_sse.json'

with (match_file).open('w') as json_file:
    json.dump(match_sse.to_dict(), json_file, indent='\t')
    
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])

sim_sse = run_match(match_sse,
                    match_file,
                    true_values,
                    delete=True)
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_sse
#
#
# [2019-10-02 11:11:41,935] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-02 11:11:41,935] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-10-02 11:11:41,935] launcher  INFO    Worker distribution:
#
# [2019-10-02 11:11:41,935] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-10-02 11:11:45,628] multistart (b'127.0.0.1:54649') INFO    Population [Individual('d', [0.40564270052662443, 0.83382014582473]), Individual('d', [0.3530413188645931, 0.48344316615120086]), Individual('d', [0.402360620977364, 0.4295398669145485]), Individual('d', [0.43667485642488646, 0.0013722638923920893]), Individual('d', [0.6157030475698335, 0.836731753780075]), Individual('d', [0.1116611003683522, 0.17873868758649658]), Individual('d', [0.7618247072190997, 0.6499250592696417]), Individual('d', [0.5116120882294525, 0.8276165473435604]), Individual('d', [0.2829477606928813, 0.4144165508177682]), Individual('d', [0.022163209219866697, 0.02278559892890597]), Individual('d', [0.14911086465220014, 0.395522706371385]), Individual('d', [0.5815592506707018, 0.3630959590024938]), Individual('d', [0.9446687367916626, 0.7357159766495257]), Individual('d', [0.988015083912783, 0.3145813875620984]), Individual('d', [0.9410191419289489, 0.05687392868298691]), Individual('d', [0.8429127267077863, 0.2936567554611824]), Individual('d', [0.49177024243039336, 0.09854892907081825]), Individual('d', [0.7893689318141867, 0.615475213306842]), Individual('d', [0.17712854751641516, 0.7313246143809783]), Individual('d', [0.8610246567255928, 0.9852698279800831]), Individual('d', [0.17210908631647814, 0.9937545456313005]), Individual('d', [0.6119146688204543, 0.8604674774417352]), Individual('d', [0.0117531143337134, 0.47033926240823354]), Individual('d', [0.4835727214258292, 0.08857775959944192])]
#
# [2019-10-02 11:11:46,246] gradFD    (b'127.0.0.1:54649') INFO    removed [0.40564270052662443, 0.83382014582473] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,247] gradFD    (b'127.0.0.1:54649') INFO    removed [0.402360620977364, 0.4295398669145485] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,247] gradFD    (b'127.0.0.1:54649') INFO    removed [0.43667485642488646, 0.0013722638923920893] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,247] gradFD    (b'127.0.0.1:54649') INFO    removed [0.6157030475698335, 0.836731753780075] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,247] gradFD    (b'127.0.0.1:54649') INFO    removed [0.1116611003683522, 0.17873868758649658] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,248] gradFD    (b'127.0.0.1:54649') INFO    removed [0.7618247072190997, 0.6499250592696417] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,248] gradFD    (b'127.0.0.1:54649') INFO    removed [0.5116120882294525, 0.8276165473435604] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,248] gradFD    (b'127.0.0.1:54649') INFO    removed [0.2829477606928813, 0.4144165508177682] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,248] gradFD    (b'127.0.0.1:54649') INFO    removed [0.022163209219866697, 0.02278559892890597] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,248] gradFD    (b'127.0.0.1:54649') INFO    removed [0.14911086465220014, 0.395522706371385] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,489] gradFD    (b'127.0.0.1:54649') INFO    removed [0.5815592506707018, 0.3630959590024938] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,489] gradFD    (b'127.0.0.1:54649') INFO    removed [0.988015083912783, 0.3145813875620984] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,489] gradFD    (b'127.0.0.1:54649') INFO    removed [0.9410191419289489, 0.05687392868298691] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,489] gradFD    (b'127.0.0.1:54649') INFO    removed [0.8429127267077863, 0.2936567554611824] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,489] gradFD    (b'127.0.0.1:54649') INFO    removed [0.49177024243039336, 0.09854892907081825] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,489] gradFD    (b'127.0.0.1:54649') INFO    removed [0.7893689318141867, 0.615475213306842] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,489] gradFD    (b'127.0.0.1:54649') INFO    removed [0.17712854751641516, 0.7313246143809783] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,490] gradFD    (b'127.0.0.1:54649') INFO    removed [0.8610246567255928, 0.9852698279800831] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,490] gradFD    (b'127.0.0.1:54649') INFO    removed [0.17210908631647814, 0.9937545456313005] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,490] gradFD    (b'127.0.0.1:54649') INFO    removed [0.6119146688204543, 0.8604674774417352] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,490] gradFD    (b'127.0.0.1:54649') INFO    removed [0.4835727214258292, 0.08857775959944192] for insufficient overlap in gradient descent
#
# [2019-10-02 11:11:46,490] gradFD    (b'127.0.0.1:54649') INFO    overlap okay offspring [[0.3530413188645931, 0.48344316615120086], [0.9446687367916626, 0.7357159766495257], [0.0117531143337134, 0.47033926240823354]]
#
# [2019-10-02 11:12:08,492] multistart (b'127.0.0.1:54649') INFO    gradCheck -6.456812444008159e-16
#
# [2019-10-02 11:12:08,492] multistart (b'127.0.0.1:54649') INFO    newChildren [Individual('d', [0.8252572738229994, 0.5666665522717187]), Individual('d', [0.9423445867951257, 0.7363411396661388]), Individual('d', [0.003770456759213186, 0.48118827463297026])]
#
# [2019-10-02 11:12:08,498] util      (b'127.0.0.1:54649') INFO    Generation: -1 	Population: 3 	Average Score: -7.17e-16 	Best: -7.17e-16 	Minimum Score: -7.17e-16 	Best: -7.17e-16 	Product Score: -7.17e-16 	Best: -7.17e-16
#
# [2019-10-02 11:12:14,637] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-02 11:12:14,637] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-10-02 11:12:14,637] launcher  INFO    Worker distribution:
#
# [2019-10-02 11:12:14,637] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-10-02 11:12:17,294] generate_corner_graphs (b'127.0.0.1:65054') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-10-02 11:12:17,294] generate_corner_graphs (b'127.0.0.1:65054') INFO    plotting corner plots
#
# [2019-10-02 11:12:17,341] loggerwriter (b'127.0.0.1:65054') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:12:19,124] loggerwriter (b'127.0.0.1:65054') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:12:20,785] loggerwriter (b'127.0.0.1:65054') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:12:22,405] loggerwriter (b'127.0.0.1:65054') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:12:24,100] loggerwriter (b'127.0.0.1:65054') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:12:25,729] loggerwriter (b'127.0.0.1:65054') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:12:27,923] launcher  (127.0.0.1:54000) INFO    Root process is done.
#
# [2019-10-02 11:12:27,923] launcher  (127.0.0.1:54000) INFO    Finished cleaning spawned subprocesses.
#
# [2019-10-02 11:12:27,941] match     (b'127.0.0.1:54649') INFO    altFeatures False
#
# [2019-10-02 11:12:27,941] match     (b'127.0.0.1:54649') INFO    altFeatureNames []
#
# [2019-10-02 11:12:27,941] match     (b'127.0.0.1:54649') INFO    Sysem has finished
#
# [2019-10-02 11:12:27,941] match     (b'127.0.0.1:54649') INFO    The total runtime was 42.40312457084656 seconds
#
# [2019-10-02 11:12:28,710] launcher  (127.0.0.1:53721) INFO    Root process is done.
#
# [2019-10-02 11:12:28,712] launcher  (127.0.0.1:53721) INFO    Finished cleaning spawned subprocesses.
#
# Best item ac09767019da367807da9cac553e5adf for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Wed Oct  2 11:12:07 2019  ac09767019da367807da9cac553e5adf   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     1.999996e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_SSE  Product Root Score  \
# 0                           0.37   -7.174236e-16       -7.174236e-16
#
#       Min Score    Mean Score           SSE
# 0 -7.174236e-16 -7.174236e-16  7.174236e-16
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07  true_value = 2.00e-07 error: 0.00021%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 9.3e-06%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07  true_value = 2.00e-07 error: 0.00021%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 9.3e-06%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07  true_value = 2.00e-07 error: 0.00021%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 9.3e-06%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07  true_value = 2.00e-07 error: 0.00021%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 9.3e-06%

# %% [markdown]
# ## A large population can still help
# Partial Differential Equations are complex and a different start location can provide a better result. The best way to deal with this is to increase the population size.

# %%
match_sse_large = match.copy()

match_sse_large.resultsDir = 'fit_sse_large'
match_sse_large.searchMethod = 'Multistart'
match_sse_large.population = 24
match_sse_large.minPopulation = 24
match_sse_large.maxPopulation = 24
match_sse_large.experiments[0].features[0].type = 'DextranSSE'


match_file = lesson_4 / 'example_sse_large.json'

with (match_file).open('w') as json_file:
    json.dump(match_sse_large.to_dict(), json_file, indent='\t')

true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
    
sim_sse_large = run_match(match_sse_large,
                    match_file,
                    true_values,
                    delete=True)
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_sse_large
#
#
# [2019-10-02 11:12:29,739] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-02 11:12:29,739] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-10-02 11:12:29,739] launcher  INFO    Worker distribution:
#
# [2019-10-02 11:12:29,739] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-10-02 11:12:33,445] multistart (b'127.0.0.1:62339') INFO    Population [Individual('d', [0.30886328060425494, 0.8555729059176355]), Individual('d', [0.21481148469983813, 0.3217151796368166]), Individual('d', [0.0324107905765888, 0.17163505944076896]), Individual('d', [0.05998123679460732, 0.012685272320708818]), Individual('d', [0.07689120285179096, 0.359806164082227]), Individual('d', [0.5590341828291389, 0.17732005216344815]), Individual('d', [0.43358540606104135, 0.7530113973079148]), Individual('d', [0.7300457948234242, 0.05070235349698582]), Individual('d', [0.7256531746609968, 0.8564217568080096]), Individual('d', [0.9721315154200733, 0.06622044446865061]), Individual('d', [0.025932454552417106, 0.5400072363480047]), Individual('d', [0.5276176622598147, 0.08900952115732219]), Individual('d', [0.604999049128633, 0.04854931083243863]), Individual('d', [0.5322597477530929, 0.9365887047402651]), Individual('d', [0.056443631372764314, 0.49564683075165383]), Individual('d', [0.3004137155165001, 0.4749718626820676]), Individual('d', [0.28541989190475303, 0.6168185709108706]), Individual('d', [0.44195486273391715, 0.2806045556435224]), Individual('d', [0.5515878094065914, 0.137123376905247]), Individual('d', [0.046441934563671516, 0.862169020037213]), Individual('d', [0.47269300554345417, 0.9467882637260545]), Individual('d', [0.6462456931392404, 0.29013526911628684]), Individual('d', [0.00032932806781749147, 0.5108804904504561]), Individual('d', [0.19841092413852324, 0.9900407422151156]), Individual('d', [0.7914597510643187, 0.8135043117934208]), Individual('d', [0.6247515112582682, 0.09760059863463832]), Individual('d', [0.790032258417163, 0.3778655758503068]), Individual('d', [0.7536421660809196, 0.9117128019550291]), Individual('d', [0.6322215670979804, 0.05626819473020506]), Individual('d', [0.701155987572367, 0.525346062304573]), Individual('d', [0.758999473680965, 0.9671272599723185]), Individual('d', [0.0149262812136014, 0.7477354039068392]), Individual('d', [0.7236592612230522, 0.015020801125704364]), Individual('d', [0.7667149785922269, 0.11109717830308052]), Individual('d', [0.9772920215336219, 0.594319649229965]), Individual('d', [0.5282021920754107, 0.0782795740513833]), Individual('d', [0.16789683818914625, 0.6458283496853358]), Individual('d', [0.6519466460347927, 0.7234895141059292]), Individual('d', [0.6808004510208002, 0.4650717121105714]), Individual('d', [0.3477292489576004, 0.5393342417199236]), Individual('d', [0.5384954236914801, 0.6208286838116831]), Individual('d', [0.3622713091794124, 0.9257462817500773]), Individual('d', [0.4420463487685985, 0.8355013337108371]), Individual('d', [0.6810062438689783, 0.26436299159130083]), Individual('d', [0.916590148039896, 0.7739578154731914]), Individual('d', [0.9305993541976386, 0.5911877300234772]), Individual('d', [0.01480024817854797, 0.3339911183431007]), Individual('d', [0.4971104137931811, 0.9982609400501202])]
#
# [2019-10-02 11:12:34,130] gradFD    (b'127.0.0.1:62339') INFO    removed [0.30886328060425494, 0.8555729059176355] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,130] gradFD    (b'127.0.0.1:62339') INFO    removed [0.21481148469983813, 0.3217151796368166] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,131] gradFD    (b'127.0.0.1:62339') INFO    removed [0.0324107905765888, 0.17163505944076896] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,131] gradFD    (b'127.0.0.1:62339') INFO    removed [0.05998123679460732, 0.012685272320708818] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,131] gradFD    (b'127.0.0.1:62339') INFO    removed [0.07689120285179096, 0.359806164082227] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,131] gradFD    (b'127.0.0.1:62339') INFO    removed [0.5590341828291389, 0.17732005216344815] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,132] gradFD    (b'127.0.0.1:62339') INFO    removed [0.43358540606104135, 0.7530113973079148] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,132] gradFD    (b'127.0.0.1:62339') INFO    removed [0.7300457948234242, 0.05070235349698582] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,132] gradFD    (b'127.0.0.1:62339') INFO    removed [0.7256531746609968, 0.8564217568080096] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,132] gradFD    (b'127.0.0.1:62339') INFO    removed [0.9721315154200733, 0.06622044446865061] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,500] gradFD    (b'127.0.0.1:62339') INFO    removed [0.5276176622598147, 0.08900952115732219] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,501] gradFD    (b'127.0.0.1:62339') INFO    removed [0.604999049128633, 0.04854931083243863] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,501] gradFD    (b'127.0.0.1:62339') INFO    removed [0.5322597477530929, 0.9365887047402651] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,502] gradFD    (b'127.0.0.1:62339') INFO    removed [0.28541989190475303, 0.6168185709108706] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,502] gradFD    (b'127.0.0.1:62339') INFO    removed [0.44195486273391715, 0.2806045556435224] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,502] gradFD    (b'127.0.0.1:62339') INFO    removed [0.5515878094065914, 0.137123376905247] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,503] gradFD    (b'127.0.0.1:62339') INFO    removed [0.046441934563671516, 0.862169020037213] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,503] gradFD    (b'127.0.0.1:62339') INFO    removed [0.47269300554345417, 0.9467882637260545] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,503] gradFD    (b'127.0.0.1:62339') INFO    removed [0.6462456931392404, 0.29013526911628684] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,909] gradFD    (b'127.0.0.1:62339') INFO    removed [0.19841092413852324, 0.9900407422151156] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,909] gradFD    (b'127.0.0.1:62339') INFO    removed [0.7914597510643187, 0.8135043117934208] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,909] gradFD    (b'127.0.0.1:62339') INFO    removed [0.6247515112582682, 0.09760059863463832] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,910] gradFD    (b'127.0.0.1:62339') INFO    removed [0.790032258417163, 0.3778655758503068] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,910] gradFD    (b'127.0.0.1:62339') INFO    removed [0.7536421660809196, 0.9117128019550291] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,910] gradFD    (b'127.0.0.1:62339') INFO    removed [0.6322215670979804, 0.05626819473020506] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,911] gradFD    (b'127.0.0.1:62339') INFO    removed [0.758999473680965, 0.9671272599723185] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,911] gradFD    (b'127.0.0.1:62339') INFO    removed [0.0149262812136014, 0.7477354039068392] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,911] gradFD    (b'127.0.0.1:62339') INFO    removed [0.7236592612230522, 0.015020801125704364] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,912] gradFD    (b'127.0.0.1:62339') INFO    removed [0.7667149785922269, 0.11109717830308052] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:34,912] gradFD    (b'127.0.0.1:62339') INFO    removed [0.9772920215336219, 0.594319649229965] for insufficient overlap in gradient descent
# [2019-10-02 11:12:35,136] gradFD    (b'127.0.0.1:62339') INFO    removed [0.5282021920754107, 0.0782795740513833] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:35,136] gradFD    (b'127.0.0.1:62339') INFO    removed [0.16789683818914625, 0.6458283496853358] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:35,136] gradFD    (b'127.0.0.1:62339') INFO    removed [0.6519466460347927, 0.7234895141059292] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:35,136] gradFD    (b'127.0.0.1:62339') INFO    removed [0.5384954236914801, 0.6208286838116831] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:35,136] gradFD    (b'127.0.0.1:62339') INFO    removed [0.3622713091794124, 0.9257462817500773] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:35,136] gradFD    (b'127.0.0.1:62339') INFO    removed [0.4420463487685985, 0.8355013337108371] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:35,137] gradFD    (b'127.0.0.1:62339') INFO    removed [0.6810062438689783, 0.26436299159130083] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:35,137] gradFD    (b'127.0.0.1:62339') INFO    removed [0.916590148039896, 0.7739578154731914] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:35,137] gradFD    (b'127.0.0.1:62339') INFO    removed [0.01480024817854797, 0.3339911183431007] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:35,137] gradFD    (b'127.0.0.1:62339') INFO    removed [0.4971104137931811, 0.9982609400501202] for insufficient overlap in gradient descent
#
# [2019-10-02 11:12:35,137] gradFD    (b'127.0.0.1:62339') INFO    overlap okay offspring [[0.025932454552417106, 0.5400072363480047], [0.056443631372764314, 0.49564683075165383], [0.3004137155165001, 0.4749718626820676], [0.00032932806781749147, 0.5108804904504561], [0.701155987572367, 0.525346062304573], [0.6808004510208002, 0.4650717121105714], [0.3477292489576004, 0.5393342417199236], [0.9305993541976386, 0.5911877300234772]]
#
# [2019-10-02 11:13:06,668] multistart (b'127.0.0.1:62339') INFO    gradCheck -1.2018381502855333e-15
#
# [2019-10-02 11:13:06,668] multistart (b'127.0.0.1:62339') INFO    newChildren [Individual('d', [0.015720183152955466, 0.5543855645596361]), Individual('d', [0.8252567202584407, 0.5666662709443588]), Individual('d', [0.8252354027905809, 0.5666554379983533]), Individual('d', [3.1279996839873846e-16, 0.5120006057608345]), Individual('d', [0.8252571918186876, 0.5666665105961782]), Individual('d', [0.825237036299586, 0.566656268046108]), Individual('d', [0.347386360424252, 0.5396601735547475]), Individual('d', [0.889170531294989, 0.6078352250678364])]
#
# [2019-10-02 11:13:06,675] util      (b'127.0.0.1:62339') INFO    Generation: -1 	Population: 8 	Average Score: -1.34e-15 	Best: -1.34e-15 	Minimum Score: -1.34e-15 	Best: -1.34e-15 	Product Score: -1.34e-15 	Best: -1.34e-15
#
# [2019-10-02 11:13:12,765] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-02 11:13:12,765] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-10-02 11:13:12,765] launcher  INFO    Worker distribution:
#
# [2019-10-02 11:13:12,765] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-10-02 11:13:15,456] generate_corner_graphs (b'127.0.0.1:64665') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-10-02 11:13:15,456] generate_corner_graphs (b'127.0.0.1:64665') INFO    plotting corner plots
#
# [2019-10-02 11:13:15,499] loggerwriter (b'127.0.0.1:64665') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:13:17,266] loggerwriter (b'127.0.0.1:64665') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:13:18,906] loggerwriter (b'127.0.0.1:64665') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:13:20,529] loggerwriter (b'127.0.0.1:64665') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:13:22,167] loggerwriter (b'127.0.0.1:64665') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:13:23,753] loggerwriter (b'127.0.0.1:64665') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-02 11:13:25,902] launcher  (127.0.0.1:54310) INFO    Root process is done.
#
# [2019-10-02 11:13:25,903] launcher  (127.0.0.1:54310) INFO    Finished cleaning spawned subprocesses.
#
# [2019-10-02 11:13:25,920] match     (b'127.0.0.1:62339') INFO    altFeatures False
#
# [2019-10-02 11:13:25,920] match     (b'127.0.0.1:62339') INFO    altFeatureNames []
#
# [2019-10-02 11:13:25,920] match     (b'127.0.0.1:62339') INFO    Sysem has finished
#
# [2019-10-02 11:13:25,920] match     (b'127.0.0.1:62339') INFO    The total runtime was 52.568400621414185 seconds
#
# [2019-10-02 11:13:26,710] launcher  (127.0.0.1:54031) INFO    Root process is done.
#
# [2019-10-02 11:13:26,710] launcher  (127.0.0.1:54031) INFO    Finished cleaning spawned subprocesses.
#
# Best item 25db7930d932a51f93589b161570066d for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Wed Oct  2 11:13:05 2019  25db7930d932a51f93589b161570066d   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     1.999994e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_SSE  Product Root Score  \
# 0                           0.37   -1.335376e-15       -1.335376e-15
#
#       Min Score    Mean Score           SSE
# 0 -1.335376e-15 -1.335376e-15  1.335376e-15
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07  true_value = 2.00e-07 error: 0.00028%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 1.3e-05%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07  true_value = 2.00e-07 error: 0.00028%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 1.3e-05%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07  true_value = 2.00e-07 error: 0.00028%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 1.3e-05%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07  true_value = 2.00e-07 error: 0.00028%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01  true_value = 3.70e-01 error: 1.3e-05%
