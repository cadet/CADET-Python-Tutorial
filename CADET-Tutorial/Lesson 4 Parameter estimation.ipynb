# %% [markdown]
# # Lesson 4
#
# Our goal is to match computer simulations to real experiments. Computer simulations are also cheaper to do and can be used to tell us if the real experiment can even answer the question we want to ask. The idea is to build the experiment synthetically first and then try to match against the synthetic data and see if under ideal circumstances if you can identify the parameters of interest. If you can't do it synthetically you can't do it in real life either which has many sources of error. Many times I have seen experiments run which turned out to have no chance of providing the required information because the experiment was run before figuring out what experiment should be run.
#
# ## Purpose
#
# The goal of this section is to learn how to setup, run and analyze a parameter estimation run.
#
# The example used is from Lesson 1 which is a simple Dextran pulse through a column. This lesson will cover the the common variable transforms, scores and search algorithms.
#
# ## Standard imports

# %%
#from IPython.core.display import display, HTML
from IPython.display import display, HTML, clear_output
display(HTML("<style>.container { width:100% !important; }</style>"))

#Python path library support
from pathlib import Path

#python numeric library
import numpy

#python math library
import math

#scientific library for python
import scipy

#pandas is python library for data analysis
import pandas

#addict is a library that makes it easier to create nested dictionaries
from addict import Dict

#json is a standard text based format and it used in CADETMatch for the configuration file
import json

#python plotting library
import matplotlib.pyplot as plt

#cadet python interface
from cadet import Cadet

#jupyter widget support
from ipywidgets import interact
import ipywidgets as widgets

from CADETMatch.jupyter import Match

#This is just a support function to make running the examples a bit easier later
def deleteResultDir(path):
    #This is to try and make sure that only an actual result directory can be removed
    #And only if no other files have been added to the directory, just in case
    if not path.exists():
        return
    allowed = {'evo', 'grad', 'log', 'mcmc', 'meta', 'misc', 'progress', 
               'space', 'error.csv', 'result.h5', 'progress.csv'}
    allowed.add(match.CSV)
    allowed.add(match_file.name)
    okayToRemove = False
    for child in path.iterdir():
        if child.name not in allowed:
            break
    else:
        okayToRemove = True
    if okayToRemove:
        import shutil
        shutil.rmtree(path)
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Setup CADET path

# %%
#put in the path to the bin folder
cadet_bin_path = Path(r"C:\Users\kosh_000\cadet_build\CADET\VCPKG\bin")

cadet_path = cadet_bin_path / "cadet-cli.exe"

if cadet_path.exists():
    print("CADET was found. Continue to the next step.")
    Cadet.cadet_path = cadet_path.as_posix()
else:
    print('CADET could not be found. Please check the bin path')
    
print(cadet_path.as_posix())
# Out:
# CADET was found. Continue to the next step.
# C:/Users/kosh_000/cadet_build/CADET/VCPKG/bin/cadet-cli.exe

# %% [markdown]
# ## Find the lesson folders and create the folder for lesson 4

# %%
#set this to a directory on your computer where the cadet tutorial files can be saved
cadet_tutorial = Path('F:/temp/cadet_tutorial')
lesson_1 = cadet_tutorial / "lesson_1"
lesson_2 = cadet_tutorial / "lesson_2"
lesson_3 = cadet_tutorial / "lesson_3"
lesson_4 = cadet_tutorial / "lesson_4"
lesson_4.mkdir(exist_ok = True, parents=True)

# %% [markdown]
# ## Load simple example from Lesson 1
# This code is pretty much the same as what we have looked at before. We open the file from Lesson 1 and then resave it to the Lesson 4 folder. We also run the simulation and save the output of the chromatogram as a CSV file to use in the matching process.

# %%
simple_example = lesson_1 / "simple_example"
simple_example.mkdir(exist_ok = True)

simple = Cadet()

#give a filename for where the simulation should be saved
simple.filename = (simple_example / 'example.h5').as_posix()

simple.load()

simple.filename = (lesson_4 / 'example.h5').as_posix()

#save the simulation
simple.save()

#run the simulation
data = simple.run()

print(data)

if data.returncode == 0:
    print("Simulation completed successfully")
    
    #load the data from the simulation so we can view the results
    simple.load()
    
    #plot the simulation
    plt.figure(figsize=[10,10])
    plt.plot(simple.root.output.solution.solution_times,
        simple.root.output.solution.unit_002.solution_outlet_comp_000)
    
    #write the chromatogram data out to a csv file
    data = pandas.DataFrame([simple.root.output.solution.solution_times,
                        simple.root.output.solution.unit_001.solution_outlet_comp_000]).transpose()
    data.to_csv((lesson_4 / 'example.csv').as_posix(), index=False, header=False)
    
else:
    print("Simulation failed")
# Out:
# CompletedProcess(args=['C:/Users/kosh_000/cadet_build/CADET/VCPKG/bin/cadet-cli.exe', 'F:/temp/cadet_tutorial/lesson_4/example.h5'], returncode=0, stdout=b'', stderr=b'')
# Simulation completed successfully

# %% [markdown]
# ## Create CADETMatch configuration
#
# ### Search Method
# There are 4 main search methods and only 3 of them are directly used.
# 1. NSGA3
#   This is the default evolutionary algorithm and the best choice to use when you don't know anything about your search space.
# 2. Multistart
#   This is a multistart gradient descent algorithm. If your problem can be solved with gradient descent then this can be a very good choice. It creates an initial population the same way that NSGA3 does so that you don't have to worry about starting point.
# 3. GraphSpace
#   This is not for optimization and instead it is just for sampling the space. If you have a new problem and you have no idea what the range of any of the parameters are you can use this with a very large population and it will just evaluate the entire starting population and then terminate. This allows you to figure out what are plausiable ranges for your variables before using one of the search algorithms. When dealing with many variables it is still possible to miss regions of viable solutions inside large non-viable regions but in practice this has rarely been a problem.
# 4. MCMC
#   This performans the error modeling and sampling. It is not an optimization algorithm and while it will probably find the optimum value while it runs it is very slow to do so and won't stop even if it finds the optimal value. This should also not be used directly. Normally NSGA3 is used and an option is set to continue with MCMC after NSGA3 has completed. This allows MCMC to be seeded with the best values from NSGA3 which dramatically improves convergence. If you have many variables and you run this directly it may never converge since it may never find high probability regions, much less sample from them effectively.

# %%
match = Dict()
match.CADETPath = cadet_path.as_posix()
match.baseDir = lesson_4.as_posix()
match.resultsDir = 'fit_nsga3'
match.CSV = 'fit_results.csv'
match.checkpointFile = "check"
match.stopAverage = 1.1
match.stopBest = 1.1
match.gradCheck = 1.1
match.gradVector = 1
match.searchMethod = 'NSGA3'
match.mutationRate = 1.0
match.crossoverRate = 1.0
match.generations = 1000
match.population = 12
match.minPopulation = 12
match.maxPopulation = 12
match.finalGradRefinement = 1
match.stallGenerations = 10

# %% [markdown]
# ### Variable transforms
# Search algorithms don't work well when the parameters have very different ranges. For example if one parmeter varies from 1e-5 to 1e-10 and the other varies from 1-10. Another problem is when parameters are tightly coupled together but presented to the optimizer as indepdent variables. This is true with kA and kD for the adsorption and desorption rates. The parameters kA and kD are coupled together but given as two different variables while they do not freely vary from each other. To solve this problem variable transforms are available. I will cover the most common and useful transformations. There are some other variable transforms available that you can see at https://github.com/modsim/CADET-Match/tree/master/CADETMatch/transform
#
# 1. norm
#
#   This is a simple transform that normalizes a variable from 0 to 1. This is best used when you have a variable that varies over less then 3 orders of magnitude.
#
#   ```json
# {
#       "transform": "norm",
#       "component": -1,
#       "bound": -1,
#       "location": "/input/model/unit_001/COL_POROSITY",
#       "min": 0.2,
#       "max": 0.5
#     }
# ```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm'
# parameter.component = -1
# parameter.bound = -1
# parameter.location = "/input/model/unit_001/COL_POROSITY"
# parameter.min = 0.2
# parameter.max = 0.5
# ```
#
# 2. norm_log
#
#   This transform takes the log before normalizing the variable from 0 to 1. Use this transform when your variable spans more than 3 orders of magnitude.
#
#     ```json
# {
#       "transform": "norm_log",
#       "component": -1,
#       "bound": -1,
#       "location": "/input/model/unit_001/COL_DISPERSION",
#       "min": 1e-12,
#       "max": 1e-5
#     }
# ```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_log'
# parameter.component = -1
# parameter.bound = -1
# parameter.location = "/input/model/unit_001/COL_DISPERSION"
# parameter.min = 1e-12
# parameter.max = 1e-5
# ```
#
# 3. norm_keq
#
#    This transform turns ka, kd in ka and keq=ka/kd and then takes a log transform and normalizes from 0 to 1.
#
#    ```json
# {
#     "transform": "norm_keq",
#     "component": 0,
#     "bound": 0,
#     "location": [
#         "/input/model/unit_001/adsorption/LIN_KA",
#         "/input/model/unit_001/adsorption/LIN_KD"
#     ],
#     "minKA": 1e-8,
#     "maxKA": 1e8,
#     "minKEQ": 1e-4,
#     "maxKEQ": 1e4
# }
# ```
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_keq'
# parameter.component = 0
# parameter.bound = 0
# parameter.location = ["/input/model/unit_001/adsorption/LIN_KA",
#                       "/input/model/unit_001/adsorption/LIN_KD"]
# parameter.minKA = 1e-8
# parameter.maxKA = 1e8
# parameter.minKEQ = 1e-4
# parameter.maxKEQ = 1e4
# ```
#
#
# 4. norm_volume_area
#
#     This transform and the following one where created to solve the same common problem. When fitting bypass data and you model the tubing you are fitting the length, crosssectional area and dispersion of the tubing. Dispersion though is tied to the length such that a shorter length can just be compensated for with a higher diffusion. Basically we have fewer degrees of freedom that we are fitting with and since this is not a fluid dynamics model it is not physically accurate. This transformation couples the length and area together through the volume since volume is an identfiable quantity (since water is incompressible). We don't actually care much about the parameters for the tubing, it is just there to fill in for the real tubing so that fewer errors are carried into the column. Use this version if it is easier to measure the diameter of the tubing and use the other transform if measuring the length is easier. I just depends on your experimental setup.
#
#
#
# ```json
# {
#   "transform": "norm_volume_area",
#   "area_location": "/input/model/unit_003/COL_DISPERSION",
#   "length_location": "/input/model/unit_004/COL_DISPERSION",
#   "component": -1,
#   "bound": -1,
#   "minVolume":1e-6,
#   "maxVolume":1e-5,
#   "minArea":1e-4,
#   "maxArea":1e-3
# }```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_volume_area'
# parameter.area_location = "/input/model/unit_003/COL_DISPERSION"
# parameter.length_location = "/input/model/unit_004/COL_DISPERSION"
# parameter.component = -1
# parameter.bound = -1
# parameter.minVolume = 1e-6
# parameter.maxVolume = 1e-5
# parameter.minArea = 1e-4
# parameter.maxArea = 1e-3
# ```
#
#
# 5. norm_volume_length
#
#     Use this transform if measuring the length accurately is easier than measuring the diameter of the tubing. If you are lumping together all the tubing in front of the column or after the column together and you have multiple diameters it doesn't matter which of these transforms you choose.
#
# ```json
# {
#   "transform": "norm_volume_length",
#   "area_location": "/input/model/unit_003/COL_DISPERSION",
#   "length_location": "/input/model/unit_004/COL_DISPERSION",
#   "component": -1,
#   "bound": -1,
#   "minVolume":1e-6,
#   "maxVolume":1e-5,
#   "minLength":0.25,
#   "maxLength":0.75
# }```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_volume_area'
# parameter.area_location = "/input/model/unit_003/COL_DISPERSION"
# parameter.length_location = "/input/model/unit_004/COL_DISPERSION"
# parameter.component = -1
# parameter.bound = -1
# parameter.minVolume = 1e-6
# parameter.maxVolume = 1e-5
# parameter.minLength = 0.25
# parameter.maxLength = 0.75
# ```
#
#
# 6. set_value
#
#     This is a different kind of transform. What it allows you to do is copy a value from place to another. This is important if you are estimating axial dispersion for identical tubing in front of and behind the column. You want the same axial dispersion for both pieces of tubing but you only want to estimate one variable. With this you can estimate axial dispersion for the first piece of tubing and then copy the value over to the other piece of tubing. This is also required if you want to estimate SMA_LAMDA. Whenever SMA_LAMBDA change the initial bound salt concentration also much change or electronuetrality would be violated.
#
# ```json
# {
#   "transform": "set_value",
#   "componentFrom": -1,
#   "boundFrom": -1,
#   "locationFrom": "/input/model/unit_003/COL_DISPERSION",
#   "componentTo": -1,
#   "boundTo": -1,
#   "locationTo": "/input/model/unit_004/COL_DISPERSION"
# }```
#
# ```python
# {
# parameter = Dict()
# parameter.transform = 'set_value'
# parameter.componentFrom = -1
# parameter.boundFrom = -1
# parameter.locationFrom = "/input/model/unit_001/COL_DISPERSION"
# parameter.componentTo = -1
# parameter.boundTo = -1
# parameter.locationTo = "/input/model/unit_001/COL_DISPERSION"
# }```

# %%
parameter1 = Dict()
parameter1.transform = 'norm_log'
parameter1.component = -1
parameter1.bound = -1
parameter1.location = "/input/model/unit_001/COL_DISPERSION"
parameter1.min = 1e-10
parameter1.max = 1e-6

parameter2 = Dict()
parameter2.transform = 'norm'
parameter2.component = -1
parameter2.bound = -1
parameter2.location = "/input/model/unit_001/COL_POROSITY"
parameter2.min = 0.2
parameter2.max = 0.5

match.parameters = [parameter1, parameter2]

# %% [markdown]
# ### Scores
#
# Scores are how the search algorithm measures if a solution is better or worse than what it had before. Without a good score system an optimizer can't work. There are many scores available and I am going to cover the most commonly used ones and when you should use them. You can see all of them at https://github.com/modsim/CADET-Match/tree/master/CADETMatch/scores . Most of these scores are based on physical understanding of the problem and it is pretty easy to add new scores. If there is a feature you can identify in your problem that ties to one of the variables being estimated then go ahead and make a score for it. Maybe for your isotherm the width of the peak or some other feature reveals important information.
#
# 1. Shape
#
#   This is the default score used when fitting an isotherm. It looks at the shape, position, and height of the peak. It has a small initial penalty for the peak being out of position in time and increases as the peak gets further away. This is to deal with the problem of pump delays and other experimental errors. The best fit may not be and often is not the peak that is in exactly the right location but it is the one with the right shape. The shape is determined by the physics which is why it is so heavily emphasied in the score system.
#
# 2. ShapeDecay
#
#   This is the default score to use when fitting transport parameters. Transport experiments are more difficult because you MUST make sure that as few errors as possible happened in the physical experiment. On most AKTA type systems if there is an alarm the timer for data collection is also paused until the alarm is cleared and the system resumes. This results in data that has no gap in the time. However, the chemicals are still reacting and moving even if the pumps are off and data collection stops. Any such error that occurs will result in the diffusion being wrong and the longer the error persists before being fixed the more wrong the estimate for diffusion will be. Things like pump delays or other pauses in the system can cause problems with estimating volume or porosity. Any errors that occur in transport experiments will be carried through to isotherm parameters which harms scaleup later.
#
# 3. DextranShape
#
#   Dextran is a nice tracer overall but it has no ideal behavior in most systems. You normally see this in strange tailing behavior. What this means is that only the front side of the peak can be used. This score specifically looks only at the front side of the peak.
#
# 4. fractionationSlide
#
#   If you have a fractionation proble use this score. Internally it is a little complex. After each simulation for each species it numerically slides the chromatogram back and forward in time and refactionates at each time to find which location best matches the experimental data to find the time difference between the synthetic and experimental peak along with a shape comparison at that time.
#
# 5. SSE
#
#   This is the Sum of Squared Errors. This score can not be combined with any of the other scores since it does not range from 0 to 1.
#
# 6. AbsoluteHeight and AbsoluteTime
#
#   These scores are needed by the MCMC system. They are absolute measurements of height and time since the beginning of the simulation. They are used to capture the impact of errors that have an assymetric impact on the peaks.

# %%
experiment1 = Dict()
experiment1.CSV = "example.csv"
experiment1.isotherm = "/output/solution/unit_001/SOLUTION_OUTLET_COMP_000"
experiment1.HDF5 = "example.h5"
experiment1.name = "main"
experiment1.timeout = 30.0

feature1 = Dict()
feature1.name = "Pulse"
feature1.type = 'DextranShape'

experiment1.features = [feature1,]

match.experiments = [experiment1,]

match_file = lesson_4 / 'example_nsga3.json'

with (match_file).open('w') as json_file:
    json.dump(match.to_dict(), json_file, indent='\t')

# %% [markdown]
# ## Create match using jupyter interface
# This creates a simple Match object to use for parameter estimation. This is useful when running a match from inside Jupyter notebook. Most of the time this is only done for small matches or when you are running a jupyter notebook on a more powerful server. All of the same results are generated as when the matching software is run directly on the command line and the full results can still be viewed. The jupyter notebook interface just shows a few highlights.

# %%
sim = Match((lesson_4 / 'example_nsga3.json').as_posix())

# %% [markdown]
# ## Start parameter estimation
# Once the Match object has been created all that you need to use is call .start_sim() and the output will be written to the notebook as the matching process runs.
#
# The first few lines tell you what version of python is being used and how many workers are being used. After that the system provides some output at the end of each generation.
#
# > [2019-09-27 12:29:34,593] util      (b'127.0.0.1:61306') INFO    Generation: 0 	Population: 24 	Average Score: 0.968 	Best: 0.981 	Minimum Score: 0.942 	Best: 0.973 	Product Score: 0.967 	Best: 0.981
#
# The above line gives information for when the line was created, what generation the system is on, how long the population is and score information. For most scores the best value is 1.0. The Average, Minimum and Products scores are the values based on the entire population while the Best versions are the scores for only the items on the pareto front. When first starting out the normal scores are usually much lower then the best scores and as the system converges they also tend to get closer.

# %%
resultDir = Path(match.baseDir) / match.resultsDir
print("Your results are located at", resultDir.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDir)

sim.start_sim()
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_nsga3
#
#
# [2019-09-27 17:23:37,489] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-27 17:23:37,489] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-09-27 17:23:37,489] launcher  INFO    Worker distribution:
#
# [2019-09-27 17:23:37,489] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-09-27 17:23:42,328] util      (b'127.0.0.1:52863') INFO    Generation: -1 	Population: 24 	Average Score: 0.976 	Best: 0.984 	Minimum Score: 0.961 	Best: 0.981 	Product Score: 0.976 	Best: 0.984
#
# [2019-09-27 17:23:43,323] util      (b'127.0.0.1:52863') INFO    Generation: 0 	Population: 24 	Average Score: 0.931 	Best: 0.987 	Minimum Score: 0.866 	Best: 0.983 	Product Score: 0.926 	Best: 0.987
#
# [2019-09-27 17:23:44,317] util      (b'127.0.0.1:52863') INFO    Generation: 1 	Population: 24 	Average Score: 0.934 	Best: 0.996 	Minimum Score: 0.869 	Best: 0.995 	Product Score: 0.928 	Best: 0.996
#
# [2019-09-27 17:23:45,315] util      (b'127.0.0.1:52863') INFO    Generation: 2 	Population: 24 	Average Score: 0.935 	Best: 0.996 	Minimum Score: 0.871 	Best: 0.995 	Product Score: 0.929 	Best: 0.996
#
# [2019-09-27 17:23:46,317] util      (b'127.0.0.1:52863') INFO    Generation: 3 	Population: 24 	Average Score: 0.95 	Best: 0.996 	Minimum Score: 0.901 	Best: 0.995 	Product Score: 0.946 	Best: 0.996
#
# [2019-09-27 17:23:47,372] util      (b'127.0.0.1:52863') INFO    Generation: 4 	Population: 24 	Average Score: 0.955 	Best: 0.996 	Minimum Score: 0.912 	Best: 0.995 	Product Score: 0.952 	Best: 0.996
#
# [2019-09-27 17:23:48,500] util      (b'127.0.0.1:52863') INFO    Generation: 5 	Population: 24 	Average Score: 0.986 	Best: 0.996 	Minimum Score: 0.973 	Best: 0.995 	Product Score: 0.985 	Best: 0.996
#
# [2019-09-27 17:23:49,465] util      (b'127.0.0.1:52863') INFO    Generation: 6 	Population: 24 	Average Score: 0.987 	Best: 0.996 	Minimum Score: 0.976 	Best: 0.995 	Product Score: 0.987 	Best: 0.996
#
# [2019-09-27 17:23:50,508] util      (b'127.0.0.1:52863') INFO    Generation: 7 	Population: 24 	Average Score: 0.988 	Best: 0.996 	Minimum Score: 0.978 	Best: 0.995 	Product Score: 0.988 	Best: 0.996
#
# [2019-09-27 17:23:51,500] util      (b'127.0.0.1:52863') INFO    Generation: 8 	Population: 24 	Average Score: 0.995 	Best: 0.997 	Minimum Score: 0.99 	Best: 0.997 	Product Score: 0.994 	Best: 0.997
#
# [2019-09-27 17:23:52,512] util      (b'127.0.0.1:52863') INFO    Generation: 9 	Population: 24 	Average Score: 0.997 	Best: 0.997 	Minimum Score: 0.995 	Best: 0.997 	Product Score: 0.997 	Best: 0.997
#
# [2019-09-27 17:23:53,446] util      (b'127.0.0.1:52863') INFO    Generation: 10 	Population: 24 	Average Score: 0.997 	Best: 0.997 	Minimum Score: 0.995 	Best: 0.997 	Product Score: 0.997 	Best: 0.997
#
# [2019-09-27 17:23:54,364] util      (b'127.0.0.1:52863') INFO    Generation: 11 	Population: 24 	Average Score: 0.997 	Best: 0.997 	Minimum Score: 0.995 	Best: 0.997 	Product Score: 0.997 	Best: 0.997
#
# [2019-09-27 17:23:55,443] util      (b'127.0.0.1:52863') INFO    Generation: 12 	Population: 24 	Average Score: 0.997 	Best: 0.998 	Minimum Score: 0.996 	Best: 0.997 	Product Score: 0.997 	Best: 0.998
#
# [2019-09-27 17:23:56,408] util      (b'127.0.0.1:52863') INFO    Generation: 13 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-27 17:23:57,388] util      (b'127.0.0.1:52863') INFO    Generation: 14 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-27 17:23:58,288] util      (b'127.0.0.1:52863') INFO    Generation: 15 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-27 17:23:59,357] util      (b'127.0.0.1:52863') INFO    Generation: 16 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-27 17:24:00,201] util      (b'127.0.0.1:52863') INFO    Generation: 17 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-27 17:24:01,081] util      (b'127.0.0.1:52863') INFO    Generation: 18 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-27 17:24:01,949] util      (b'127.0.0.1:52863') INFO    Generation: 19 	Population: 24 	Average Score: 0.996 	Best: 1 	Minimum Score: 0.991 	Best: 1 	Product Score: 0.996 	Best: 1
#
# [2019-09-27 17:24:02,863] util      (b'127.0.0.1:52863') INFO    Generation: 20 	Population: 24 	Average Score: 0.996 	Best: 1 	Minimum Score: 0.991 	Best: 1 	Product Score: 0.996 	Best: 1
#
# [2019-09-27 17:24:03,803] util      (b'127.0.0.1:52863') INFO    Generation: 21 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-27 17:24:04,716] util      (b'127.0.0.1:52863') INFO    Generation: 22 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-27 17:24:05,623] util      (b'127.0.0.1:52863') INFO    Generation: 23 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-27 17:24:10,191] util      (b'127.0.0.1:52863') INFO    Generation: 24 	Population: 1 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-27 17:24:14,007] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-27 17:24:14,007] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-09-27 17:24:14,008] launcher  INFO    Worker distribution:
#
# [2019-09-27 17:24:14,008] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-09-27 17:24:15,987] generate_corner_graphs (b'127.0.0.1:55224') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-09-27 17:24:15,987] generate_corner_graphs (b'127.0.0.1:55224') INFO    plotting corner plots
#
# [2019-09-27 17:24:15,991] generate_corner_graphs (b'127.0.0.1:55224') INFO    graphing remove 0 points
#
# [2019-09-27 17:24:28,766] launcher  (127.0.0.1:51584) INFO    Root process is done.
#
# [2019-09-27 17:24:28,767] launcher  (127.0.0.1:51584) INFO    Finished cleaning spawned subprocesses.
#
# [2019-09-27 17:24:28,783] match     (b'127.0.0.1:52863') INFO    altFeatures False
#
# [2019-09-27 17:24:28,783] match     (b'127.0.0.1:52863') INFO    altFeatureNames []
#
# [2019-09-27 17:24:28,783] match     (b'127.0.0.1:52863') INFO    Sysem has finished
#
# [2019-09-27 17:24:28,783] match     (b'127.0.0.1:52863') INFO    The total runtime was 48.209673166275024 seconds
#
# [2019-09-27 17:24:29,506] launcher  (127.0.0.1:51261) INFO    Root process is done.
#
# [2019-09-27 17:24:29,507] launcher  (127.0.0.1:51261) INFO    Finished cleaning spawned subprocesses.

# %% [markdown]
# ## Parameter estimation from the command line
# Most of the time paramter estimation is run from the command line. This makes it easy to run it on a remote computer and restart if something goes wrong. You can also run this under the control of a batch system and is how the software is typically used. Complex parameter estimation with multiple experiments and many variables can take a week or more to run to completion. The matching software peridically writes out graphs and other information as it runs. If you notice that the answer is good enough you can end matching early. I have seen systems get 99% of the final answer within a day and spend another week refining it with minor improvements. There is no absolute rule for this.
#
# For almost all cases what you want to run is
#
# > python -m CADETMatch --match -j /path/to/file.json
#
# It is possible that you will need to change python to python3 depending on your system
#
# If you want to force the system to generate graphs for all the simulations it has so far immediately you can run
#
# > python -m CADETMatch --generate_graphs -j /path/to/file.json
#
# If you have not passed the first generation some graphs won't be generated since the data won't be available yet.
#
# If you run this version from inside a jupyter notebook by use ! to run an external program the output won't show up until the whole estimation finishes. If you are going to run this from inside a jupyter notebok use the jupyter interface covered above. This is here as an example to show how to run the software from the command line.

# %%
#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDir)

json_path = (lesson_4 / 'example_nsga3.json').as_posix()

command = 'python -m CADETMatch --match -j "%s"' % json_path

print(command)

# !{command}
# Out:
# python -m CADETMatch --match -j "F:/temp/cadet_tutorial/lesson_4/example_nsga3.json"
# [2019-09-27 17:24:31,433] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
# [2019-09-27 17:24:31,433] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
# [2019-09-27 17:24:31,433] launcher  INFO    Worker distribution:
# [2019-09-27 17:24:31,433] launcher  INFO       127.0.0.1:	11 + origin
# [2019-09-27 17:24:36,224] util      (b'127.0.0.1:57287') INFO    Generation: -1 	Population: 24 	Average Score: 0.898 	Best: 0.985 	Minimum Score: 0.8 	Best: 0.977 	Product Score: 0.888 	Best: 0.985
# [2019-09-27 17:24:37,213] util      (b'127.0.0.1:57287') INFO    Generation: 0 	Population: 24 	Average Score: 0.921 	Best: 0.992 	Minimum Score: 0.845 	Best: 0.99 	Product Score: 0.914 	Best: 0.992
# [2019-09-27 17:24:38,149] util      (b'127.0.0.1:57287') INFO    Generation: 1 	Population: 24 	Average Score: 0.927 	Best: 0.995 	Minimum Score: 0.857 	Best: 0.994 	Product Score: 0.922 	Best: 0.995
# [2019-09-27 17:24:39,084] util      (b'127.0.0.1:57287') INFO    Generation: 2 	Population: 24 	Average Score: 0.936 	Best: 0.995 	Minimum Score: 0.873 	Best: 0.994 	Product Score: 0.932 	Best: 0.995
# [2019-09-27 17:24:40,027] util      (b'127.0.0.1:57287') INFO    Generation: 3 	Population: 24 	Average Score: 0.926 	Best: 0.995 	Minimum Score: 0.854 	Best: 0.994 	Product Score: 0.921 	Best: 0.995
# [2019-09-27 17:24:40,981] util      (b'127.0.0.1:57287') INFO    Generation: 4 	Population: 24 	Average Score: 0.926 	Best: 0.997 	Minimum Score: 0.854 	Best: 0.994 	Product Score: 0.922 	Best: 0.997
# [2019-09-27 17:24:41,905] util      (b'127.0.0.1:57287') INFO    Generation: 5 	Population: 24 	Average Score: 0.936 	Best: 0.997 	Minimum Score: 0.873 	Best: 0.994 	Product Score: 0.932 	Best: 0.997
# [2019-09-27 17:24:42,829] util      (b'127.0.0.1:57287') INFO    Generation: 6 	Population: 24 	Average Score: 0.988 	Best: 0.997 	Minimum Score: 0.978 	Best: 0.994 	Product Score: 0.988 	Best: 0.997
# [2019-09-27 17:24:43,728] util      (b'127.0.0.1:57287') INFO    Generation: 7 	Population: 24 	Average Score: 0.99 	Best: 0.997 	Minimum Score: 0.981 	Best: 0.994 	Product Score: 0.99 	Best: 0.997
# [2019-09-27 17:24:44,644] util      (b'127.0.0.1:57287') INFO    Generation: 8 	Population: 24 	Average Score: 0.989 	Best: 0.998 	Minimum Score: 0.979 	Best: 0.997 	Product Score: 0.989 	Best: 0.998
# [2019-09-27 17:24:45,579] util      (b'127.0.0.1:57287') INFO    Generation: 9 	Population: 24 	Average Score: 0.989 	Best: 0.998 	Minimum Score: 0.979 	Best: 0.997 	Product Score: 0.989 	Best: 0.998
# [2019-09-27 17:24:46,439] util      (b'127.0.0.1:57287') INFO    Generation: 10 	Population: 24 	Average Score: 0.989 	Best: 0.998 	Minimum Score: 0.979 	Best: 0.997 	Product Score: 0.989 	Best: 0.998
# [2019-09-27 17:24:47,307] util      (b'127.0.0.1:57287') INFO    Generation: 11 	Population: 24 	Average Score: 0.989 	Best: 0.998 	Minimum Score: 0.979 	Best: 0.997 	Product Score: 0.989 	Best: 0.998
# [2019-09-27 17:24:48,215] util      (b'127.0.0.1:57287') INFO    Generation: 12 	Population: 24 	Average Score: 0.987 	Best: 0.998 	Minimum Score: 0.974 	Best: 0.997 	Product Score: 0.987 	Best: 0.998
# [2019-09-27 17:24:49,128] util      (b'127.0.0.1:57287') INFO    Generation: 13 	Population: 24 	Average Score: 0.99 	Best: 0.998 	Minimum Score: 0.979 	Best: 0.997 	Product Score: 0.99 	Best: 0.998
# [2019-09-27 17:24:50,041] util      (b'127.0.0.1:57287') INFO    Generation: 14 	Population: 24 	Average Score: 0.992 	Best: 0.998 	Minimum Score: 0.984 	Best: 0.997 	Product Score: 0.992 	Best: 0.998
# [2019-09-27 17:24:51,001] util      (b'127.0.0.1:57287') INFO    Generation: 15 	Population: 24 	Average Score: 0.992 	Best: 0.998 	Minimum Score: 0.985 	Best: 0.997 	Product Score: 0.992 	Best: 0.998
# [2019-09-27 17:24:51,990] util      (b'127.0.0.1:57287') INFO    Generation: 16 	Population: 24 	Average Score: 0.995 	Best: 0.999 	Minimum Score: 0.99 	Best: 0.999 	Product Score: 0.995 	Best: 0.999
# [2019-09-27 17:24:52,928] util      (b'127.0.0.1:57287') INFO    Generation: 17 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.987 	Best: 1 	Product Score: 0.993 	Best: 1
# [2019-09-27 17:24:53,934] util      (b'127.0.0.1:57287') INFO    Generation: 18 	Population: 24 	Average Score: 0.99 	Best: 1 	Minimum Score: 0.98 	Best: 1 	Product Score: 0.99 	Best: 1
# [2019-09-27 17:24:54,804] util      (b'127.0.0.1:57287') INFO    Generation: 19 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.984 	Best: 1 	Product Score: 0.992 	Best: 1
# [2019-09-27 17:24:55,717] util      (b'127.0.0.1:57287') INFO    Generation: 20 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
# [2019-09-27 17:24:56,681] util      (b'127.0.0.1:57287') INFO    Generation: 21 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
# [2019-09-27 17:24:57,554] util      (b'127.0.0.1:57287') INFO    Generation: 22 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
# [2019-09-27 17:24:58,472] util      (b'127.0.0.1:57287') INFO    Generation: 23 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
# [2019-09-27 17:24:59,379] util      (b'127.0.0.1:57287') INFO    Generation: 24 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
# [2019-09-27 17:25:00,287] util      (b'127.0.0.1:57287') INFO    Generation: 25 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
# [2019-09-27 17:25:01,188] util      (b'127.0.0.1:57287') INFO    Generation: 26 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
# [2019-09-27 17:25:02,108] util      (b'127.0.0.1:57287') INFO    Generation: 27 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
# [2019-09-27 17:25:02,996] util      (b'127.0.0.1:57287') INFO    Generation: 28 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.984 	Best: 1 	Product Score: 0.992 	Best: 1
# [2019-09-27 17:25:03,930] util      (b'127.0.0.1:57287') INFO    Generation: 29 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.984 	Best: 1 	Product Score: 0.992 	Best: 1
# [2019-09-27 17:25:04,785] util      (b'127.0.0.1:57287') INFO    Generation: 30 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.984 	Best: 1 	Product Score: 0.992 	Best: 1
# [2019-09-27 17:25:05,649] util      (b'127.0.0.1:57287') INFO    Generation: 31 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.984 	Best: 1 	Product Score: 0.992 	Best: 1
# [2019-09-27 17:25:06,603] util      (b'127.0.0.1:57287') INFO    Generation: 32 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.984 	Best: 1 	Product Score: 0.992 	Best: 1
# [2019-09-27 17:25:07,485] util      (b'127.0.0.1:57287') INFO    Generation: 33 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.984 	Best: 1 	Product Score: 0.992 	Best: 1
# [2019-09-27 17:25:08,328] util      (b'127.0.0.1:57287') INFO    Generation: 34 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.984 	Best: 1 	Product Score: 0.992 	Best: 1
# [2019-09-27 17:25:09,173] util      (b'127.0.0.1:57287') INFO    Generation: 35 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
# [2019-09-27 17:25:10,035] util      (b'127.0.0.1:57287') INFO    Generation: 36 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
# [2019-09-27 17:25:10,967] util      (b'127.0.0.1:57287') INFO    Generation: 37 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
# [2019-09-27 17:25:11,771] util      (b'127.0.0.1:57287') INFO    Generation: 38 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
# [2019-09-27 17:25:12,629] util      (b'127.0.0.1:57287') INFO    Generation: 39 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:13,563] util      (b'127.0.0.1:57287') INFO    Generation: 40 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:14,488] util      (b'127.0.0.1:57287') INFO    Generation: 41 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:15,350] util      (b'127.0.0.1:57287') INFO    Generation: 42 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:16,309] util      (b'127.0.0.1:57287') INFO    Generation: 43 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:17,211] util      (b'127.0.0.1:57287') INFO    Generation: 44 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:18,110] util      (b'127.0.0.1:57287') INFO    Generation: 45 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:19,073] util      (b'127.0.0.1:57287') INFO    Generation: 46 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:20,139] util      (b'127.0.0.1:57287') INFO    Generation: 47 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:21,149] util      (b'127.0.0.1:57287') INFO    Generation: 48 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:22,136] util      (b'127.0.0.1:57287') INFO    Generation: 49 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:23,112] util      (b'127.0.0.1:57287') INFO    Generation: 50 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:24,094] util      (b'127.0.0.1:57287') INFO    Generation: 51 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:25,146] util      (b'127.0.0.1:57287') INFO    Generation: 52 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:26,110] util      (b'127.0.0.1:57287') INFO    Generation: 53 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:27,095] util      (b'127.0.0.1:57287') INFO    Generation: 54 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:28,044] util      (b'127.0.0.1:57287') INFO    Generation: 55 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:29,046] util      (b'127.0.0.1:57287') INFO    Generation: 56 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:29,931] util      (b'127.0.0.1:57287') INFO    Generation: 57 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:30,800] util      (b'127.0.0.1:57287') INFO    Generation: 58 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:31,713] util      (b'127.0.0.1:57287') INFO    Generation: 59 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:32,662] util      (b'127.0.0.1:57287') INFO    Generation: 60 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:33,595] util      (b'127.0.0.1:57287') INFO    Generation: 61 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:34,573] util      (b'127.0.0.1:57287') INFO    Generation: 62 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:42,388] util      (b'127.0.0.1:57287') INFO    Generation: 63 	Population: 5 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-27 17:25:46,315] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
# [2019-09-27 17:25:46,315] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
# [2019-09-27 17:25:46,315] launcher  INFO    Worker distribution:
# [2019-09-27 17:25:46,315] launcher  INFO       127.0.0.1:	0 + origin
# [2019-09-27 17:25:48,485] generate_corner_graphs (b'127.0.0.1:57764') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
# [2019-09-27 17:25:48,485] generate_corner_graphs (b'127.0.0.1:57764') INFO    plotting corner plots
# [2019-09-27 17:25:48,493] generate_corner_graphs (b'127.0.0.1:57764') INFO    graphing remove 0 points
# [2019-09-27 17:26:04,945] launcher  (127.0.0.1:51953) INFO    Root process is done.
# [2019-09-27 17:26:04,945] launcher  (127.0.0.1:51953) INFO    Finished cleaning spawned subprocesses.
# [2019-09-27 17:26:04,961] match     (b'127.0.0.1:57287') INFO    altFeatures False
# [2019-09-27 17:26:04,961] match     (b'127.0.0.1:57287') INFO    altFeatureNames []
# [2019-09-27 17:26:04,962] match     (b'127.0.0.1:57287') INFO    Sysem has finished
# [2019-09-27 17:26:04,962] match     (b'127.0.0.1:57287') INFO    The total runtime was 90.44854521751404 seconds
# [2019-09-27 17:26:05,705] launcher  (127.0.0.1:51615) INFO    Root process is done.
# [2019-09-27 17:26:05,707] launcher  (127.0.0.1:51615) INFO    Finished cleaning spawned subprocesses.

# %% [markdown]
# ## Complete results
# Sorry this next line only works on Windows. On your own system you can use whatever program you use for managing files to open up the result dir and see the same thing.
#
# The system creates a number of sub directories and depending on what settings are in the JSON file some will be empty.
#
# The import ones are
#
# 1. log
#   This contains all the log files from the system. If something goes wrong the information is usually here to find the problem and fix it. This is especialy useful for us to help with a problem.
# 2. meta
#   This contains all the results on the pareto front of meta scores. Your best results will be in this folder. There are simulations, images and results in csv and xlsx format to view.
# 3. progress
#   This folder watches the general progress of the algorithm. In this folder you can see if your variables are identifiable or the progress the search method is making.
# 4. space
#   This folder has plots for what the search space looks like. This is especially useful for debugging. Based on graphs in this folder you can expand or contract the search range for your variables which can improve the fits.
#
# There are also some important items in this folder
# 1. error.csv
#   If any simulation fails it will be recorded here
# 2. json file
#   This is the JSON used to create this simulation. It is a copy of the JSON file you started the matching process with
# 3. progress.csv
#   This file contains some information on algorithm progress. Of special interest are the last two columns that show the last generation where a new item was added to the pareto front of meta scores and how many generations in a row that progress has been made. If enough generations pass without progress the search will terminate.
# 4. result.h5
#   This is an HDF5 file that contains enormous information about the system. It has the entire population, the scores for all items, and other information. With HDFview you can easily view these files and with python you can read any information you want from these files.
# 5. csv file
#   There is one last csv file that is named based on the JSON configuration file and it shows every simulation the system has run along with the scores for that simulation.

# %%
# !explorer {resultDir}

# %% [markdown]
# ## Create corner plots
# These are frequency plots of each variable in your system along with their correlations. What you are looking for is a single peak and this indicates that your variable is identifiable. The peak may be more or less narrow depending on the ranges you gave to the optimizer. If you use an early stopping criteria these plots probably won't be accurate. What is happening is that as the system converges it searches around the best found values to try and find better ones. This means that there are many similar values and so the frequency goes up which shows up as a peak.

# %%
sim.plot_corner()
# Out:
# Corner plot in search space
# Corner plot in original space

# %% [markdown]
# ## Best plots
# This draws a selection of items from the meta folder. It will look in the folder and find the highest Product Root Score, Min Score and Mean Score and the lowest SSE and plot all of those entries. There may still be other items in those folders which are compromises between these scores. The plot will show the ID of the best found item, by what measurements it is the best and what its paramters are.

# %%
sim.plot_best()
# Out:
# Best item b0187cce63e5c8d485ccddcdf3a48724 for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Fri Sep 27 17:25:41 2019  b0187cce63e5c8d485ccddcdf3a48724   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     1.999999e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_Shape  main_Pulse_Time  \
# 0                           0.37               1.0              1.0
#
#    Product Root Score  Min Score  Mean Score           SSE
# 0                 1.0        1.0         1.0  8.329938e-17

# %% [markdown]
# ## Comparing to the correct answer
# After all of the fitting is done the results can be compared to the correct answer when doing synthetic experiments. In this case we can see the error is well under 0.1% for all variables which is very good. That would indicate that if we ran this experiment accurately in real life it could work. If a synthetic experiment can not recover the original value then the real experiment will not find those variables accurately either.

# %%
best ,score, best_score = sim.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 7.1e-05%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 3.2e-06%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 7.1e-05%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 3.2e-06%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 7.1e-05%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 3.2e-06%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 7.1e-05%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 3.2e-06%

# %%
match_grad = match.copy()

match_grad.gradVector = 0
match_grad.resultsDir = 'fit_grad'
match_grad.searchMethod = 'Multistart'


match_file = lesson_4 / 'example_gradient.json'

with (match_file).open('w') as json_file:
    json.dump(match_grad.to_dict(), json_file, indent='\t')
    
sim_grad = Match(match_file.as_posix())

resultDirGrad = Path(match_grad.baseDir) / match_grad.resultsDir
print("Your results are located at", resultDirGrad.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDirGrad)

sim_grad.start_sim()

sim_grad.plot_best()
best ,score, best_score = sim_grad.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim_grad.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_grad
#
#
# [2019-09-27 17:26:06,276] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-27 17:26:06,276] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-09-27 17:26:06,276] launcher  INFO    Worker distribution:
#
# [2019-09-27 17:26:06,276] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-09-27 17:26:10,140] multistart (b'127.0.0.1:53563') INFO    Population [Individual('d', [0.7637381379993905, 0.47309814353866586]), Individual('d', [0.3723632491130192, 0.6332469686554782]), Individual('d', [0.5929738788296601, 0.5414973351032459]), Individual('d', [0.5955052641486219, 0.1480070604702628]), Individual('d', [0.22607013774597173, 0.4383519589026752]), Individual('d', [0.004688064894976085, 0.6266177573645785]), Individual('d', [0.21458585125877871, 0.7379340042287368]), Individual('d', [0.027825535858292616, 0.7327399586218301]), Individual('d', [0.18337173843380183, 0.7999135612275524]), Individual('d', [0.49680059944596866, 0.8467685069280072]), Individual('d', [0.6638778832414235, 0.5044596543381916]), Individual('d', [0.1821856414136761, 0.3089085854584773]), Individual('d', [0.7611791260586966, 0.7578474302404875]), Individual('d', [0.8140322099023457, 0.02115558230422454]), Individual('d', [0.2815024362532219, 0.5079259723811235]), Individual('d', [0.5490097009085486, 0.5323686978003741]), Individual('d', [0.4350086062973394, 0.6277691568441419]), Individual('d', [0.47990754007238157, 0.1883159823258943]), Individual('d', [0.22867644715050583, 0.8665693529267574]), Individual('d', [0.8571912318144995, 0.6820789961307212]), Individual('d', [0.09014849218598064, 0.6160388270183966]), Individual('d', [0.021195635262499124, 0.40294329658770167]), Individual('d', [0.8782235526986549, 0.8699718878473365]), Individual('d', [0.6000205478786189, 0.9768594942066272])]
#
# [2019-09-27 17:27:08,303] multistart (b'127.0.0.1:53563') INFO    gradCheck 0.899999970404041
#
# [2019-09-27 17:27:08,303] multistart (b'127.0.0.1:53563') INFO    newChildren [Individual('d', [0.7655402430866592, 0.4745941812636114]), Individual('d', [0.5422260536164328, 0.41928009652298753]), Individual('d', [0.6156253599430498, 0.5128663094978214]), Individual('d', [0.6022132429099905, 0.14573722133560846]), Individual('d', [0.2233057150759162, 0.43512874879974583]), Individual('d', [0.36308768183780066, 0.5050568031189934]), Individual('d', [0.006256413920817996, 0.3733283166666764]), Individual('d', [0.05498896156768585, 0.504322400759137]), Individual('d', [0.9738173407739195, 0.9707266464511642]), Individual('d', [0.8877164671272055, 0.6068190767844462]), Individual('d', [0.6651431580222622, 0.5023640602582061]), Individual('d', [0.18674181969593504, 0.3079267695288335]), Individual('d', [0.795372619083571, 0.549844954779013]), Individual('d', [0.8265296884378966, 0.019725729115732994]), Individual('d', [0.2858608998250018, 0.5046574631167071]), Individual('d', [0.5690640665183523, 0.5058659009821533]), Individual('d', [0.8074222534031977, 0.5546327396128419]), Individual('d', [0.48701432038123893, 0.18587561872584124]), Individual('d', [0.022609013521484245, 0.3887424445688975]), Individual('d', [0.8233939395330111, 0.564128601462988]), Individual('d', [0.6462882798575205, 0.47262278669805236]), Individual('d', [0.045879674449071435, 0.40030531296962013]), Individual('d', [0.8750710763672214, 0.8711231015180786]), Individual('d', [0.9077185160179891, 0.6351212397999672])]
#
# [2019-09-27 17:27:08,310] util      (b'127.0.0.1:53563') INFO    Generation: -1 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-09-27 17:27:11,901] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-27 17:27:11,901] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-09-27 17:27:11,901] launcher  INFO    Worker distribution:
#
# [2019-09-27 17:27:11,901] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-09-27 17:27:13,825] generate_corner_graphs (b'127.0.0.1:61554') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-09-27 17:27:13,825] generate_corner_graphs (b'127.0.0.1:61554') INFO    plotting corner plots
#
# [2019-09-27 17:27:13,828] generate_corner_graphs (b'127.0.0.1:61554') INFO    graphing remove 0 points
#
# [2019-09-27 17:27:13,869] loggerwriter (b'127.0.0.1:61554') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:27:15,647] loggerwriter (b'127.0.0.1:61554') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:27:17,293] loggerwriter (b'127.0.0.1:61554') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:27:18,888] loggerwriter (b'127.0.0.1:61554') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:27:20,600] loggerwriter (b'127.0.0.1:61554') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:27:22,258] loggerwriter (b'127.0.0.1:61554') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:27:24,439] launcher  (127.0.0.1:52462) INFO    Root process is done.
#
# [2019-09-27 17:27:24,440] launcher  (127.0.0.1:52462) INFO    Finished cleaning spawned subprocesses.
#
# [2019-09-27 17:27:24,456] match     (b'127.0.0.1:53563') INFO    altFeatures False
#
# [2019-09-27 17:27:24,456] match     (b'127.0.0.1:53563') INFO    altFeatureNames []
#
# [2019-09-27 17:27:24,457] match     (b'127.0.0.1:53563') INFO    Sysem has finished
#
# [2019-09-27 17:27:24,457] match     (b'127.0.0.1:53563') INFO    The total runtime was 74.42442321777344 seconds
#
# [2019-09-27 17:27:25,219] launcher  (127.0.0.1:52005) INFO    Root process is done.
#
# [2019-09-27 17:27:25,220] launcher  (127.0.0.1:52005) INFO    Finished cleaning spawned subprocesses.
#
# Best item 6c8ac3fde652e5ba9cc12fa82ae6d1a2 for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Fri Sep 27 17:27:06 2019  6c8ac3fde652e5ba9cc12fa82ae6d1a2   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     1.965965e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_Shape  main_Pulse_Time  \
# 0                       0.369239               1.0              1.0
#
#    Product Root Score  Min Score  Mean Score       SSE
# 0                 1.0        1.0         1.0  0.000016
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.97e-07   error: 1.7%
# COL_POROSITY Comp:-1 Bound:-1 = 3.69e-01   error: 0.21%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.97e-07   error: 1.7%
# COL_POROSITY Comp:-1 Bound:-1 = 3.69e-01   error: 0.21%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.97e-07   error: 1.7%
# COL_POROSITY Comp:-1 Bound:-1 = 3.69e-01   error: 0.21%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 1.97e-07   error: 1.7%
# COL_POROSITY Comp:-1 Bound:-1 = 3.69e-01   error: 0.21%

# %%
match_grad_large = match.copy()

match_grad_large.gradVector = 0
match_grad_large.resultsDir = 'fit_grad_large'
match_grad_large.searchMethod = 'Multistart'
match_grad_large.population = 24
match_grad_large.minPopulation = 24
match_grad_large.maxPopulation = 24


match_file_large = lesson_4 / 'example_gradient_large.json'

with (match_file_large).open('w') as json_file:
    json.dump(match_grad_large.to_dict(), json_file, indent='\t')
    
sim_grad_large = Match(match_file_large.as_posix())

resultDirGradLarge = Path(match_grad_large.baseDir) / match_grad_large.resultsDir
print("Your results are located at", resultDirGrad.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDirGradLarge)

sim_grad_large.start_sim()

sim_grad_large.plot_best()
best ,score, best_score = sim_grad_large.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim_grad_large.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_grad
#
#
# [2019-09-27 17:28:52,676] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-27 17:28:52,676] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-09-27 17:28:52,676] launcher  INFO    Worker distribution:
#
# [2019-09-27 17:28:52,676] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-09-27 17:28:55,891] multistart (b'127.0.0.1:60156') INFO    Population [Individual('d', [0.531207409980647, 0.550863386541911]), Individual('d', [0.7489593893409255, 0.33504782734079697]), Individual('d', [0.27495550422991777, 0.905101121994705]), Individual('d', [0.4769669193530228, 0.016845899610295922]), Individual('d', [0.9422278396026923, 0.11724212587646388]), Individual('d', [0.15875446788223224, 0.6221450999850855]), Individual('d', [0.9127886974484978, 0.14371485642407278]), Individual('d', [0.44115926916553505, 0.19515419016710167]), Individual('d', [0.0504631942560031, 0.10004531333622235]), Individual('d', [0.986059078969023, 0.47792335309071965]), Individual('d', [0.4864530158869639, 0.8764484382246351]), Individual('d', [0.969445942892468, 0.6056137148578851]), Individual('d', [0.0663750988534646, 0.17979122504860312]), Individual('d', [0.8533271180738299, 0.07141340263441542]), Individual('d', [0.08447509305285594, 0.27024753287477465]), Individual('d', [0.8151668105201905, 0.8628889489262794]), Individual('d', [0.5698687522956105, 0.26733011252425254]), Individual('d', [0.5684567418690987, 0.6074710147464409]), Individual('d', [0.015018642889831346, 0.3236120262014426]), Individual('d', [0.5387665875450235, 0.34487798573554007]), Individual('d', [0.18853926185892267, 0.5175041685924723]), Individual('d', [0.772327388800295, 0.3965901535109392]), Individual('d', [0.14289239457116565, 0.24703352450589222]), Individual('d', [0.9679911399878732, 0.8279328274010951]), Individual('d', [0.338078731141785, 0.5942201952492819]), Individual('d', [0.42551022154697127, 0.10601309388830416]), Individual('d', [0.6367043805750883, 0.0516164050857445]), Individual('d', [0.9665736892121578, 0.687895723577808]), Individual('d', [0.8956001671580859, 0.5103417817474455]), Individual('d', [0.0493887788056796, 0.7119120856502108]), Individual('d', [0.8810120867197111, 0.5996675293125242]), Individual('d', [0.22207379948195993, 0.9672170990221319]), Individual('d', [0.022791279987322777, 0.8401430534701753]), Individual('d', [0.26028412804327594, 0.3063877338875248]), Individual('d', [0.37064883782768643, 0.5166778545246935]), Individual('d', [0.8633994167674339, 0.26914022002786053]), Individual('d', [0.8115038781773383, 0.7449001516045372]), Individual('d', [0.7490217018206037, 0.5173596549096746]), Individual('d', [0.9514965178391162, 0.9132034962808527]), Individual('d', [0.44252882033298147, 0.13057478535512845]), Individual('d', [0.10996037925641167, 0.5131016133182942]), Individual('d', [0.34338328936165297, 0.33572475798130696]), Individual('d', [0.03193363818345529, 0.1120841474617067]), Individual('d', [0.9152287469348468, 0.6227429471407904]), Individual('d', [0.0046054111120023, 0.7020009165834856]), Individual('d', [0.30798105961039524, 0.31474329789297883]), Individual('d', [0.6006852830236609, 0.031817987057815356]), Individual('d', [0.4913281926838571, 0.2952455771293184])]
#
# [2019-09-27 17:30:39,341] multistart (b'127.0.0.1:60156') INFO    gradCheck 0.8999999953944947
#
# [2019-09-27 17:30:39,341] multistart (b'127.0.0.1:60156') INFO    newChildren [Individual('d', [0.5837711251764667, 0.5066899364446072]), Individual('d', [0.7505060301760522, 0.33346768924120507]), Individual('d', [0.7844945899731621, 0.41232418435936485]), Individual('d', [0.5193304128766666, 0.016225598779730104]), Individual('d', [0.8243380205729651, 0.565409984132248]), Individual('d', [0.00035329382572704026, 0.411850402729167]), Individual('d', [0.8580726047548475, 0.15532918201358986]), Individual('d', [0.45113136665490244, 0.1932217617575633]), Individual('d', [0.051588266956968006, 0.09984231949579893]), Individual('d', [0.9387958093320484, 0.6441259236160911]), Individual('d', [0.6193187253000897, 0.32564099385487805]), Individual('d', [0.9282494094319995, 0.6389554773015015]), Individual('d', [0.08469361451022835, 0.1768974311656293]), Individual('d', [0.8546477717108352, 0.07076060461722761]), Individual('d', [0.10115085590364138, 0.2693463293550349]), Individual('d', [0.5109219230596959, 0.5074157681635486]), Individual('d', [0.5731736442515086, 0.2651471867045765]), Individual('d', [0.8243781880861051, 0.5654490069761857]), Individual('d', [0.015384383541530485, 0.32325002936484526]), Individual('d', [0.5416494794056, 0.34171861751769755]), Individual('d', [0.20665777023768128, 0.5044601888253072]), Individual('d', [0.7723271953834688, 0.3965901352839138]), Individual('d', [0.15227985112805, 0.2462607133349184]), Individual('d', [0.9669129505701424, 0.8281541222628825]), Individual('d', [0.2897446816050961, 0.5008199441433878]), Individual('d', [0.4265528044387018, 0.10428746627143531]), Individual('d', [0.6495781761084128, 0.05021701716484781]), Individual('d', [0.9635179020370777, 0.6888888626618473]), Individual('d', [0.8274603409960346, 0.5676878150075864]), Individual('d', [0.11037077427363477, 0.5043539670374712]), Individual('d', [0.8787106715031102, 0.6007303707449015]), Individual('d', [0.9182136829922938, 0.13013158044617723]), Individual('d', [0.01997689820151182, 0.46963792009617944]), Individual('d', [0.28111799751013844, 0.3042188900387732]), Individual('d', [0.38541832675296167, 0.5052388212882112]), Individual('d', [0.9372801387593155, 0.6473176123050305]), Individual('d', [0.822327811055865, 0.5627020002426002]), Individual('d', [0.750858203459859, 0.5149883578095668]), Individual('d', [0.9512779469647878, 0.9132255290800744]), Individual('d', [0.44619016633801395, 0.12785982792971926]), Individual('d', [0.11574848015863844, 0.5043539306540129]), Individual('d', [0.3447016732381081, 0.3352740825954619]), Individual('d', [0.06225001411480563, 0.11140376682700755]), Individual('d', [0.9148565213941492, 0.6228918320616189]), Individual('d', [0.2713156527031883, 0.48919079687052436]), Individual('d', [0.30044492179328863, 0.3119743982642267]), Individual('d', [0.600690109429849, 0.12237020726873568]), Individual('d', [0.4935844515295764, 0.29419199270936003])]
#
# [2019-09-27 17:30:39,349] util      (b'127.0.0.1:60156') INFO    Generation: -1 	Population: 48 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-09-27 17:30:42,858] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-27 17:30:42,858] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-09-27 17:30:42,859] launcher  INFO    Worker distribution:
#
# [2019-09-27 17:30:42,859] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-09-27 17:30:44,821] generate_corner_graphs (b'127.0.0.1:58376') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-09-27 17:30:44,822] generate_corner_graphs (b'127.0.0.1:58376') INFO    plotting corner plots
#
# [2019-09-27 17:30:44,825] generate_corner_graphs (b'127.0.0.1:58376') INFO    graphing remove 0 points
#
# [2019-09-27 17:30:44,864] loggerwriter (b'127.0.0.1:58376') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:30:46,706] loggerwriter (b'127.0.0.1:58376') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:30:48,455] loggerwriter (b'127.0.0.1:58376') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:30:55,721] launcher  (127.0.0.1:52914) INFO    Root process is done.
#
# [2019-09-27 17:30:55,721] launcher  (127.0.0.1:52914) INFO    Finished cleaning spawned subprocesses.
#
# [2019-09-27 17:30:55,738] match     (b'127.0.0.1:60156') INFO    altFeatures False
#
# [2019-09-27 17:30:55,738] match     (b'127.0.0.1:60156') INFO    altFeatureNames []
#
# [2019-09-27 17:30:55,738] match     (b'127.0.0.1:60156') INFO    Sysem has finished
#
# [2019-09-27 17:30:55,738] match     (b'127.0.0.1:60156') INFO    The total runtime was 119.93732476234436 seconds
# [2019-09-27 17:30:56,507] launcher  (127.0.0.1:52522) INFO    Root process is done.
#
# [2019-09-27 17:30:56,508] launcher  (127.0.0.1:52522) INFO    Finished cleaning spawned subprocesses.
#
# Best item f00682b1c71cf6243e93a83350f3b078 for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Fri Sep 27 17:29:45 2019  f00682b1c71cf6243e93a83350f3b078   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     1.983134e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_Shape  main_Pulse_Time  \
# 0                       0.369623               1.0              1.0
#
#    Product Root Score  Min Score  Mean Score       SSE
# 0                 1.0        1.0         1.0  0.000004
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.98e-07   error: 0.85%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.1%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.98e-07   error: 0.85%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.1%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.98e-07   error: 0.85%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.1%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 1.98e-07   error: 0.85%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.1%

# %%
match_sse = match.copy()

match_sse.resultsDir = 'fit_sse'
match_sse.searchMethod = 'Multistart'
match_sse.experiments[0].features[0].type = 'SSE'


match_file = lesson_4 / 'example_sse.json'

with (match_file).open('w') as json_file:
    json.dump(match_sse.to_dict(), json_file, indent='\t')

sim_sse = Match(match_file.as_posix())

resultDirSSE = Path(match_sse.baseDir) / match_sse.resultsDir
print("Your results are located at", resultDirSSE.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDirSSE)

sim_sse.start_sim()

sim_sse.plot_best()
best ,score, best_score = sim_sse.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim_sse.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_sse
#
#
# [2019-09-27 17:30:56,725] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-27 17:30:56,725] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-09-27 17:30:56,726] launcher  INFO    Worker distribution:
#
# [2019-09-27 17:30:56,726] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-09-27 17:30:59,807] multistart (b'127.0.0.1:60247') INFO    Population [Individual('d', [0.04445516488604295, 0.4955716861833913]), Individual('d', [0.5415835476753663, 0.5464619753084464]), Individual('d', [0.7275446429391773, 0.9433370114755908]), Individual('d', [0.45500848067052024, 0.030499073586506276]), Individual('d', [0.5938752592961888, 0.4516760211797365]), Individual('d', [0.49952136383713264, 0.3418098310962402]), Individual('d', [0.42605502024063746, 0.036548342474684525]), Individual('d', [0.4908970740138189, 0.3639914345764409]), Individual('d', [0.7497538319726567, 0.628855824275493]), Individual('d', [0.5844656491257786, 0.1691157241942448]), Individual('d', [0.8462082541970658, 0.6445006509398827]), Individual('d', [0.36596890397643245, 0.8918636536896878]), Individual('d', [0.3854247105826085, 0.481474878235137]), Individual('d', [0.7239738520599452, 0.17476455255449652]), Individual('d', [0.9820446285025648, 0.4889300938538651]), Individual('d', [0.6087839822055027, 0.3765138834889732]), Individual('d', [0.18652476394799966, 0.7965940262008084]), Individual('d', [0.9392922728598198, 0.7804219187102373]), Individual('d', [0.6576374298951629, 0.3690676132556332]), Individual('d', [0.9267044128929837, 0.9818411025313246]), Individual('d', [0.5938996044066229, 0.7317852692485313]), Individual('d', [0.7229406911007139, 0.48083718379611307]), Individual('d', [0.1747847543427946, 0.08127380711420373]), Individual('d', [0.7534830030428046, 0.23035270809324626])]
#
# [2019-09-27 17:31:00,443] gradFD    (b'127.0.0.1:60247') INFO    removed [0.7275446429391773, 0.9433370114755908] for insufficient overlap in gradient descent
#
# [2019-09-27 17:31:00,443] gradFD    (b'127.0.0.1:60247') INFO    removed [0.45500848067052024, 0.030499073586506276] for insufficient overlap in gradient descent
#
# [2019-09-27 17:31:00,444] gradFD    (b'127.0.0.1:60247') INFO    removed [0.42605502024063746, 0.036548342474684525] for insufficient overlap in gradient descent
#
# [2019-09-27 17:31:00,735] gradFD    (b'127.0.0.1:60247') INFO    removed [0.5844656491257786, 0.1691157241942448] for insufficient overlap in gradient descent
#
# [2019-09-27 17:31:00,735] gradFD    (b'127.0.0.1:60247') INFO    removed [0.36596890397643245, 0.8918636536896878] for insufficient overlap in gradient descent
#
# [2019-09-27 17:31:00,736] gradFD    (b'127.0.0.1:60247') INFO    removed [0.7239738520599452, 0.17476455255449652] for insufficient overlap in gradient descent
#
# [2019-09-27 17:31:00,754] gradFD    (b'127.0.0.1:60247') INFO    removed [0.1747847543427946, 0.08127380711420373] for insufficient overlap in gradient descent
#
# [2019-09-27 17:31:00,754] gradFD    (b'127.0.0.1:60247') INFO    removed [0.7534830030428046, 0.23035270809324626] for insufficient overlap in gradient descent
#
# [2019-09-27 17:31:00,754] gradFD    (b'127.0.0.1:60247') INFO    overlap okay offspring [[0.04445516488604295, 0.4955716861833913], [0.5415835476753663, 0.5464619753084464], [0.5938752592961888, 0.4516760211797365], [0.49952136383713264, 0.3418098310962402], [0.4908970740138189, 0.3639914345764409], [0.7497538319726567, 0.628855824275493], [0.8462082541970658, 0.6445006509398827], [0.3854247105826085, 0.481474878235137], [0.9820446285025648, 0.4889300938538651], [0.6087839822055027, 0.3765138834889732], [0.18652476394799966, 0.7965940262008084], [0.9392922728598198, 0.7804219187102373], [0.6576374298951629, 0.3690676132556332], [0.9267044128929837, 0.9818411025313246], [0.5938996044066229, 0.7317852692485313], [0.7229406911007139, 0.48083718379611307]]
#
# [2019-09-27 17:31:36,686] multistart (b'127.0.0.1:60247') INFO    gradCheck -1.8251098597958938e-16
#
# [2019-09-27 17:31:36,686] multistart (b'127.0.0.1:60247') INFO    newChildren [Individual('d', [0.8252574972573395, 0.5666666667152259]), Individual('d', [0.825257501207029, 0.5666666665995865]), Individual('d', [0.8252575003390418, 0.5666666666249994]), Individual('d', [0.825257495902353, 0.5666666667548983]), Individual('d', [0.8252575014224139, 0.5666666665932811]), Individual('d', [0.8252575007727097, 0.5666666666122973]), Individual('d', [0.8252574951466897, 0.5666666667770123]), Individual('d', [0.8252574961089973, 0.5666666667488465]), Individual('d', [0.8252574969558789, 0.5666666667240537]), Individual('d', [0.8252575008754542, 0.5666666666092991]), Individual('d', [0.8252574961670761, 0.5666666667471537]), Individual('d', [0.8252574950596683, 0.5666666667795641]), Individual('d', [0.8252574958038895, 0.5666666667577717]), Individual('d', [0.8252575012917569, 0.5666666665971055]), Individual('d', [0.8252574974384501, 0.5666666667099202]), Individual('d', [0.8252574957105272, 0.5666666667605035])]
#
# [2019-09-27 17:31:36,697] util      (b'127.0.0.1:60247') INFO    Generation: -1 	Population: 16 	Average Score: -2.03e-16 	Best: -2.03e-16 	Minimum Score: -2.03e-16 	Best: -2.03e-16 	Product Score: -2.03e-16 	Best: -2.03e-16
#
# [2019-09-27 17:31:40,622] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-27 17:31:40,622] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-09-27 17:31:40,622] launcher  INFO    Worker distribution:
#
# [2019-09-27 17:31:40,622] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-09-27 17:31:42,844] generate_corner_graphs (b'127.0.0.1:63332') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-09-27 17:31:42,844] generate_corner_graphs (b'127.0.0.1:63332') INFO    plotting corner plots
#
# [2019-09-27 17:31:42,899] loggerwriter (b'127.0.0.1:63332') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:31:45,117] loggerwriter (b'127.0.0.1:63332') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:31:47,121] loggerwriter (b'127.0.0.1:63332') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:31:49,091] loggerwriter (b'127.0.0.1:63332') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:31:51,136] loggerwriter (b'127.0.0.1:63332') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:31:53,140] loggerwriter (b'127.0.0.1:63332') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:31:55,767] launcher  (127.0.0.1:53408) INFO    Root process is done.
#
# [2019-09-27 17:31:55,768] launcher  (127.0.0.1:53408) INFO    Finished cleaning spawned subprocesses.
#
# [2019-09-27 17:31:55,789] match     (b'127.0.0.1:60247') INFO    altFeatures False
#
# [2019-09-27 17:31:55,789] match     (b'127.0.0.1:60247') INFO    altFeatureNames []
#
# [2019-09-27 17:31:55,789] match     (b'127.0.0.1:60247') INFO    Sysem has finished
#
# [2019-09-27 17:31:55,789] match     (b'127.0.0.1:60247') INFO    The total runtime was 56.072627544403076 seconds
#
# [2019-09-27 17:31:56,662] launcher  (127.0.0.1:52951) INFO    Root process is done.
#
# [2019-09-27 17:31:56,662] launcher  (127.0.0.1:52951) INFO    Finished cleaning spawned subprocesses.
#
# Best item 742aaffba5e85d5b72c33fe508fbd67e for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Fri Sep 27 17:31:25 2019  742aaffba5e85d5b72c33fe508fbd67e   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     2.000000e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_SSE  Product Root Score  \
# 0                           0.37   -2.027900e-16       -2.027900e-16
#
#       Min Score    Mean Score           SSE
# 0 -2.027900e-16 -2.027900e-16  2.027900e-16
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 1.3e-06%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 3.4e-09%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 1.3e-06%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 3.4e-09%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 1.3e-06%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 3.4e-09%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 1.3e-06%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 3.4e-09%

# %%
match_sse_large = match.copy()

match_sse_large.resultsDir = 'fit_sse_large'
match_sse_large.searchMethod = 'Multistart'
match_sse_large.population = 24
match_sse_large.minPopulation = 24
match_sse_large.maxPopulation = 24
match_sse_large.experiments[0].features[0].type = 'SSE'


match_file = lesson_4 / 'example_sse_large.json'

with (match_file).open('w') as json_file:
    json.dump(match_sse_large.to_dict(), json_file, indent='\t')

sim_sse_large = Match(match_file.as_posix())

resultDirSSELarge = Path(match_sse_large.baseDir) / match_sse_large.resultsDir
print("Your results are located at", resultDirSSELarge.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDirSSELarge)

sim_sse_large.start_sim()

sim_sse_large.plot_best()
best ,score, best_score = sim_sse_large.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim_sse_large.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_sse_large
#
#
# [2019-09-27 17:31:56,907] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-27 17:31:56,907] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-09-27 17:31:56,907] launcher  INFO    Worker distribution:
#
# [2019-09-27 17:31:56,907] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-09-27 17:32:00,547] multistart (b'127.0.0.1:52629') INFO    Population [Individual('d', [0.3733529725560898, 0.5557525035740071]), Individual('d', [0.7654906887696997, 0.5083081530243505]), Individual('d', [0.5651008540226106, 0.7948889585552849]), Individual('d', [0.6427612704778699, 0.2526765462975564]), Individual('d', [0.9234042973408059, 0.06457677975553133]), Individual('d', [0.13415199116891363, 0.46695748509173496]), Individual('d', [0.7365151144563287, 0.5403231107128221]), Individual('d', [0.9986308499838009, 0.04119374256078179]), Individual('d', [0.6204534501029918, 0.7889573215634598]), Individual('d', [0.9310231599840136, 0.6042846297550224]), Individual('d', [0.4669398419461436, 0.9513453078287746]), Individual('d', [0.8424915138409668, 0.28098595860988085]), Individual('d', [0.19655954604834025, 0.008690029700677782]), Individual('d', [0.9265089794149931, 0.43503750623167403]), Individual('d', [0.8576618472958307, 0.03402417295520965]), Individual('d', [0.30007422872466905, 0.23620388514130652]), Individual('d', [0.9126592275615099, 0.9091754746357463]), Individual('d', [0.3779124654976216, 0.09831658921318798]), Individual('d', [0.574192890971447, 0.7019105125629438]), Individual('d', [0.5144610703981057, 0.7405552545925406]), Individual('d', [0.18917090635840506, 0.8830118727350144]), Individual('d', [0.5469036822361591, 0.8715621703305554]), Individual('d', [0.7248758794481072, 0.1771343512532101]), Individual('d', [0.6189555829897931, 0.7138337404469055]), Individual('d', [0.04278078797283813, 0.5744793260815768]), Individual('d', [0.8232950695552997, 0.21912576018039875]), Individual('d', [0.30711621140858825, 0.0664158003158094]), Individual('d', [0.8547500262536275, 0.5265704573899335]), Individual('d', [0.4203586030640739, 0.5195181181932709]), Individual('d', [0.675367556444637, 0.23155896668562703]), Individual('d', [0.04992274636005767, 0.09481738385169247]), Individual('d', [0.0992972887316278, 0.5470178582640184]), Individual('d', [0.7782614889395834, 0.8352412102785224]), Individual('d', [0.9674465023931503, 0.864973224816225]), Individual('d', [0.5071897325891777, 0.3117427674467418]), Individual('d', [0.8738294149514053, 0.502274105173246]), Individual('d', [0.8361282796030708, 0.37379521033209206]), Individual('d', [0.31521177789043553, 0.4812240101675246]), Individual('d', [0.6231699838312521, 0.8002954985940236]), Individual('d', [0.7008266115985679, 0.7906449257291818]), Individual('d', [0.6644359498413379, 0.16063199232044278]), Individual('d', [0.05951902534149478, 0.16281451165465688]), Individual('d', [0.7051976147463778, 0.5593810315817271]), Individual('d', [0.012390277198438104, 0.04885171986934511]), Individual('d', [0.012888480272510328, 0.4050652401769238]), Individual('d', [0.741233724989411, 0.2177417808179285]), Individual('d', [0.40741756965599596, 0.7041376896804408]), Individual('d', [0.4541949899424025, 0.6019807116508596])]
#
# [2019-09-27 17:32:01,220] gradFD    (b'127.0.0.1:52629') INFO    removed [0.6427612704778699, 0.2526765462975564] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:01,220] gradFD    (b'127.0.0.1:52629') INFO    removed [0.9234042973408059, 0.06457677975553133] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:01,220] gradFD    (b'127.0.0.1:52629') INFO    removed [0.9986308499838009, 0.04119374256078179] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:01,763] gradFD    (b'127.0.0.1:52629') INFO    removed [0.4669398419461436, 0.9513453078287746] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:01,766] gradFD    (b'127.0.0.1:52629') INFO    removed [0.19655954604834025, 0.008690029700677782] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:01,767] gradFD    (b'127.0.0.1:52629') INFO    removed [0.8576618472958307, 0.03402417295520965] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:01,768] gradFD    (b'127.0.0.1:52629') INFO    removed [0.30007422872466905, 0.23620388514130652] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:01,769] gradFD    (b'127.0.0.1:52629') INFO    removed [0.3779124654976216, 0.09831658921318798] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:01,770] gradFD    (b'127.0.0.1:52629') INFO    removed [0.18917090635840506, 0.8830118727350144] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:01,770] gradFD    (b'127.0.0.1:52629') INFO    removed [0.5469036822361591, 0.8715621703305554] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:01,771] gradFD    (b'127.0.0.1:52629') INFO    removed [0.7248758794481072, 0.1771343512532101] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:02,230] gradFD    (b'127.0.0.1:52629') INFO    removed [0.8232950695552997, 0.21912576018039875] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:02,230] gradFD    (b'127.0.0.1:52629') INFO    removed [0.30711621140858825, 0.0664158003158094] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:02,231] gradFD    (b'127.0.0.1:52629') INFO    removed [0.675367556444637, 0.23155896668562703] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:02,231] gradFD    (b'127.0.0.1:52629') INFO    removed [0.04992274636005767, 0.09481738385169247] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:02,358] gradFD    (b'127.0.0.1:52629') INFO    removed [0.6644359498413379, 0.16063199232044278] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:02,375] gradFD    (b'127.0.0.1:52629') INFO    removed [0.05951902534149478, 0.16281451165465688] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:02,384] gradFD    (b'127.0.0.1:52629') INFO    removed [0.012390277198438104, 0.04885171986934511] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:02,398] gradFD    (b'127.0.0.1:52629') INFO    removed [0.741233724989411, 0.2177417808179285] for insufficient overlap in gradient descent
#
# [2019-09-27 17:32:02,399] gradFD    (b'127.0.0.1:52629') INFO    overlap okay offspring [[0.3733529725560898, 0.5557525035740071], [0.7654906887696997, 0.5083081530243505], [0.5651008540226106, 0.7948889585552849], [0.13415199116891363, 0.46695748509173496], [0.7365151144563287, 0.5403231107128221], [0.6204534501029918, 0.7889573215634598], [0.9310231599840136, 0.6042846297550224], [0.8424915138409668, 0.28098595860988085], [0.9265089794149931, 0.43503750623167403], [0.9126592275615099, 0.9091754746357463], [0.574192890971447, 0.7019105125629438], [0.5144610703981057, 0.7405552545925406], [0.6189555829897931, 0.7138337404469055], [0.04278078797283813, 0.5744793260815768], [0.8547500262536275, 0.5265704573899335], [0.4203586030640739, 0.5195181181932709], [0.0992972887316278, 0.5470178582640184], [0.7782614889395834, 0.8352412102785224], [0.9674465023931503, 0.864973224816225], [0.5071897325891777, 0.3117427674467418], [0.8738294149514053, 0.502274105173246], [0.8361282796030708, 0.37379521033209206], [0.31521177789043553, 0.4812240101675246], [0.6231699838312521, 0.8002954985940236], [0.7008266115985679, 0.7906449257291818], [0.7051976147463778, 0.5593810315817271], [0.012888480272510328, 0.4050652401769238], [0.40741756965599596, 0.7041376896804408], [0.4541949899424025, 0.6019807116508596]]
#
# [2019-09-27 17:33:09,434] multistart (b'127.0.0.1:52629') INFO    gradCheck -1.2533469988970337e-16
#
# [2019-09-27 17:33:09,434] multistart (b'127.0.0.1:52629') INFO    newChildren [Individual('d', [0.8252574953141152, 0.5666666667721116]), Individual('d', [0.8252575003596219, 0.5666666666243967]), Individual('d', [0.8252575005451339, 0.5666666666189679]), Individual('d', [0.8252575006194269, 0.5666666666167812]), Individual('d', [0.8252575022348054, 0.5666666665694962]), Individual('d', [0.8252575013418658, 0.5666666665956357]), Individual('d', [0.8252575005340386, 0.5666666666192983]), Individual('d', [0.8252574969835594, 0.5666666667232519]), Individual('d', [0.8252575029546795, 0.5666666665484121]), Individual('d', [0.8252574977367297, 0.5666666667011935]), Individual('d', [0.8252574969980084, 0.566666666722817]), Individual('d', [0.8252575003741408, 0.5666666666239718]), Individual('d', [0.825257497713986, 0.5666666667018686]), Individual('d', [0.82525750088446, 0.5666666666090202]), Individual('d', [0.8252575006233298, 0.5666666666166751]), Individual('d', [0.8252574976900489, 0.5666666667025604]), Individual('d', [0.8252575008700307, 0.5666666666094604]), Individual('d', [0.8252574970309852, 0.5666666667218497]), Individual('d', [0.8252575020716385, 0.5666666665742616]), Individual('d', [0.8252574976633714, 0.5666666667033501]), Individual('d', [0.8252574960556248, 0.5666666667504102]), Individual('d', [0.8252575024039243, 0.5666666665645388]), Individual('d', [0.8252574976979234, 0.5666666667023347]), Individual('d', [0.825257497631769, 0.566666666704265]), Individual('d', [0.8252574956403264, 0.5666666667625773]), Individual('d', [0.8252574965035988, 0.5666666667372984]), Individual('d', [0.8252575023711121, 0.5666666665655076]), Individual('d', [0.825257497573783, 0.5666666667059705]), Individual('d', [0.8252574969279332, 0.5666666667248755])]
#
# [2019-09-27 17:33:09,443] util      (b'127.0.0.1:52629') INFO    Generation: -1 	Population: 29 	Average Score: -1.39e-16 	Best: -1.39e-16 	Minimum Score: -1.39e-16 	Best: -1.39e-16 	Product Score: -1.39e-16 	Best: -1.39e-16
# [2019-09-27 17:33:12,786] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-27 17:33:12,787] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-09-27 17:33:12,787] launcher  INFO    Worker distribution:
#
# [2019-09-27 17:33:12,787] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-09-27 17:33:14,662] generate_corner_graphs (b'127.0.0.1:62624') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-09-27 17:33:14,663] generate_corner_graphs (b'127.0.0.1:62624') INFO    plotting corner plots
#
# [2019-09-27 17:33:14,706] loggerwriter (b'127.0.0.1:62624') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:33:16,527] loggerwriter (b'127.0.0.1:62624') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:33:18,232] loggerwriter (b'127.0.0.1:62624') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:33:19,867] loggerwriter (b'127.0.0.1:62624') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:33:21,597] loggerwriter (b'127.0.0.1:62624') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:33:23,266] loggerwriter (b'127.0.0.1:62624') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-27 17:33:25,459] launcher  (127.0.0.1:53815) INFO    Root process is done.
#
# [2019-09-27 17:33:25,459] launcher  (127.0.0.1:53815) INFO    Finished cleaning spawned subprocesses.
#
# [2019-09-27 17:33:25,476] match     (b'127.0.0.1:52629') INFO    altFeatures False
#
# [2019-09-27 17:33:25,476] match     (b'127.0.0.1:52629') INFO    altFeatureNames []
#
# [2019-09-27 17:33:25,476] match     (b'127.0.0.1:52629') INFO    Sysem has finished
#
# [2019-09-27 17:33:25,476] match     (b'127.0.0.1:52629') INFO    The total runtime was 85.03598165512085 seconds
#
# [2019-09-27 17:33:26,226] launcher  (127.0.0.1:53438) INFO    Root process is done.
#
# [2019-09-27 17:33:26,228] launcher  (127.0.0.1:53438) INFO    Finished cleaning spawned subprocesses.
#
# Best item 9b4083308676296658e2f47c7f22bed1 for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Fri Sep 27 17:33:05 2019  9b4083308676296658e2f47c7f22bed1   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     2.000000e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_SSE  Product Root Score  \
# 0                           0.37   -1.392608e-16       -1.392608e-16
#
#       Min Score    Mean Score           SSE
# 0 -1.392608e-16 -1.392608e-16  1.392608e-16
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 1.1e-06%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 2.8e-09%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 1.1e-06%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 2.8e-09%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 1.1e-06%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 2.8e-09%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 1.1e-06%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 2.8e-09%
