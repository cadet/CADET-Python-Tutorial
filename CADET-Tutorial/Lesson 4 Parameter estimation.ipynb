# %% [markdown]
# # Lesson 4
#
# Our goal is to match computer simulations to real experiments. Computer simulations are also cheaper to do and can be used to tell us if the real experiment can even answer the question we want to ask. The idea is to build the experiment synthetically first and then try to match against the synthetic data and see if under ideal circumstances if you can identify the parameters of interest. If you can't do it synthetically you can't do it in real life either which has many sources of error. Many times I have seen experiments run which turned out to have no chance of providing the required information because the experiment was run before figuring out what experiment should be run.
#
# ## Purpose
#
# The goal of this section is to learn how to setup, run and analyze a parameter estimation run.
#
# The example used is from Lesson 1 which is a simple Dextran pulse through a column. This lesson will cover the the common variable transforms, scores and search algorithms.
#
# ## Standard imports

# %%
#from IPython.core.display import display, HTML
from IPython.display import display, HTML, clear_output
display(HTML("<style>.container { width:100% !important; }</style>"))

#Python path library support
from pathlib import Path

#python numeric library
import numpy

#python math library
import math

#scientific library for python
import scipy

#pandas is python library for data analysis
import pandas

#addict is a library that makes it easier to create nested dictionaries
from addict import Dict

#json is a standard text based format and it used in CADETMatch for the configuration file
import json

#python plotting library
import matplotlib.pyplot as plt

#cadet python interface
from cadet import Cadet

#jupyter widget support
from ipywidgets import interact
import ipywidgets as widgets

from CADETMatch.jupyter import Match

#This is just a support function to make running the examples a bit easier later
def deleteResultDir(path):
    #This is to try and make sure that only an actual result directory can be removed
    #And only if no other files have been added to the directory, just in case
    if not path.exists():
        return
    allowed = {'evo', 'grad', 'log', 'mcmc', 'meta', 'misc', 'progress', 
               'space', 'error.csv', 'result.h5', 'progress.csv'}
    allowed.add(match.csv)
    allowed.add(match_file.name)
    okayToRemove = False
    for child in path.iterdir():
        if child.name not in allowed:
            break
    else:
        okayToRemove = True
    if okayToRemove:
        import shutil
        shutil.rmtree(path)
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Setup CADET path

# %%
#put in the path to the bin folder
cadet_bin_path = Path(r"C:\Users\kosh_000\cadet_build\CADET\VCPKG\bin")

cadet_path = cadet_bin_path / "cadet-cli.exe"

if cadet_path.exists():
    print("CADET was found. Continue to the next step.")
    Cadet.cadet_path = cadet_path.as_posix()
else:
    print('CADET could not be found. Please check the bin path')
    
print(cadet_path.as_posix())
# Out:
# CADET was found. Continue to the next step.
# C:/Users/kosh_000/cadet_build/CADET/VCPKG/bin/cadet-cli.exe

# %% [markdown]
# ## Find the lesson folders and create the folder for lesson 4

# %%
#set this to a directory on your computer where the cadet tutorial files can be saved
cadet_tutorial = Path('F:/temp/cadet_tutorial')
lesson_1 = cadet_tutorial / "lesson_1"
lesson_2 = cadet_tutorial / "lesson_2"
lesson_3 = cadet_tutorial / "lesson_3"
lesson_4 = cadet_tutorial / "lesson_4"
lesson_4.mkdir(exist_ok = True, parents=True)

# %% [markdown]
# ## Load simple example from Lesson 1
# This code is pretty much the same as what we have looked at before. We open the file from Lesson 1 and then resave it to the Lesson 4 folder. We also run the simulation and save the output of the chromatogram as a CSV file to use in the matching process.

# %%
simple_example = lesson_1 / "simple_example"
simple_example.mkdir(exist_ok = True)

simple = Cadet()

#give a filename for where the simulation should be saved
simple.filename = (simple_example / 'example.h5').as_posix()

simple.load()

simple.filename = (lesson_4 / 'example.h5').as_posix()

#save the simulation
simple.save()

#run the simulation
data = simple.run()

print(data)

if data.returncode == 0:
    print("Simulation completed successfully")
    
    #load the data from the simulation so we can view the results
    simple.load()
    
    #plot the simulation
    plt.figure(figsize=[10,10])
    plt.plot(simple.root.output.solution.solution_times,
        simple.root.output.solution.unit_002.solution_outlet_comp_000)
    
    #write the chromatogram data out to a csv file
    data = pandas.DataFrame([simple.root.output.solution.solution_times,
                        simple.root.output.solution.unit_001.solution_outlet_comp_000]).transpose()
    data.to_csv((lesson_4 / 'example.csv').as_posix(), index=False, header=False)
    
else:
    print("Simulation failed")
# Out:
# CompletedProcess(args=['C:/Users/kosh_000/cadet_build/CADET/VCPKG/bin/cadet-cli.exe', 'F:/temp/cadet_tutorial/lesson_4/example.h5'], returncode=0, stdout=b'', stderr=b'')
# Simulation completed successfully

# %% [markdown]
# ## Create CADETMatch configuration
#
# ### Search Method
# There are 4 main search methods and only 3 of them are directly used.
# 1. NSGA3
#   This is the default evolutionary algorithm and the best choice to use when you don't know anything about your search space.
# 2. Multistart
#   This is a multistart gradient descent algorithm. If your problem can be solved with gradient descent then this can be a very good choice. It creates an initial population the same way that NSGA3 does so that you don't have to worry about starting point.
# 3. GraphSpace
#   This is not for optimization and instead it is just for sampling the space. If you have a new problem and you have no idea what the range of any of the parameters are you can use this with a very large population and it will just evaluate the entire starting population and then terminate. This allows you to figure out what are plausiable ranges for your variables before using one of the search algorithms. When dealing with many variables it is still possible to miss regions of viable solutions inside large non-viable regions but in practice this has rarely been a problem.
# 4. MCMC
#   This performans the error modeling and sampling. It is not an optimization algorithm and while it will probably find the optimum value while it runs it is very slow to do so and won't stop even if it finds the optimal value. This should also not be used directly. Normally NSGA3 is used and an option is set to continue with MCMC after NSGA3 has completed. This allows MCMC to be seeded with the best values from NSGA3 which dramatically improves convergence. If you have many variables and you run this directly it may never converge since it may never find high probability regions, much less sample from them effectively.

# %%
match = Dict()
match.CADETPath = cadet_path.as_posix()
match.baseDir = lesson_4.as_posix()
match.resultsDir = 'fit_nsga3'
match.csv = 'fit_results.csv'
match.checkpointFile = "check"
match.stopAverage = 1
match.stopBest = 1
match.gradCheck = 1
match.gradVector = 1
match.searchMethod = 'NSGA3'
match.mutationRate = 1.0
match.crossoverRate = 1.0
match.generations = 1000
match.population = 12
match.minPopulation = 12
match.maxPopulation = 12
match.finalGradRefinement = 1
match.stallGenerations = 10

# %% [markdown]
# ### Variable transforms
# Search algorithms don't work well when the parameters have very different ranges. For example if one parmeter varies from 1e-5 to 1e-10 and the other varies from 1-10. Another problem is when parameters are tightly coupled together but presented to the optimizer as indepdent variables. This is true with kA and kD for the adsorption and desorption rates. The parameters kA and kD are coupled together but given as two different variables while they do not freely vary from each other. To solve this problem variable transforms are available. I will cover the most common and useful transformations. There are some other variable transforms available that you can see at https://github.com/modsim/CADET-Match/tree/master/CADETMatch/transform
#
# 1. norm
#
#   This is a simple transform that normalizes a variable from 0 to 1. This is best used when you have a variable that varies over less then 3 orders of magnitude.
#
#   ```json
# {
#       "transform": "norm",
#       "component": -1,
#       "bound": -1,
#       "location": "/input/model/unit_001/COL_POROSITY",
#       "min": 0.2,
#       "max": 0.5
#     }
# ```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm'
# parameter.component = -1
# parameter.bound = -1
# parameter.location = "/input/model/unit_001/COL_POROSITY"
# parameter.min = 0.2
# parameter.max = 0.5
# ```
#
# 2. norm_log
#
#   This transform takes the log before normalizing the variable from 0 to 1. Use this transform when your variable spans more than 3 orders of magnitude.
#
#     ```json
# {
#       "transform": "norm_log",
#       "component": -1,
#       "bound": -1,
#       "location": "/input/model/unit_001/COL_DISPERSION",
#       "min": 1e-12,
#       "max": 1e-5
#     }
# ```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_log'
# parameter.component = -1
# parameter.bound = -1
# parameter.location = "/input/model/unit_001/COL_DISPERSION"
# parameter.min = 1e-12
# parameter.max = 1e-5
# ```
#
# 3. norm_keq
#
#    This transform turns ka, kd in ka and keq=ka/kd and then takes a log transform and normalizes from 0 to 1.
#
#    ```json
# {
#     "transform": "norm_keq",
#     "component": 0,
#     "bound": 0,
#     "location": [
#         "/input/model/unit_001/adsorption/LIN_KA",
#         "/input/model/unit_001/adsorption/LIN_KD"
#     ],
#     "minKA": 1e-8,
#     "maxKA": 1e8,
#     "minKEQ": 1e-4,
#     "maxKEQ": 1e4
# }
# ```
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_keq'
# parameter.component = 0
# parameter.bound = 0
# parameter.location = ["/input/model/unit_001/adsorption/LIN_KA",
#                       "/input/model/unit_001/adsorption/LIN_KD"]
# parameter.minKA = 1e-8
# parameter.maxKA = 1e8
# parameter.minKEQ = 1e-4
# parameter.maxKEQ = 1e4
# ```
#
#
# 4. norm_volume_area
#
#     This transform and the following one where created to solve the same common problem. When fitting bypass data and you model the tubing you are fitting the length, crosssectional area and dispersion of the tubing. Dispersion though is tied to the length such that a shorter length can just be compensated for with a higher diffusion. Basically we have fewer degrees of freedom that we are fitting with and since this is not a fluid dynamics model it is not physically accurate. This transformation couples the length and area together through the volume since volume is an identfiable quantity (since water is incompressible). We don't actually care much about the parameters for the tubing, it is just there to fill in for the real tubing so that fewer errors are carried into the column. Use this version if it is easier to measure the diameter of the tubing and use the other transform if measuring the length is easier. I just depends on your experimental setup.
#
#
#
# ```json
# {
#   "transform": "norm_volume_area",
#   "area_location": "/input/model/unit_003/COL_DISPERSION",
#   "length_location": "/input/model/unit_004/COL_DISPERSION",
#   "component": -1,
#   "bound": -1,
#   "minVolume":1e-6,
#   "maxVolume":1e-5,
#   "minArea":1e-4,
#   "maxArea":1e-3
# }```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_volume_area'
# parameter.area_location = "/input/model/unit_003/COL_DISPERSION"
# parameter.length_location = "/input/model/unit_004/COL_DISPERSION"
# parameter.component = -1
# parameter.bound = -1
# parameter.minVolume = 1e-6
# parameter.maxVolume = 1e-5
# parameter.minArea = 1e-4
# parameter.maxArea = 1e-3
# ```
#
#
# 5. norm_volume_length
#
#     Use this transform if measuring the length accurately is easier than measuring the diameter of the tubing. If you are lumping together all the tubing in front of the column or after the column together and you have multiple diameters it doesn't matter which of these transforms you choose.
#
# ```json
# {
#   "transform": "norm_volume_length",
#   "area_location": "/input/model/unit_003/COL_DISPERSION",
#   "length_location": "/input/model/unit_004/COL_DISPERSION",
#   "component": -1,
#   "bound": -1,
#   "minVolume":1e-6,
#   "maxVolume":1e-5,
#   "minLength":0.25,
#   "maxLength":0.75
# }```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_volume_area'
# parameter.area_location = "/input/model/unit_003/COL_DISPERSION"
# parameter.length_location = "/input/model/unit_004/COL_DISPERSION"
# parameter.component = -1
# parameter.bound = -1
# parameter.minVolume = 1e-6
# parameter.maxVolume = 1e-5
# parameter.minLength = 0.25
# parameter.maxLength = 0.75
# ```
#
#
# 6. set_value
#
#     This is a different kind of transform. What it allows you to do is copy a value from place to another. This is important if you are estimating axial dispersion for identical tubing in front of and behind the column. You want the same axial dispersion for both pieces of tubing but you only want to estimate one variable. With this you can estimate axial dispersion for the first piece of tubing and then copy the value over to the other piece of tubing. This is also required if you want to estimate SMA_LAMDA. Whenever SMA_LAMBDA change the initial bound salt concentration also much change or electronuetrality would be violated.
#
# ```json
# {
#   "transform": "set_value",
#   "componentFrom": -1,
#   "boundFrom": -1,
#   "locationFrom": "/input/model/unit_003/COL_DISPERSION",
#   "componentTo": -1,
#   "boundTo": -1,
#   "locationTo": "/input/model/unit_004/COL_DISPERSION"
# }```
#
# ```python
# parameter = Dict()
# parameter.transform = 'set_value'
# parameter.componentFrom = -1
# parameter.boundFrom = -1
# parameter.locationFrom = "/input/model/unit_001/COL_DISPERSION"
# parameter.componentTo = -1
# parameter.boundTo = -1
# parameter.locationTo = "/input/model/unit_001/COL_DISPERSION"
# ```

# %%
parameter1 = Dict()
parameter1.transform = 'norm_log'
parameter1.component = -1
parameter1.bound = -1
parameter1.location = "/input/model/unit_001/COL_DISPERSION"
parameter1.min = 1e-10
parameter1.max = 1e-6

parameter2 = Dict()
parameter2.transform = 'norm'
parameter2.component = -1
parameter2.bound = -1
parameter2.location = "/input/model/unit_001/COL_POROSITY"
parameter2.min = 0.2
parameter2.max = 0.5

match.parameters = [parameter1, parameter2]

# %% [markdown]
# ### Scores
#
# Scores are how the search algorithm measures if a solution is better or worse than what it had before. Without a good score system an optimizer can't work. There are many scores available and I am going to cover the most commonly used ones and when you should use them. You can see all of them at https://github.com/modsim/CADET-Match/tree/master/CADETMatch/scores . Most of these scores are based on physical understanding of the problem and it is pretty easy to add new scores. If there is a feature you can identify in your problem that ties to one of the variables being estimated then go ahead and make a score for it. Maybe for your isotherm the width of the peak or some other feature reveals important information.
#
# 1. Shape
#
#   This is the default score used when fitting an isotherm. It looks at the shape, position, and height of the peak. It has a small initial penalty for the peak being out of position in time and increases as the peak gets further away. This is to deal with the problem of pump delays and other experimental errors. The best fit may not be and often is not the peak that is in exactly the right location but it is the one with the right shape. The shape is determined by the physics which is why it is so heavily emphasied in the score system.
#
# 2. ShapeDecay
#
#   This is the default score to use when fitting transport parameters. Transport experiments are more difficult because you MUST make sure that as few errors as possible happened in the physical experiment. On most AKTA type systems if there is an alarm the timer for data collection is also paused until the alarm is cleared and the system resumes. This results in data that has no gap in the time. However, the chemicals are still reacting and moving even if the pumps are off and data collection stops. Any such error that occurs will result in the diffusion being wrong and the longer the error persists before being fixed the more wrong the estimate for diffusion will be. Things like pump delays or other pauses in the system can cause problems with estimating volume or porosity. Any errors that occur in transport experiments will be carried through to isotherm parameters which harms scaleup later.
#
# 3. DextranShape
#
#   Dextran is a nice tracer overall but it has no ideal behavior in most systems. You normally see this in strange tailing behavior. What this means is that only the front side of the peak can be used. This score specifically looks only at the front side of the peak.
#
# 4. fractionationSlide
#
#   If you have a fractionation proble use this score. Internally it is a little complex. After each simulation for each species it numerically slides the chromatogram back and forward in time and refactionates at each time to find which location best matches the experimental data to find the time difference between the synthetic and experimental peak along with a shape comparison at that time.
#
# 5. SSE
#
#   This is the Sum of Squared Errors. This score can not be combined with any of the other scores since it does not range from 0 to 1.
#
# 6. AbsoluteHeight and AbsoluteTime
#
#   These scores are needed by the MCMC system. They are absolute measurements of height and time since the beginning of the simulation. They are used to capture the impact of errors that have an assymetric impact on the peaks.

# %%
experiment1 = Dict()
experiment1.csv = "example.csv"
experiment1.isotherm = "/output/solution/unit_001/SOLUTION_OUTLET_COMP_000"
experiment1.HDF5 = "example.h5"
experiment1.name = "main"
experiment1.timeout = 30.0

feature1 = Dict()
feature1.name = "Pulse"
feature1.type = 'DextranShape'

experiment1.features = [feature1,]

match.experiments = [experiment1,]

match_file = lesson_4 / 'example_nsga3.json'

with (match_file).open('w') as json_file:
    json.dump(match.to_dict(), json_file, indent='\t')

# %% [markdown]
# ## Create match using jupyter interface
# This creates a simple Match object to use for parameter estimation. This is useful when running a match from inside Jupyter notebook. Most of the time this is only done for small matches or when you are running a jupyter notebook on a more powerful server. All of the same results are generated as when the matching software is run directly on the command line and the full results can still be viewed. The jupyter notebook interface just shows a few highlights.

# %%
sim = Match((lesson_4 / 'example_nsga3.json').as_posix())

# %% [markdown]
# ## Start parameter estimation
# Once the Match object has been created all that you need to use is call .start_sim() and the output will be written to the notebook as the matching process runs.
#
# The first few lines tell you what version of python is being used and how many workers are being used. After that the system provides some output at the end of each generation.
#
# > [2019-09-27 12:29:34,593] util      (b'127.0.0.1:61306') INFO    Generation: 0 	Population: 24 	Average Score: 0.968 	Best: 0.981 	Minimum Score: 0.942 	Best: 0.973 	Product Score: 0.967 	Best: 0.981
#
# The above line gives information for when the line was created, what generation the system is on, how long the population is and score information. For most scores the best value is 1.0. The Average, Minimum and Products scores are the values based on the entire population while the Best versions are the scores for only the items on the pareto front. When first starting out the normal scores are usually much lower then the best scores and as the system converges they also tend to get closer.

# %%
resultDir = Path(match.baseDir) / match.resultsDir
print("Your results are located at", resultDir.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDir)

sim.start_sim()
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_nsga3
#
#
# [2019-10-01 09:28:01,652] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-01 09:28:01,652] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-10-01 09:28:01,652] launcher  INFO    Worker distribution:
#
# [2019-10-01 09:28:01,652] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-10-01 09:28:07,351] util      (b'127.0.0.1:49841') INFO    Generation: -1 	Population: 24 	Average Score: 0.988 	Best: 0.993 	Minimum Score: 0.98 	Best: 0.992 	Product Score: 0.988 	Best: 0.993
#
# [2019-10-01 09:28:08,237] util      (b'127.0.0.1:49841') INFO    Generation: 0 	Population: 24 	Average Score: 0.988 	Best: 0.993 	Minimum Score: 0.98 	Best: 0.992 	Product Score: 0.988 	Best: 0.993
#
# [2019-10-01 09:28:09,153] util      (b'127.0.0.1:49841') INFO    Generation: 1 	Population: 24 	Average Score: 0.985 	Best: 0.993 	Minimum Score: 0.972 	Best: 0.992 	Product Score: 0.985 	Best: 0.993
#
# [2019-10-01 09:28:10,030] util      (b'127.0.0.1:49841') INFO    Generation: 2 	Population: 24 	Average Score: 0.986 	Best: 0.993 	Minimum Score: 0.974 	Best: 0.992 	Product Score: 0.986 	Best: 0.993
#
# [2019-10-01 09:28:10,937] util      (b'127.0.0.1:49841') INFO    Generation: 3 	Population: 24 	Average Score: 0.987 	Best: 0.993 	Minimum Score: 0.976 	Best: 0.992 	Product Score: 0.987 	Best: 0.993
#
# [2019-10-01 09:28:11,950] util      (b'127.0.0.1:49841') INFO    Generation: 4 	Population: 24 	Average Score: 0.99 	Best: 0.996 	Minimum Score: 0.981 	Best: 0.993 	Product Score: 0.99 	Best: 0.996
#
# [2019-10-01 09:28:12,863] util      (b'127.0.0.1:49841') INFO    Generation: 5 	Population: 24 	Average Score: 0.99 	Best: 0.997 	Minimum Score: 0.98 	Best: 0.997 	Product Score: 0.99 	Best: 0.997
#
# [2019-10-01 09:28:13,719] util      (b'127.0.0.1:49841') INFO    Generation: 6 	Population: 24 	Average Score: 0.989 	Best: 0.997 	Minimum Score: 0.978 	Best: 0.997 	Product Score: 0.989 	Best: 0.997
#
# [2019-10-01 09:28:14,556] util      (b'127.0.0.1:49841') INFO    Generation: 7 	Population: 24 	Average Score: 0.991 	Best: 0.998 	Minimum Score: 0.983 	Best: 0.997 	Product Score: 0.991 	Best: 0.998
#
# [2019-10-01 09:28:15,426] util      (b'127.0.0.1:49841') INFO    Generation: 8 	Population: 24 	Average Score: 0.991 	Best: 0.998 	Minimum Score: 0.983 	Best: 0.997 	Product Score: 0.991 	Best: 0.998
#
# [2019-10-01 09:28:16,419] util      (b'127.0.0.1:49841') INFO    Generation: 9 	Population: 24 	Average Score: 0.993 	Best: 0.999 	Minimum Score: 0.986 	Best: 0.997 	Product Score: 0.993 	Best: 0.999
#
# [2019-10-01 09:28:17,322] util      (b'127.0.0.1:49841') INFO    Generation: 10 	Population: 24 	Average Score: 0.994 	Best: 1 	Minimum Score: 0.988 	Best: 0.999 	Product Score: 0.994 	Best: 1
#
# [2019-10-01 09:28:18,198] util      (b'127.0.0.1:49841') INFO    Generation: 11 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.985 	Best: 0.999 	Product Score: 0.992 	Best: 1
#
# [2019-10-01 09:28:19,087] util      (b'127.0.0.1:49841') INFO    Generation: 12 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.987 	Best: 0.999 	Product Score: 0.993 	Best: 1
#
# [2019-10-01 09:28:19,886] util      (b'127.0.0.1:49841') INFO    Generation: 13 	Population: 24 	Average Score: 0.994 	Best: 1 	Minimum Score: 0.988 	Best: 0.999 	Product Score: 0.994 	Best: 1
#
# [2019-10-01 09:28:20,778] util      (b'127.0.0.1:49841') INFO    Generation: 14 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.986 	Best: 1 	Product Score: 0.993 	Best: 1
#
# [2019-10-01 09:28:21,617] util      (b'127.0.0.1:49841') INFO    Generation: 15 	Population: 24 	Average Score: 0.991 	Best: 1 	Minimum Score: 0.982 	Best: 1 	Product Score: 0.991 	Best: 1
#
# [2019-10-01 09:28:22,487] util      (b'127.0.0.1:49841') INFO    Generation: 16 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.984 	Best: 1 	Product Score: 0.992 	Best: 1
#
# [2019-10-01 09:28:23,343] util      (b'127.0.0.1:49841') INFO    Generation: 17 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.984 	Best: 1 	Product Score: 0.992 	Best: 1
#
# [2019-10-01 09:28:24,213] util      (b'127.0.0.1:49841') INFO    Generation: 18 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.984 	Best: 1 	Product Score: 0.992 	Best: 1
#
# [2019-10-01 09:28:25,125] util      (b'127.0.0.1:49841') INFO    Generation: 19 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.984 	Best: 1 	Product Score: 0.992 	Best: 1
#
# [2019-10-01 09:28:26,060] util      (b'127.0.0.1:49841') INFO    Generation: 20 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.984 	Best: 1 	Product Score: 0.992 	Best: 1
#
# [2019-10-01 09:28:26,955] util      (b'127.0.0.1:49841') INFO    Generation: 21 	Population: 24 	Average Score: 0.991 	Best: 1 	Minimum Score: 0.982 	Best: 1 	Product Score: 0.991 	Best: 1
#
# [2019-10-01 09:28:27,820] util      (b'127.0.0.1:49841') INFO    Generation: 22 	Population: 24 	Average Score: 0.991 	Best: 1 	Minimum Score: 0.982 	Best: 1 	Product Score: 0.991 	Best: 1
#
# [2019-10-01 09:28:28,704] util      (b'127.0.0.1:49841') INFO    Generation: 23 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.983 	Best: 1 	Product Score: 0.991 	Best: 1
#
# [2019-10-01 09:28:29,574] util      (b'127.0.0.1:49841') INFO    Generation: 24 	Population: 24 	Average Score: 0.992 	Best: 1 	Minimum Score: 0.983 	Best: 1 	Product Score: 0.991 	Best: 1
#
# [2019-10-01 09:28:30,432] util      (b'127.0.0.1:49841') INFO    Generation: 25 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:31,235] util      (b'127.0.0.1:49841') INFO    Generation: 26 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:32,064] util      (b'127.0.0.1:49841') INFO    Generation: 27 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:32,909] util      (b'127.0.0.1:49841') INFO    Generation: 28 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:33,777] util      (b'127.0.0.1:49841') INFO    Generation: 29 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:34,639] util      (b'127.0.0.1:49841') INFO    Generation: 30 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:35,440] util      (b'127.0.0.1:49841') INFO    Generation: 31 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:36,278] util      (b'127.0.0.1:49841') INFO    Generation: 32 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:37,196] util      (b'127.0.0.1:49841') INFO    Generation: 33 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:38,103] util      (b'127.0.0.1:49841') INFO    Generation: 34 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:38,922] util      (b'127.0.0.1:49841') INFO    Generation: 35 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-10-01 09:28:39,785] util      (b'127.0.0.1:49841') INFO    Generation: 36 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:40,649] util      (b'127.0.0.1:49841') INFO    Generation: 37 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:41,513] util      (b'127.0.0.1:49841') INFO    Generation: 38 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-01 09:28:42,334] util      (b'127.0.0.1:49841') INFO    Generation: 39 	Population: 24 	Average Score: 0.996 	Best: 1 	Minimum Score: 0.993 	Best: 1 	Product Score: 0.996 	Best: 1
#
# [2019-10-01 09:28:43,179] util      (b'127.0.0.1:49841') INFO    Generation: 40 	Population: 24 	Average Score: 0.996 	Best: 1 	Minimum Score: 0.992 	Best: 1 	Product Score: 0.996 	Best: 1
#
# [2019-10-01 09:28:43,979] util      (b'127.0.0.1:49841') INFO    Generation: 41 	Population: 24 	Average Score: 0.996 	Best: 1 	Minimum Score: 0.992 	Best: 1 	Product Score: 0.996 	Best: 1
#
# [2019-10-01 09:28:44,809] util      (b'127.0.0.1:49841') INFO    Generation: 42 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:45,637] util      (b'127.0.0.1:49841') INFO    Generation: 43 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:46,477] util      (b'127.0.0.1:49841') INFO    Generation: 44 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:47,304] util      (b'127.0.0.1:49841') INFO    Generation: 45 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:48,143] util      (b'127.0.0.1:49841') INFO    Generation: 46 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:49,020] util      (b'127.0.0.1:49841') INFO    Generation: 47 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:49,871] util      (b'127.0.0.1:49841') INFO    Generation: 48 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:50,707] util      (b'127.0.0.1:49841') INFO    Generation: 49 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:51,571] util      (b'127.0.0.1:49841') INFO    Generation: 50 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:52,427] util      (b'127.0.0.1:49841') INFO    Generation: 51 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:53,240] util      (b'127.0.0.1:49841') INFO    Generation: 52 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:54,109] util      (b'127.0.0.1:49841') INFO    Generation: 53 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:54,926] util      (b'127.0.0.1:49841') INFO    Generation: 54 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:55,825] util      (b'127.0.0.1:49841') INFO    Generation: 55 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:56,660] util      (b'127.0.0.1:49841') INFO    Generation: 56 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:57,511] util      (b'127.0.0.1:49841') INFO    Generation: 57 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:58,366] util      (b'127.0.0.1:49841') INFO    Generation: 58 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:28:59,264] util      (b'127.0.0.1:49841') INFO    Generation: 59 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:29:03,736] util      (b'127.0.0.1:49841') INFO    Generation: 60 	Population: 1 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.996 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-10-01 09:29:10,161] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-01 09:29:10,161] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-10-01 09:29:10,161] launcher  INFO    Worker distribution:
#
# [2019-10-01 09:29:10,162] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-10-01 09:29:12,898] generate_corner_graphs (b'127.0.0.1:61684') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-10-01 09:29:12,898] generate_corner_graphs (b'127.0.0.1:61684') INFO    plotting corner plots
#
# [2019-10-01 09:29:12,903] generate_corner_graphs (b'127.0.0.1:61684') INFO    graphing remove 0 points
#
# [2019-10-01 09:29:29,188] launcher  (127.0.0.1:58669) INFO    Root process is done.
#
# [2019-10-01 09:29:29,189] launcher  (127.0.0.1:58669) INFO    Finished cleaning spawned subprocesses.
#
# [2019-10-01 09:29:29,205] match     (b'127.0.0.1:49841') INFO    altFeatures False
#
# [2019-10-01 09:29:29,205] match     (b'127.0.0.1:49841') INFO    altFeatureNames []
#
# [2019-10-01 09:29:29,205] match     (b'127.0.0.1:49841') INFO    Sysem has finished
#
# [2019-10-01 09:29:29,205] match     (b'127.0.0.1:49841') INFO    The total runtime was 83.43022990226746 seconds
#
# [2019-10-01 09:29:29,940] launcher  (127.0.0.1:58387) INFO    Root process is done.
#
# [2019-10-01 09:29:29,943] launcher  (127.0.0.1:58387) INFO    Finished cleaning spawned subprocesses.

# %% [markdown]
# ## Parameter estimation from the command line
# Most of the time paramter estimation is run from the command line. This makes it easy to run it on a remote computer and restart if something goes wrong. You can also run this under the control of a batch system and is how the software is typically used. Complex parameter estimation with multiple experiments and many variables can take a week or more to run to completion. The matching software peridically writes out graphs and other information as it runs. If you notice that the answer is good enough you can end matching early. I have seen systems get 99% of the final answer within a day and spend another week refining it with minor improvements. There is no absolute rule for this.
#
# For almost all cases what you want to run is
#
# > python -m CADETMatch --match -j /path/to/file.json
#
# It is possible that you will need to change python to python3 depending on your system
#
# If you want to force the system to generate graphs for all the simulations it has so far immediately you can run
#
# > python -m CADETMatch --generate_graphs -j /path/to/file.json
#
# If you have not passed the first generation some graphs won't be generated since the data won't be available yet.
#
# If you run this version from inside a jupyter notebook by use ! to run an external program the output won't show up until the whole estimation finishes. If you are going to run this from inside a jupyter notebok use the jupyter interface covered above. This is here as an example to show how to run the software from the command line.

# %%
#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDir)

json_path = (lesson_4 / 'example_nsga3.json').as_posix()

command = 'python -m CADETMatch --match -j "%s"' % json_path

print(command)

# !{command}
# Out:
# python -m CADETMatch --match -j "F:/temp/cadet_tutorial/lesson_4/example_nsga3.json"
# [2019-10-01 09:10:20,410] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
# [2019-10-01 09:10:20,410] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
# [2019-10-01 09:10:20,410] launcher  INFO    Worker distribution:
# [2019-10-01 09:10:20,410] launcher  INFO       127.0.0.1:	11 + origin
# [2019-10-01 09:10:26,277] util      (b'127.0.0.1:62447') INFO    Generation: -1 	Population: 24 	Average Score: 0.985 	Best: 0.992 	Minimum Score: 0.976 	Best: 0.987 	Product Score: 0.985 	Best: 0.992
# [2019-10-01 09:10:27,313] util      (b'127.0.0.1:62447') INFO    Generation: 0 	Population: 24 	Average Score: 0.984 	Best: 0.992 	Minimum Score: 0.973 	Best: 0.987 	Product Score: 0.984 	Best: 0.992
# [2019-10-01 09:10:28,300] util      (b'127.0.0.1:62447') INFO    Generation: 1 	Population: 24 	Average Score: 0.984 	Best: 0.994 	Minimum Score: 0.971 	Best: 0.991 	Product Score: 0.984 	Best: 0.994
# [2019-10-01 09:10:29,293] util      (b'127.0.0.1:62447') INFO    Generation: 2 	Population: 24 	Average Score: 0.987 	Best: 0.994 	Minimum Score: 0.977 	Best: 0.991 	Product Score: 0.987 	Best: 0.994
# [2019-10-01 09:10:30,321] util      (b'127.0.0.1:62447') INFO    Generation: 3 	Population: 24 	Average Score: 0.986 	Best: 0.994 	Minimum Score: 0.974 	Best: 0.994 	Product Score: 0.986 	Best: 0.994
# [2019-10-01 09:10:31,287] util      (b'127.0.0.1:62447') INFO    Generation: 4 	Population: 24 	Average Score: 0.99 	Best: 0.995 	Minimum Score: 0.983 	Best: 0.994 	Product Score: 0.99 	Best: 0.995
# [2019-10-01 09:10:32,181] util      (b'127.0.0.1:62447') INFO    Generation: 5 	Population: 24 	Average Score: 0.991 	Best: 0.995 	Minimum Score: 0.986 	Best: 0.994 	Product Score: 0.991 	Best: 0.995
# [2019-10-01 09:10:33,210] util      (b'127.0.0.1:62447') INFO    Generation: 6 	Population: 24 	Average Score: 0.991 	Best: 0.995 	Minimum Score: 0.986 	Best: 0.994 	Product Score: 0.991 	Best: 0.995
# [2019-10-01 09:10:34,276] util      (b'127.0.0.1:62447') INFO    Generation: 7 	Population: 24 	Average Score: 0.993 	Best: 0.995 	Minimum Score: 0.988 	Best: 0.994 	Product Score: 0.993 	Best: 0.995
# [2019-10-01 09:10:35,313] util      (b'127.0.0.1:62447') INFO    Generation: 8 	Population: 24 	Average Score: 0.994 	Best: 0.995 	Minimum Score: 0.99 	Best: 0.994 	Product Score: 0.994 	Best: 0.995
# [2019-10-01 09:10:36,379] util      (b'127.0.0.1:62447') INFO    Generation: 9 	Population: 24 	Average Score: 0.994 	Best: 0.995 	Minimum Score: 0.99 	Best: 0.994 	Product Score: 0.994 	Best: 0.995
# [2019-10-01 09:10:37,485] util      (b'127.0.0.1:62447') INFO    Generation: 10 	Population: 24 	Average Score: 0.995 	Best: 0.998 	Minimum Score: 0.991 	Best: 0.997 	Product Score: 0.995 	Best: 0.998
# [2019-10-01 09:10:38,511] util      (b'127.0.0.1:62447') INFO    Generation: 11 	Population: 24 	Average Score: 0.994 	Best: 0.998 	Minimum Score: 0.989 	Best: 0.997 	Product Score: 0.994 	Best: 0.998
# [2019-10-01 09:10:39,537] util      (b'127.0.0.1:62447') INFO    Generation: 12 	Population: 24 	Average Score: 0.993 	Best: 1 	Minimum Score: 0.987 	Best: 1 	Product Score: 0.993 	Best: 1
# [2019-10-01 09:10:40,465] util      (b'127.0.0.1:62447') INFO    Generation: 13 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-01 09:10:41,389] util      (b'127.0.0.1:62447') INFO    Generation: 14 	Population: 24 	Average Score: 0.997 	Best: 1 	Minimum Score: 0.993 	Best: 1 	Product Score: 0.997 	Best: 1
# [2019-10-01 09:10:42,360] util      (b'127.0.0.1:62447') INFO    Generation: 15 	Population: 24 	Average Score: 0.997 	Best: 1 	Minimum Score: 0.993 	Best: 1 	Product Score: 0.997 	Best: 1
# [2019-10-01 09:10:43,368] util      (b'127.0.0.1:62447') INFO    Generation: 16 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-01 09:10:44,310] util      (b'127.0.0.1:62447') INFO    Generation: 17 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-01 09:10:45,294] util      (b'127.0.0.1:62447') INFO    Generation: 18 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-01 09:10:46,299] util      (b'127.0.0.1:62447') INFO    Generation: 19 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-01 09:10:47,297] util      (b'127.0.0.1:62447') INFO    Generation: 20 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-01 09:10:48,252] util      (b'127.0.0.1:62447') INFO    Generation: 21 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-01 09:10:49,231] util      (b'127.0.0.1:62447') INFO    Generation: 22 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-01 09:10:50,153] util      (b'127.0.0.1:62447') INFO    Generation: 23 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-01 09:10:51,121] util      (b'127.0.0.1:62447') INFO    Generation: 24 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-01 09:10:52,025] util      (b'127.0.0.1:62447') INFO    Generation: 25 	Population: 24 	Average Score: 0.997 	Best: 1 	Minimum Score: 0.994 	Best: 1 	Product Score: 0.997 	Best: 1
# [2019-10-01 09:10:52,977] util      (b'127.0.0.1:62447') INFO    Generation: 26 	Population: 24 	Average Score: 0.997 	Best: 1 	Minimum Score: 0.994 	Best: 1 	Product Score: 0.997 	Best: 1
# [2019-10-01 09:10:53,955] util      (b'127.0.0.1:62447') INFO    Generation: 27 	Population: 24 	Average Score: 0.997 	Best: 1 	Minimum Score: 0.994 	Best: 1 	Product Score: 0.997 	Best: 1
# [2019-10-01 09:10:54,853] util      (b'127.0.0.1:62447') INFO    Generation: 28 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-01 09:11:13,438] util      (b'127.0.0.1:62447') INFO    Generation: 29 	Population: 1 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-10-01 09:11:20,018] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
# [2019-10-01 09:11:20,018] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
# [2019-10-01 09:11:20,018] launcher  INFO    Worker distribution:
# [2019-10-01 09:11:20,018] launcher  INFO       127.0.0.1:	0 + origin
# [2019-10-01 09:11:22,895] generate_corner_graphs (b'127.0.0.1:50485') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
# [2019-10-01 09:11:22,895] generate_corner_graphs (b'127.0.0.1:50485') INFO    plotting corner plots
# [2019-10-01 09:11:22,900] generate_corner_graphs (b'127.0.0.1:50485') INFO    graphing remove 0 points
# [2019-10-01 09:11:36,937] launcher  (127.0.0.1:56236) INFO    Root process is done.
# [2019-10-01 09:11:36,937] launcher  (127.0.0.1:56236) INFO    Finished cleaning spawned subprocesses.
# [2019-10-01 09:11:36,956] match     (b'127.0.0.1:62447') INFO    altFeatures False
# [2019-10-01 09:11:36,956] match     (b'127.0.0.1:62447') INFO    altFeatureNames []
# [2019-10-01 09:11:36,956] match     (b'127.0.0.1:62447') INFO    Sysem has finished
# [2019-10-01 09:11:36,956] match     (b'127.0.0.1:62447') INFO    The total runtime was 72.46193265914917 seconds
# [2019-10-01 09:11:37,705] launcher  (127.0.0.1:55960) INFO    Root process is done.
# [2019-10-01 09:11:37,706] launcher  (127.0.0.1:55960) INFO    Finished cleaning spawned subprocesses.

# %% [markdown]
# ## Complete results
# Sorry this next line only works on Windows. On your own system you can use whatever program you use for managing files to open up the result dir and see the same thing.
#
# The system creates a number of sub directories and depending on what settings are in the JSON file some will be empty.
#
# The import ones are
#
# 1. log
#   This contains all the log files from the system. If something goes wrong the information is usually here to find the problem and fix it. This is especialy useful for us to help with a problem.
# 2. meta
#   This contains all the results on the pareto front of meta scores. Your best results will be in this folder. There are simulations, images and results in csv and xlsx format to view.
# 3. progress
#   This folder watches the general progress of the algorithm. In this folder you can see if your variables are identifiable or the progress the search method is making.
# 4. space
#   This folder has plots for what the search space looks like. This is especially useful for debugging. Based on graphs in this folder you can expand or contract the search range for your variables which can improve the fits.
#
# There are also some important items in this folder
# 1. error.csv
#   If any simulation fails it will be recorded here
# 2. json file
#   This is the JSON used to create this simulation. It is a copy of the JSON file you started the matching process with
# 3. progress.csv
#   This file contains some information on algorithm progress. Of special interest are the last two columns that show the last generation where a new item was added to the pareto front of meta scores and how many generations in a row that progress has been made. If enough generations pass without progress the search will terminate.
# 4. result.h5
#   This is an HDF5 file that contains enormous information about the system. It has the entire population, the scores for all items, and other information. With HDFview you can easily view these files and with python you can read any information you want from these files.
# 5. csv file
#   There is one last csv file that is named based on the JSON configuration file and it shows every simulation the system has run along with the scores for that simulation.

# %%
# !explorer {resultDir}

# %% [markdown]
# ## Create corner plots
# These are frequency plots of each variable in your system along with their correlations. What you are looking for is a single peak and this indicates that your variable is identifiable. The peak may be more or less narrow depending on the ranges you gave to the optimizer. If you use an early stopping criteria these plots probably won't be accurate. What is happening is that as the system converges it searches around the best found values to try and find better ones. This means that there are many similar values and so the frequency goes up which shows up as a peak.

# %%
sim.plot_corner()
# Out:
# Corner plot in search space
# Corner plot in original space

# %% [markdown]
# ## Best plots
# This draws a selection of items from the meta folder. It will look in the folder and find the highest Product Root Score, Min Score and Mean Score and the lowest SSE and plot all of those entries. There may still be other items in those folders which are compromises between these scores. The plot will show the ID of the best found item, by what measurements it is the best and what its paramters are.

# %%
sim.plot_best()
# Out:
# Best item d24c46f1feceed713e67a64f44c51d66 for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Tue Oct  1 09:29:03 2019  d24c46f1feceed713e67a64f44c51d66   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     1.999835e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_Shape  main_Pulse_Time  \
# 0                       0.369999               1.0              1.0
#
#    Product Root Score  Min Score  Mean Score           SSE
# 0                 1.0        1.0         1.0  1.132326e-12

# %% [markdown]
# ## Comparing to the correct answer
# After all of the fitting is done the results can be compared to the correct answer when doing synthetic experiments. In this case we can see the error is well under 0.1% for all variables which is very good. That would indicate that if we ran this experiment accurately in real life it could work. If a synthetic experiment can not recover the original value then the real experiment will not find those variables accurately either.

# %%
best ,score, best_score = sim.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0082%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.00037%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0082%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.00037%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0082%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.00037%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0082%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.00037%

# %% [markdown]
# ## Change the search method
# We can also take the exact same setup we just made and change the search method from NSGA3 to Multistart and store the results in a new folder. You can see how the different methods compare.

# %%
match_grad = match.copy()

match_grad.gradVector = 0
match_grad.resultsDir = 'fit_grad'
match_grad.searchMethod = 'Multistart'


match_file = lesson_4 / 'example_gradient.json'

with (match_file).open('w') as json_file:
    json.dump(match_grad.to_dict(), json_file, indent='\t')
    
sim_grad = Match(match_file.as_posix())

resultDirGrad = Path(match_grad.baseDir) / match_grad.resultsDir
print("Your results are located at", resultDirGrad.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDirGrad)

sim_grad.start_sim()

sim_grad.plot_best()
best ,score, best_score = sim_grad.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim_grad.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_grad
#
#
# [2019-10-01 09:11:39,191] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-01 09:11:39,191] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-10-01 09:11:39,191] launcher  INFO    Worker distribution:
#
# [2019-10-01 09:11:39,191] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-10-01 09:11:43,666] multistart (b'127.0.0.1:59092') INFO    Population [Individual('d', [0.28154983811750056, 0.9276102829733247]), Individual('d', [0.8601258036374739, 0.0782875370414573]), Individual('d', [0.04701808798553131, 0.6411766432866797]), Individual('d', [0.18027488966456462, 0.8240673750644523]), Individual('d', [0.10722571661697122, 0.899645435286407]), Individual('d', [0.4908333877388116, 0.5221061377782246]), Individual('d', [0.45848375993172963, 0.4692416186821792]), Individual('d', [0.6514714391778691, 0.7193662190064348]), Individual('d', [0.018902704199455722, 0.9576289818313987]), Individual('d', [0.23508530435858388, 0.30870085886289644]), Individual('d', [0.30180507535233325, 0.1496408106673891]), Individual('d', [0.18444890298632177, 0.0020472035145570056]), Individual('d', [0.027224810403231325, 0.48986054126576184]), Individual('d', [0.7965927180664027, 0.4548631770007959]), Individual('d', [0.33305690552422906, 0.24431979265530024]), Individual('d', [0.20417589931116464, 0.9728412173889914]), Individual('d', [0.5958361109437286, 0.5908757468765565]), Individual('d', [0.3824792495646294, 0.30786927763680694]), Individual('d', [0.4942680245426767, 0.39623803387993695]), Individual('d', [0.22596634917193992, 0.22904238172443037]), Individual('d', [0.6875240282547518, 0.23085950873021288]), Individual('d', [0.548614067767129, 0.48018292449052435]), Individual('d', [0.13938006493131416, 0.17394484498622687]), Individual('d', [0.47497754877583487, 0.287269373264756])]
#
# [2019-10-01 09:12:37,585] multistart (b'127.0.0.1:59092') INFO    gradCheck 0.8998582147648537
#
# [2019-10-01 09:12:37,585] multistart (b'127.0.0.1:59092') INFO    newChildren [Individual('d', [0.801644450889543, 0.5522883894834827]), Individual('d', [0.8625004530762682, 0.07685524099789183]), Individual('d', [0.26918294317843783, 0.48147740047032384]), Individual('d', [0.18027487406339135, 0.8240673793032293]), Individual('d', [0.0023630636445789274, 0.4079972775144633]), Individual('d', [0.5206798887362454, 0.499966971791049]), Individual('d', [0.4619927825150125, 0.4675980350921139]), Individual('d', [0.8995160490827218, 0.673378053157103]), Individual('d', [0.04078324722561689, 0.16917544484220154]), Individual('d', [0.2343596069131985, 0.3079870621881788]), Individual('d', [0.3073014669720988, 0.1462692853091901]), Individual('d', [0.10682442903641177, 4.8594406417247095e-06]), Individual('d', [0.02900246206764988, 0.4889019875258005]), Individual('d', [0.7226109184376146, 0.46409951319831466]), Individual('d', [0.3488834736065369, 0.24275354453194126]), Individual('d', [0.9968296766318658, 0.9999936726844993]), Individual('d', [0.6736830121540156, 0.49561924514560957]), Individual('d', [0.3944814013011829, 0.30469529149985486]), Individual('d', [0.49673205071757176, 0.394798225954403]), Individual('d', [0.2404201852033428, 0.22779100277168732]), Individual('d', [0.6908427476412743, 0.22927868273939667]), Individual('d', [0.5514282414100455, 0.4778365349424645]), Individual('d', [0.14150750525232555, 0.17305778119455978]), Individual('d', [0.475968148384235, 0.28618895430752705])]
#
# [2019-10-01 09:12:37,592] util      (b'127.0.0.1:59092') INFO    Generation: -1 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-10-01 09:12:43,695] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-01 09:12:43,695] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-10-01 09:12:43,695] launcher  INFO    Worker distribution:
#
# [2019-10-01 09:12:43,695] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-10-01 09:12:46,573] generate_corner_graphs (b'127.0.0.1:62280') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-10-01 09:12:46,574] generate_corner_graphs (b'127.0.0.1:62280') INFO    plotting corner plots
#
# [2019-10-01 09:12:46,577] generate_corner_graphs (b'127.0.0.1:62280') INFO    graphing remove 0 points
#
# [2019-10-01 09:12:46,631] loggerwriter (b'127.0.0.1:62280') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:12:48,667] loggerwriter (b'127.0.0.1:62280') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:12:50,649] loggerwriter (b'127.0.0.1:62280') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:12:52,589] loggerwriter (b'127.0.0.1:62280') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:12:54,409] loggerwriter (b'127.0.0.1:62280') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:12:56,302] loggerwriter (b'127.0.0.1:62280') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:12:58,772] launcher  (127.0.0.1:56555) INFO    Root process is done.
#
# [2019-10-01 09:12:58,772] launcher  (127.0.0.1:56555) INFO    Finished cleaning spawned subprocesses.
#
# [2019-10-01 09:12:58,789] match     (b'127.0.0.1:59092') INFO    altFeatures False
#
# [2019-10-01 09:12:58,789] match     (b'127.0.0.1:59092') INFO    altFeatureNames []
#
# [2019-10-01 09:12:58,790] match     (b'127.0.0.1:59092') INFO    Sysem has finished
#
# [2019-10-01 09:12:58,790] match     (b'127.0.0.1:59092') INFO    The total runtime was 75.2149453163147 seconds
#
# [2019-10-01 09:12:59,558] launcher  (127.0.0.1:56279) INFO    Root process is done.
#
# [2019-10-01 09:12:59,560] launcher  (127.0.0.1:56279) INFO    Finished cleaning spawned subprocesses.
#
# Best item b4327a8138da617cf7f41c1ad8b5c12e for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Tue Oct  1 09:12:23 2019  b4327a8138da617cf7f41c1ad8b5c12e   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     1.609081e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_Shape  main_Pulse_Time  \
# 0                       0.365687          0.999752         0.999933
#
#    Product Root Score  Min Score  Mean Score       SSE
# 0            0.999842   0.999752    0.999842  0.000094
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.61e-07   error: 24%
# COL_POROSITY Comp:-1 Bound:-1 = 3.66e-01   error: 1.2%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.61e-07   error: 24%
# COL_POROSITY Comp:-1 Bound:-1 = 3.66e-01   error: 1.2%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.61e-07   error: 24%
# COL_POROSITY Comp:-1 Bound:-1 = 3.66e-01   error: 1.2%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 1.61e-07   error: 24%
# COL_POROSITY Comp:-1 Bound:-1 = 3.66e-01   error: 1.2%

# %% [markdown]
# ## Change the population size
# Sometimes the population size is not large enough and needs to be increased to find better answers.

# %%
match_grad_large = match.copy()

match_grad_large.gradVector = 0
match_grad_large.resultsDir = 'fit_grad_large'
match_grad_large.searchMethod = 'Multistart'
match_grad_large.population = 24
match_grad_large.minPopulation = 24
match_grad_large.maxPopulation = 24


match_file_large = lesson_4 / 'example_gradient_large.json'

with (match_file_large).open('w') as json_file:
    json.dump(match_grad_large.to_dict(), json_file, indent='\t')
    
sim_grad_large = Match(match_file_large.as_posix())

resultDirGradLarge = Path(match_grad_large.baseDir) / match_grad_large.resultsDir
print("Your results are located at", resultDirGrad.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDirGradLarge)

sim_grad_large.start_sim()

sim_grad_large.plot_best()
best ,score, best_score = sim_grad_large.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim_grad_large.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_grad
#
#
# [2019-10-01 09:13:00,624] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-01 09:13:00,625] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-10-01 09:13:00,625] launcher  INFO    Worker distribution:
#
# [2019-10-01 09:13:00,625] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-10-01 09:13:04,813] multistart (b'127.0.0.1:50138') INFO    Population [Individual('d', [0.6178939327037293, 0.02379716250922992]), Individual('d', [0.11923990644711935, 0.7495333474811735]), Individual('d', [0.5200469166795991, 0.10631170369829923]), Individual('d', [0.3469526273495832, 0.6956960593111897]), Individual('d', [0.40825826925613007, 0.11441048765734352]), Individual('d', [0.5271725162424876, 0.5497250616182779]), Individual('d', [0.09096954472153795, 0.6386709279613774]), Individual('d', [0.7499452751689407, 0.5694789234673298]), Individual('d', [0.4795467424195208, 0.9233526471113596]), Individual('d', [0.6239543627595128, 0.2068826251863386]), Individual('d', [0.05713029537307501, 0.36858874446373047]), Individual('d', [0.11182878846005928, 0.30835079640965357]), Individual('d', [0.433046284903144, 0.704593692322918]), Individual('d', [0.587100457200214, 0.2972682904360464]), Individual('d', [0.9734615613973931, 0.7809385082601957]), Individual('d', [0.5237562636141789, 0.11486958145242532]), Individual('d', [0.9297012070224452, 0.7969157588974989]), Individual('d', [0.4688910330932632, 0.26264127252126346]), Individual('d', [0.9953955365551768, 0.2968748781537325]), Individual('d', [0.9616946746832742, 0.30932802740532706]), Individual('d', [0.08604671500403571, 0.8612576486424417]), Individual('d', [0.6212037044352895, 0.7701772374519004]), Individual('d', [0.5923637484795202, 0.4032988657845842]), Individual('d', [0.5745569095217715, 0.23784073987436083]), Individual('d', [0.5459796670805361, 0.07895882877062277]), Individual('d', [0.5955039119404929, 0.6349052566399368]), Individual('d', [0.2784611325795172, 0.9872922076550334]), Individual('d', [0.3351216829679824, 0.03628159179750978]), Individual('d', [0.4626150518742389, 0.492350474355453]), Individual('d', [0.7825579661614052, 0.29978920100783146]), Individual('d', [0.9751058285955632, 0.8160471114550595]), Individual('d', [0.1417459085554974, 0.6834235845056807]), Individual('d', [0.6553360611501753, 0.8274515196409276]), Individual('d', [0.020255467419735274, 0.027676945278802267]), Individual('d', [0.4396134434908914, 0.8346695006504836]), Individual('d', [0.7994730281373507, 0.9388340734409377]), Individual('d', [0.18695246987995906, 0.15626088265418736]), Individual('d', [0.8339566512993939, 0.34530512162136195]), Individual('d', [0.11855601636885427, 0.3666054647164676]), Individual('d', [0.8891064849904865, 0.7456872839207637]), Individual('d', [0.9641818233105659, 0.8927579537325602]), Individual('d', [0.30528937529390476, 0.3584851209642087]), Individual('d', [0.38527730033504914, 0.38077055933928794]), Individual('d', [0.5032269584736215, 0.4944013732367837]), Individual('d', [0.23966205902008209, 0.034932735623738664]), Individual('d', [0.575199114500803, 0.7805988431145748]), Individual('d', [0.8488588395159568, 0.4936337287447532]), Individual('d', [0.390591610863531, 0.09621584226435542])]
#
# [2019-10-01 09:14:56,267] multistart (b'127.0.0.1:50138') INFO    gradCheck 0.8999981941445343
#
# [2019-10-01 09:14:56,267] multistart (b'127.0.0.1:50138') INFO    newChildren [Individual('d', [0.6396827752573366, 0.02256417111269376]), Individual('d', [0.05904829003811705, 0.5043225786600871]), Individual('d', [0.527804930496391, 0.10525568112068662]), Individual('d', [0.4671701765308028, 0.5063487853614397]), Individual('d', [0.4131673870081287, 0.11193199525657385]), Individual('d', [0.5532100018591749, 0.5089789853277303]), Individual('d', [0.043277069984807924, 0.43497460993118314]), Individual('d', [0.8166004869410478, 0.5585472094931722]), Individual('d', [0.9727547368383739, 0.9987153358644624]), Individual('d', [0.6279342228020802, 0.20552635022294022]), Individual('d', [0.05813577867936227, 0.36563758193983065]), Individual('d', [0.11551821662372032, 0.3078739320670008]), Individual('d', [0.9956282173507603, 0.8808826382528117]), Individual('d', [0.588223408981877, 0.29679644926288395]), Individual('d', [0.9718846609780594, 0.7812819216807301]), Individual('d', [0.5317489312204525, 0.11304751766997935]), Individual('d', [0.9293712488281607, 0.796992180187654]), Individual('d', [0.4799911916123086, 0.25919509905624594]), Individual('d', [0.8865329577325398, 0.6148039144604174]), Individual('d', [0.8891702651180311, 0.6343446518985159]), Individual('d', [0.08604671500403571, 0.8612576486424417]), Individual('d', [0.018246689214880426, 0.3425136697618786]), Individual('d', [0.5935450696522239, 0.4021085014838521]), Individual('d', [0.5824359960525987, 0.2344004139175863]), Individual('d', [0.5479103663024647, 0.07849155632676467]), Individual('d', [0.815115731926024, 0.5579022371916379]), Individual('d', [0.2784430069046291, 0.9872911017516964]), Individual('d', [0.3050031995284782, 0.03457574578038491]), Individual('d', [0.46461184030520436, 0.4908380100120953]), Individual('d', [0.6269326035333611, 0.45122130262755816]), Individual('d', [0.9726608749453467, 0.8164872776073915]), Individual('d', [0.852707617255027, 0.5892389150959554]), Individual('d', [0.9809573538375294, 0.987378398078834]), Individual('d', [0.13864795590435172, 0.026676154337030696]), Individual('d', [0.9678534346139653, 0.6891180621627363]), Individual('d', [0.8002407045164716, 0.9383483068752868]), Individual('d', [0.17828662273871607, 0.15382056106333908]), Individual('d', [0.7475173964862439, 0.47369814857519427]), Individual('d', [0.12683925955666575, 0.3656660335466692]), Individual('d', [0.8196909021036458, 0.5599201334831037]), Individual('d', [0.9611930175735472, 0.89309977635349]), Individual('d', [0.30581014772756393, 0.35824962724763765]), Individual('d', [0.3994593663404809, 0.3780244489217211]), Individual('d', [0.506401691550062, 0.4917929849560867]), Individual('d', [0.2509710338718818, 0.034445128242987046]), Individual('d', [0.5751990017433092, 0.7805989561294906]), Individual('d', [0.7813365693023901, 0.6120723308677671]), Individual('d', [0.3913307372900394, 0.09254502531994903])]
#
# [2019-10-01 09:14:56,279] util      (b'127.0.0.1:50138') INFO    Generation: -1 	Population: 48 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-10-01 09:15:03,202] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-01 09:15:03,202] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-10-01 09:15:03,202] launcher  INFO    Worker distribution:
#
# [2019-10-01 09:15:03,202] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-10-01 09:15:06,378] generate_corner_graphs (b'127.0.0.1:49614') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-10-01 09:15:06,378] generate_corner_graphs (b'127.0.0.1:49614') INFO    plotting corner plots
#
# [2019-10-01 09:15:06,383] generate_corner_graphs (b'127.0.0.1:49614') INFO    graphing remove 0 points
#
# [2019-10-01 09:15:06,444] loggerwriter (b'127.0.0.1:49614') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:15:08,967] loggerwriter (b'127.0.0.1:49614') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:15:11,164] loggerwriter (b'127.0.0.1:49614') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:15:18,703] launcher  (127.0.0.1:56904) INFO    Root process is done.
#
# [2019-10-01 09:15:18,704] launcher  (127.0.0.1:56904) INFO    Finished cleaning spawned subprocesses.
#
# [2019-10-01 09:15:18,720] match     (b'127.0.0.1:50138') INFO    altFeatures False
#
# [2019-10-01 09:15:18,720] match     (b'127.0.0.1:50138') INFO    altFeatureNames []
#
# [2019-10-01 09:15:18,720] match     (b'127.0.0.1:50138') INFO    Sysem has finished
#
# [2019-10-01 09:15:18,720] match     (b'127.0.0.1:50138') INFO    The total runtime was 134.0056550502777 seconds
# [2019-10-01 09:15:19,512] launcher  (127.0.0.1:56584) INFO    Root process is done.
#
# [2019-10-01 09:15:19,513] launcher  (127.0.0.1:56584) INFO    Finished cleaning spawned subprocesses.
#
# Best item f8276d959bee6386ff5d8cd283285406 for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Tue Oct  1 09:14:03 2019  f8276d959bee6386ff5d8cd283285406   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     1.846724e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_Shape  main_Pulse_Time  \
# 0                       0.367564          0.999987         0.999986
#
#    Product Root Score  Min Score  Mean Score       SSE
# 0            0.999986   0.999986    0.999986  0.000109
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.85e-07   error: 8.3%
# COL_POROSITY Comp:-1 Bound:-1 = 3.68e-01   error: 0.66%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.85e-07   error: 8.3%
# COL_POROSITY Comp:-1 Bound:-1 = 3.68e-01   error: 0.66%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.85e-07   error: 8.3%
# COL_POROSITY Comp:-1 Bound:-1 = 3.68e-01   error: 0.66%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 1.85e-07   error: 8.3%
# COL_POROSITY Comp:-1 Bound:-1 = 3.68e-01   error: 0.66%

# %% [markdown]
# ## Changing the score
# You can also change to an SSE based score and use gradient descent. For this problem it should provide very good results.

# %%
match_sse = match.copy()

match_sse.resultsDir = 'fit_sse'
match_sse.searchMethod = 'Multistart'
match_sse.experiments[0].features[0].type = 'DextranSSE'


match_file = lesson_4 / 'example_sse.json'

with (match_file).open('w') as json_file:
    json.dump(match_sse.to_dict(), json_file, indent='\t')

sim_sse = Match(match_file.as_posix())

resultDirSSE = Path(match_sse.baseDir) / match_sse.resultsDir
print("Your results are located at", resultDirSSE.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDirSSE)

sim_sse.start_sim()

sim_sse.plot_best()
best ,score, best_score = sim_sse.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim_sse.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_sse
#
#
# [2019-10-01 09:15:20,567] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-01 09:15:20,567] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-10-01 09:15:20,567] launcher  INFO    Worker distribution:
#
# [2019-10-01 09:15:20,567] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-10-01 09:15:24,884] multistart (b'127.0.0.1:57677') INFO    Population [Individual('d', [0.018221925340587974, 0.7189729691196521]), Individual('d', [0.6261357444936384, 0.7670659958232288]), Individual('d', [0.318643645120949, 0.6314256891394447]), Individual('d', [0.9958961199500792, 0.3010480631894312]), Individual('d', [0.6091614737031278, 0.05710173418358755]), Individual('d', [0.00758997873716738, 0.32816563777218677]), Individual('d', [0.8673566039649978, 0.4798670246252681]), Individual('d', [0.9644234002001746, 0.6810531421831196]), Individual('d', [0.4290243641211169, 0.8786425729832823]), Individual('d', [0.3614701965393474, 0.11212976895971571]), Individual('d', [0.4110023032791583, 0.43175488571642184]), Individual('d', [0.09905009159864064, 0.9702149986345415]), Individual('d', [0.7181364086066689, 0.9975380695535461]), Individual('d', [0.9379147249247282, 0.7644744774505626]), Individual('d', [0.014576017345452885, 0.4693459677395566]), Individual('d', [0.9971521045978795, 0.6344244719852703]), Individual('d', [0.11719105129249552, 0.36954840124413113]), Individual('d', [0.5683732137241678, 0.5776313340044646]), Individual('d', [0.8315329762032924, 0.6566154644155814]), Individual('d', [0.049006267043373075, 0.6548676093577492]), Individual('d', [0.33636898784757463, 0.6263788872281582]), Individual('d', [0.01836063526933296, 0.6729549553584431]), Individual('d', [0.559758701637217, 0.6620786051986759]), Individual('d', [0.14292007051635958, 0.05942182751473013])]
#
# [2019-10-01 09:15:25,620] gradFD    (b'127.0.0.1:57677') INFO    removed [0.018221925340587974, 0.7189729691196521] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,620] gradFD    (b'127.0.0.1:57677') INFO    removed [0.6261357444936384, 0.7670659958232288] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,621] gradFD    (b'127.0.0.1:57677') INFO    removed [0.318643645120949, 0.6314256891394447] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,621] gradFD    (b'127.0.0.1:57677') INFO    removed [0.9958961199500792, 0.3010480631894312] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,621] gradFD    (b'127.0.0.1:57677') INFO    removed [0.6091614737031278, 0.05710173418358755] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,621] gradFD    (b'127.0.0.1:57677') INFO    removed [0.00758997873716738, 0.32816563777218677] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,622] gradFD    (b'127.0.0.1:57677') INFO    removed [0.8673566039649978, 0.4798670246252681] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,622] gradFD    (b'127.0.0.1:57677') INFO    removed [0.4290243641211169, 0.8786425729832823] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,622] gradFD    (b'127.0.0.1:57677') INFO    removed [0.3614701965393474, 0.11212976895971571] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,622] gradFD    (b'127.0.0.1:57677') INFO    removed [0.4110023032791583, 0.43175488571642184] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,641] gradFD    (b'127.0.0.1:57677') INFO    removed [0.09905009159864064, 0.9702149986345415] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,641] gradFD    (b'127.0.0.1:57677') INFO    removed [0.7181364086066689, 0.9975380695535461] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,739] gradFD    (b'127.0.0.1:57677') INFO    removed [0.11719105129249552, 0.36954840124413113] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,739] gradFD    (b'127.0.0.1:57677') INFO    removed [0.5683732137241678, 0.5776313340044646] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,739] gradFD    (b'127.0.0.1:57677') INFO    removed [0.8315329762032924, 0.6566154644155814] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,812] gradFD    (b'127.0.0.1:57677') INFO    removed [0.049006267043373075, 0.6548676093577492] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,830] gradFD    (b'127.0.0.1:57677') INFO    removed [0.33636898784757463, 0.6263788872281582] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,912] gradFD    (b'127.0.0.1:57677') INFO    removed [0.01836063526933296, 0.6729549553584431] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,912] gradFD    (b'127.0.0.1:57677') INFO    removed [0.559758701637217, 0.6620786051986759] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,912] gradFD    (b'127.0.0.1:57677') INFO    removed [0.14292007051635958, 0.05942182751473013] for insufficient overlap in gradient descent
#
# [2019-10-01 09:15:25,912] gradFD    (b'127.0.0.1:57677') INFO    overlap okay offspring [[0.9644234002001746, 0.6810531421831196], [0.9379147249247282, 0.7644744774505626], [0.014576017345452885, 0.4693459677395566], [0.9971521045978795, 0.6344244719852703]]
#
# [2019-10-01 09:17:35,793] multistart (b'127.0.0.1:57677') INFO    gradCheck -1.381231393105823e-16
#
# [2019-10-01 09:17:35,794] multistart (b'127.0.0.1:57677') INFO    newChildren [Individual('d', [0.9616290820670026, 0.6819668797960694]), Individual('d', [0.8252573948075678, 0.566666613757498])]
#
# [2019-10-01 09:17:35,800] util      (b'127.0.0.1:57677') INFO    Generation: -1 	Population: 2 	Average Score: -1.53e-16 	Best: -1.53e-16 	Minimum Score: -1.53e-16 	Best: -1.53e-16 	Product Score: -1.53e-16 	Best: -1.53e-16
#
# [2019-10-01 09:17:41,764] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-01 09:17:41,764] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-10-01 09:17:41,765] launcher  INFO    Worker distribution:
#
# [2019-10-01 09:17:41,765] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-10-01 09:17:44,566] generate_corner_graphs (b'127.0.0.1:62935') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-10-01 09:17:44,567] generate_corner_graphs (b'127.0.0.1:62935') INFO    plotting corner plots
#
# [2019-10-01 09:17:44,611] loggerwriter (b'127.0.0.1:62935') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:17:45,457] loggerwriter (b'127.0.0.1:62935') WARNING Traceback (most recent call last):
#
#
#
# [2019-10-01 09:17:45,457] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#
#
#
# [2019-10-01 09:17:45,457] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,457] loggerwriter (b'127.0.0.1:62935') WARNING "__main__", mod_spec)
#
# [2019-10-01 09:17:45,457] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\runpy.py", line 85, in _run_code
#
#
#
# [2019-10-01 09:17:45,457] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,457] loggerwriter (b'127.0.0.1:62935') WARNING exec(code, run_globals)
#
# [2019-10-01 09:17:45,457] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\site-packages\scoop\bootstrap\__main__.py", line 302, in <module>
#
#
#
# [2019-10-01 09:17:45,458] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,458] loggerwriter (b'127.0.0.1:62935') WARNING b.main()
#
# [2019-10-01 09:17:45,458] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\site-packages\scoop\bootstrap\__main__.py", line 92, in main
#
#
#
# [2019-10-01 09:17:45,458] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,458] loggerwriter (b'127.0.0.1:62935') WARNING self.run()
#
# [2019-10-01 09:17:45,458] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\site-packages\scoop\bootstrap\__main__.py", line 290, in run
#
#
#
# [2019-10-01 09:17:45,459] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,459] loggerwriter (b'127.0.0.1:62935') WARNING futures_startup()
#
# [2019-10-01 09:17:45,459] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\site-packages\scoop\bootstrap\__main__.py", line 271, in futures_startup
#
#
#
# [2019-10-01 09:17:45,459] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,459] loggerwriter (b'127.0.0.1:62935') WARNING run_name="__main__"
#
# [2019-10-01 09:17:45,459] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\site-packages\scoop\futures.py", line 64, in _startup
#
#
#
# [2019-10-01 09:17:45,459] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,459] loggerwriter (b'127.0.0.1:62935') WARNING result = _controller.switch(rootFuture, *args, **kargs)
#
# [2019-10-01 09:17:45,459] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\site-packages\scoop\_control.py", line 253, in runController
#
#
#
# [2019-10-01 09:17:45,460] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,460] loggerwriter (b'127.0.0.1:62935') WARNING raise future.exceptionValue
#
# [2019-10-01 09:17:45,460] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\site-packages\scoop\_control.py", line 127, in runFuture
#
#
#
# [2019-10-01 09:17:45,460] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,460] loggerwriter (b'127.0.0.1:62935') WARNING future.resultValue = future.callable(*future.args, **future.kargs)
#
# [2019-10-01 09:17:45,460] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\runpy.py", line 263, in run_path
#
#
#
# [2019-10-01 09:17:45,460] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,460] loggerwriter (b'127.0.0.1:62935') WARNING pkg_name=pkg_name, script_name=fname)
#
# [2019-10-01 09:17:45,460] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\runpy.py", line 96, in _run_module_code
#
#
#
# [2019-10-01 09:17:45,461] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,461] loggerwriter (b'127.0.0.1:62935') WARNING mod_name, mod_spec, pkg_name, script_name)
#
# [2019-10-01 09:17:45,461] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\runpy.py", line 85, in _run_code
#
#
#
# [2019-10-01 09:17:45,461] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,461] loggerwriter (b'127.0.0.1:62935') WARNING exec(code, run_globals)
#
# [2019-10-01 09:17:45,461] loggerwriter (b'127.0.0.1:62935') WARNING   File "generate_corner_graphs.py", line 287, in <module>
#
#
#
# [2019-10-01 09:17:45,461] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,461] loggerwriter (b'127.0.0.1:62935') WARNING main()
#
# [2019-10-01 09:17:45,461] loggerwriter (b'127.0.0.1:62935') WARNING   File "generate_corner_graphs.py", line 97, in main
#
#
#
# [2019-10-01 09:17:45,462] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,462] loggerwriter (b'127.0.0.1:62935') WARNING graphCorner(cache)
#
# [2019-10-01 09:17:45,462] loggerwriter (b'127.0.0.1:62935') WARNING   File "generate_corner_graphs.py", line 248, in graphCorner
#
#
#
# [2019-10-01 09:17:45,462] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,462] loggerwriter (b'127.0.0.1:62935') WARNING create_corner(out_dir, "corner.png", headers, data_input, weights=None)
#
# [2019-10-01 09:17:45,462] loggerwriter (b'127.0.0.1:62935') WARNING   File "generate_corner_graphs.py", line 272, in create_corner
#
#
#
# [2019-10-01 09:17:45,462] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,462] loggerwriter (b'127.0.0.1:62935') WARNING fig.map_lower(sns.kdeplot)
#
# [2019-10-01 09:17:45,462] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\site-packages\seaborn\axisgrid.py", line 1442, in map_lower
#
#
#
# [2019-10-01 09:17:45,463] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,463] loggerwriter (b'127.0.0.1:62935') WARNING color=color, **kwargs)
#
# [2019-10-01 09:17:45,463] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\site-packages\seaborn\distributions.py", line 687, in kdeplot
#
#
#
# [2019-10-01 09:17:45,463] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,463] loggerwriter (b'127.0.0.1:62935') WARNING cbar, cbar_ax, cbar_kws, ax, **kwargs)
#
# [2019-10-01 09:17:45,463] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\site-packages\seaborn\distributions.py", line 393, in _bivariate_kdeplot
#
#
#
# [2019-10-01 09:17:45,463] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,463] loggerwriter (b'127.0.0.1:62935') WARNING xx, yy, z = _statsmodels_bivariate_kde(x, y, bw, gridsize, cut, clip)
#
# [2019-10-01 09:17:45,464] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\site-packages\seaborn\distributions.py", line 463, in _statsmodels_bivariate_kde
#
#
#
# [2019-10-01 09:17:45,464] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,464] loggerwriter (b'127.0.0.1:62935') WARNING kde = smnp.KDEMultivariate([x, y], "cc", bw)
#
# [2019-10-01 09:17:45,464] loggerwriter (b'127.0.0.1:62935') WARNING   File "C:\Users\kosh_000\Anaconda3\lib\site-packages\statsmodels\nonparametric\kernel_density.py", line 111, in __init__
#
#
#
# [2019-10-01 09:17:45,464] loggerwriter (b'127.0.0.1:62935') WARNING
#
# [2019-10-01 09:17:45,464] loggerwriter (b'127.0.0.1:62935') WARNING raise ValueError("The number of observations must be larger " \
#
# [2019-10-01 09:17:45,464] loggerwriter (b'127.0.0.1:62935') WARNING ValueError
#
# [2019-10-01 09:17:45,464] loggerwriter (b'127.0.0.1:62935') WARNING :
#
# [2019-10-01 09:17:45,465] loggerwriter (b'127.0.0.1:62935') WARNING The number of observations must be larger than the number of variables.
#
# [2019-10-01 09:17:45,642] launcher  (127.0.0.1:57301) INFO    Root process is done.
# [2019-10-01 09:17:45,642] launcher  (127.0.0.1:57301) INFO    Finished cleaning spawned subprocesses.
#
# [2019-10-01 09:17:45,660] match     (b'127.0.0.1:57677') INFO    altFeatures False
#
# [2019-10-01 09:17:45,660] match     (b'127.0.0.1:57677') INFO    altFeatureNames []
#
# [2019-10-01 09:17:45,660] match     (b'127.0.0.1:57677') INFO    Sysem has finished
#
# [2019-10-01 09:17:45,660] match     (b'127.0.0.1:57677') INFO    The total runtime was 140.87801551818848 seconds
#
# [2019-10-01 09:17:46,373] launcher  (127.0.0.1:56935) INFO    Root process is done.
#
# [2019-10-01 09:17:46,378] launcher  (127.0.0.1:56935) INFO    Finished cleaning spawned subprocesses.
#
# Best item c5bfe34993756aa2e8202240c95d2542 for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Tue Oct  1 09:17:35 2019  c5bfe34993756aa2e8202240c95d2542   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     1.999998e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_SSE  Product Root Score  \
# 0                           0.37   -1.534702e-16       -1.534702e-16
#
#       Min Score    Mean Score           SSE
# 0 -1.534702e-16 -1.534702e-16  1.534702e-16
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 9.6e-05%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 4.3e-06%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 9.6e-05%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 4.3e-06%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 9.6e-05%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 4.3e-06%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 9.6e-05%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 4.3e-06%

# %% [markdown]
# ## A large population can still help
# Partial Differential Equations are complex and a different start location can provide a better result. The best way to deal with this is to increase the population size.

# %%
match_sse_large = match.copy()

match_sse_large.resultsDir = 'fit_sse_large'
match_sse_large.searchMethod = 'Multistart'
match_sse_large.population = 24
match_sse_large.minPopulation = 24
match_sse_large.maxPopulation = 24
match_sse_large.experiments[0].features[0].type = 'DextranSSE'


match_file = lesson_4 / 'example_sse_large.json'

with (match_file).open('w') as json_file:
    json.dump(match_sse_large.to_dict(), json_file, indent='\t')

sim_sse_large = Match(match_file.as_posix())

resultDirSSELarge = Path(match_sse_large.baseDir) / match_sse_large.resultsDir
print("Your results are located at", resultDirSSELarge.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDirSSELarge)

sim_sse_large.start_sim()

sim_sse_large.plot_best()
best ,score, best_score = sim_sse_large.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim_sse_large.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_sse_large
#
#
# [2019-10-01 09:17:47,458] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-01 09:17:47,458] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-10-01 09:17:47,458] launcher  INFO    Worker distribution:
#
# [2019-10-01 09:17:47,459] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-10-01 09:17:51,606] multistart (b'127.0.0.1:58686') INFO    Population [Individual('d', [0.9194665189800905, 0.17366329269756253]), Individual('d', [0.12266644407518756, 0.1022515808827339]), Individual('d', [0.4720063943138417, 0.8039535919876633]), Individual('d', [0.2575513862312282, 0.249920914100203]), Individual('d', [0.19622306334238604, 0.7525042139651827]), Individual('d', [0.40703414484021216, 0.20538957491277576]), Individual('d', [0.3150827228371704, 0.9804924073108975]), Individual('d', [0.6444872201626662, 0.42496128971939895]), Individual('d', [0.9878582745285647, 0.9156255486277027]), Individual('d', [0.7643076934759638, 0.14956552310933768]), Individual('d', [0.1887815321662465, 0.24893695160917806]), Individual('d', [0.6113026075724581, 0.3942798147247186]), Individual('d', [0.5422807659835209, 0.3429131171856259]), Individual('d', [0.5929972560426614, 0.6165385940790508]), Individual('d', [0.1702436350761617, 0.5550465980970429]), Individual('d', [0.10482603681777969, 0.8973270046299225]), Individual('d', [0.617980286586621, 0.6554145472940199]), Individual('d', [0.9093410097577346, 0.24163131383644743]), Individual('d', [0.01460092339327923, 0.34140014000968544]), Individual('d', [0.6218152402242494, 0.23057685308601006]), Individual('d', [0.5535781206279841, 0.46822303509285235]), Individual('d', [0.8718445705408286, 0.3056951196123985]), Individual('d', [0.9530015929336062, 0.9420303179345528]), Individual('d', [0.0197116851988417, 0.04316470055739441]), Individual('d', [0.09928458565365161, 0.503632994894357]), Individual('d', [0.02434155738953081, 0.06793429747600299]), Individual('d', [0.24005689309849354, 0.356397851525346]), Individual('d', [0.9519162420653369, 0.6959291530830616]), Individual('d', [0.8775730225736298, 0.8505292422825484]), Individual('d', [0.28931040218172754, 0.9265784161988835]), Individual('d', [0.35779184405823783, 0.29353163356104195]), Individual('d', [0.7884787321174798, 0.5141242946808453]), Individual('d', [0.2719701469402799, 0.05579695762599102]), Individual('d', [0.06903592886112941, 0.07428786056866421]), Individual('d', [0.5479507115062874, 0.9879259498484897]), Individual('d', [0.7543668473266314, 0.7559555661454013]), Individual('d', [0.5338359576271409, 0.14791068272648444]), Individual('d', [0.8682582131803691, 0.1369396158759485]), Individual('d', [0.8635830263462331, 0.10459240367314016]), Individual('d', [0.6472117502260191, 0.8791348518623299]), Individual('d', [0.33476705613806523, 0.8442937682825751]), Individual('d', [0.6098886932858616, 0.9499244538461568]), Individual('d', [0.26571994266085064, 0.5545592289245039]), Individual('d', [0.48738722590130057, 0.41348001936969014]), Individual('d', [0.5076598156462476, 0.39417772888422997]), Individual('d', [0.8167766962938859, 0.8683547325761101]), Individual('d', [0.15362465529907543, 0.9757554364887626]), Individual('d', [0.8154557938689554, 0.8707771950364096])]
#
# [2019-10-01 09:17:52,309] gradFD    (b'127.0.0.1:58686') INFO    removed [0.9194665189800905, 0.17366329269756253] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,310] gradFD    (b'127.0.0.1:58686') INFO    removed [0.12266644407518756, 0.1022515808827339] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,310] gradFD    (b'127.0.0.1:58686') INFO    removed [0.4720063943138417, 0.8039535919876633] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,310] gradFD    (b'127.0.0.1:58686') INFO    removed [0.2575513862312282, 0.249920914100203] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,310] gradFD    (b'127.0.0.1:58686') INFO    removed [0.19622306334238604, 0.7525042139651827] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,310] gradFD    (b'127.0.0.1:58686') INFO    removed [0.40703414484021216, 0.20538957491277576] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,311] gradFD    (b'127.0.0.1:58686') INFO    removed [0.3150827228371704, 0.9804924073108975] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,311] gradFD    (b'127.0.0.1:58686') INFO    removed [0.6444872201626662, 0.42496128971939895] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,311] gradFD    (b'127.0.0.1:58686') INFO    removed [0.7643076934759638, 0.14956552310933768] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,311] gradFD    (b'127.0.0.1:58686') INFO    removed [0.1887815321662465, 0.24893695160917806] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,311] gradFD    (b'127.0.0.1:58686') INFO    removed [0.6113026075724581, 0.3942798147247186] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,745] gradFD    (b'127.0.0.1:58686') INFO    removed [0.5422807659835209, 0.3429131171856259] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,745] gradFD    (b'127.0.0.1:58686') INFO    removed [0.5929972560426614, 0.6165385940790508] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,746] gradFD    (b'127.0.0.1:58686') INFO    removed [0.1702436350761617, 0.5550465980970429] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,746] gradFD    (b'127.0.0.1:58686') INFO    removed [0.10482603681777969, 0.8973270046299225] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,746] gradFD    (b'127.0.0.1:58686') INFO    removed [0.617980286586621, 0.6554145472940199] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,747] gradFD    (b'127.0.0.1:58686') INFO    removed [0.9093410097577346, 0.24163131383644743] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,747] gradFD    (b'127.0.0.1:58686') INFO    removed [0.01460092339327923, 0.34140014000968544] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,747] gradFD    (b'127.0.0.1:58686') INFO    removed [0.6218152402242494, 0.23057685308601006] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,748] gradFD    (b'127.0.0.1:58686') INFO    removed [0.8718445705408286, 0.3056951196123985] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,748] gradFD    (b'127.0.0.1:58686') INFO    removed [0.9530015929336062, 0.9420303179345528] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,748] gradFD    (b'127.0.0.1:58686') INFO    removed [0.0197116851988417, 0.04316470055739441] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:52,749] gradFD    (b'127.0.0.1:58686') INFO    removed [0.02434155738953081, 0.06793429747600299] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,076] gradFD    (b'127.0.0.1:58686') INFO    removed [0.24005689309849354, 0.356397851525346] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,076] gradFD    (b'127.0.0.1:58686') INFO    removed [0.8775730225736298, 0.8505292422825484] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,077] gradFD    (b'127.0.0.1:58686') INFO    removed [0.28931040218172754, 0.9265784161988835] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,077] gradFD    (b'127.0.0.1:58686') INFO    removed [0.35779184405823783, 0.29353163356104195] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,077] gradFD    (b'127.0.0.1:58686') INFO    removed [0.2719701469402799, 0.05579695762599102] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,077] gradFD    (b'127.0.0.1:58686') INFO    removed [0.06903592886112941, 0.07428786056866421] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,078] gradFD    (b'127.0.0.1:58686') INFO    removed [0.5479507115062874, 0.9879259498484897] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,078] gradFD    (b'127.0.0.1:58686') INFO    removed [0.7543668473266314, 0.7559555661454013] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,078] gradFD    (b'127.0.0.1:58686') INFO    removed [0.5338359576271409, 0.14791068272648444] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,078] gradFD    (b'127.0.0.1:58686') INFO    removed [0.8682582131803691, 0.1369396158759485] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,079] gradFD    (b'127.0.0.1:58686') INFO    removed [0.8635830263462331, 0.10459240367314016] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,079] gradFD    (b'127.0.0.1:58686') INFO    removed [0.6472117502260191, 0.8791348518623299] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,082] gradFD    (b'127.0.0.1:58686') INFO    removed [0.33476705613806523, 0.8442937682825751] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,087] gradFD    (b'127.0.0.1:58686') INFO    removed [0.6098886932858616, 0.9499244538461568] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,128] gradFD    (b'127.0.0.1:58686') INFO    removed [0.26571994266085064, 0.5545592289245039] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,190] gradFD    (b'127.0.0.1:58686') INFO    removed [0.48738722590130057, 0.41348001936969014] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,199] gradFD    (b'127.0.0.1:58686') INFO    removed [0.5076598156462476, 0.39417772888422997] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,200] gradFD    (b'127.0.0.1:58686') INFO    removed [0.8167766962938859, 0.8683547325761101] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,207] gradFD    (b'127.0.0.1:58686') INFO    removed [0.15362465529907543, 0.9757554364887626] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,207] gradFD    (b'127.0.0.1:58686') INFO    removed [0.8154557938689554, 0.8707771950364096] for insufficient overlap in gradient descent
#
# [2019-10-01 09:17:53,207] gradFD    (b'127.0.0.1:58686') INFO    overlap okay offspring [[0.9878582745285647, 0.9156255486277027], [0.5535781206279841, 0.46822303509285235], [0.09928458565365161, 0.503632994894357], [0.9519162420653369, 0.6959291530830616], [0.7884787321174798, 0.5141242946808453]]
# [2019-10-01 09:18:23,348] multistart (b'127.0.0.1:58686') INFO    gradCheck -5.105311688768318e-16
#
# [2019-10-01 09:18:23,348] multistart (b'127.0.0.1:58686') INFO    newChildren [Individual('d', [0.936805344868268, 0.9228141009340363]), Individual('d', [0.8252572987621075, 0.5666665649460577]), Individual('d', [0.8252552290457421, 0.5666655130996506]), Individual('d', [0.9492648739528087, 0.6968072477185375]), Individual('d', [0.8252552518579318, 0.5666655246929047])]
#
# [2019-10-01 09:18:23,355] util      (b'127.0.0.1:58686') INFO    Generation: -1 	Population: 5 	Average Score: -5.67e-16 	Best: -5.67e-16 	Minimum Score: -5.67e-16 	Best: -5.67e-16 	Product Score: -5.67e-16 	Best: -5.67e-16
#
# [2019-10-01 09:18:29,299] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-10-01 09:18:29,299] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-10-01 09:18:29,299] launcher  INFO    Worker distribution:
#
# [2019-10-01 09:18:29,299] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-10-01 09:18:32,029] generate_corner_graphs (b'127.0.0.1:56616') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-10-01 09:18:32,030] generate_corner_graphs (b'127.0.0.1:56616') INFO    plotting corner plots
#
# [2019-10-01 09:18:32,074] loggerwriter (b'127.0.0.1:56616') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:18:33,866] loggerwriter (b'127.0.0.1:56616') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:18:35,780] loggerwriter (b'127.0.0.1:56616') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:18:37,860] loggerwriter (b'127.0.0.1:56616') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:18:40,025] loggerwriter (b'127.0.0.1:56616') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:18:41,816] loggerwriter (b'127.0.0.1:56616') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-10-01 09:18:44,099] launcher  (127.0.0.1:57670) INFO    Root process is done.
#
# [2019-10-01 09:18:44,099] launcher  (127.0.0.1:57670) INFO    Finished cleaning spawned subprocesses.
#
# [2019-10-01 09:18:44,115] match     (b'127.0.0.1:58686') INFO    altFeatures False
#
# [2019-10-01 09:18:44,115] match     (b'127.0.0.1:58686') INFO    altFeatureNames []
#
# [2019-10-01 09:18:44,115] match     (b'127.0.0.1:58686') INFO    Sysem has finished
#
# [2019-10-01 09:18:44,115] match     (b'127.0.0.1:58686') INFO    The total runtime was 52.611783504486084 seconds
#
# [2019-10-01 09:18:44,860] launcher  (127.0.0.1:57346) INFO    Root process is done.
#
# [2019-10-01 09:18:44,862] launcher  (127.0.0.1:57346) INFO    Finished cleaning spawned subprocesses.
#
# Best item c682488b28703c008eb066b4a36d73bb for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Tue Oct  1 09:18:14 2019  c682488b28703c008eb066b4a36d73bb   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     1.999996e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_SSE  Product Root Score  \
# 0                           0.37   -5.672569e-16       -5.672569e-16
#
#       Min Score    Mean Score           SSE
# 0 -5.672569e-16 -5.672569e-16  5.672569e-16
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.00018%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 8.2e-06%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.00018%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 8.2e-06%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.00018%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 8.2e-06%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.00018%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 8.2e-06%
