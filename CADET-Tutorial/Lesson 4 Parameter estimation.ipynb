# %% [markdown]
# # Lesson 4
#
# Our goal is to match computer simulations to real experiments. Computer simulations are also cheaper to do and can be used to tell us if the real experiment can even answer the question we want to ask. The idea is to build the experiment synthetically first and then try to match against the synthetic data and see if under ideal circumstances if you can identify the parameters of interest. If you can't do it synthetically you can't do it in real life either which has many sources of error. Many times I have seen experiments run which turned out to have no chance of providing the required information because the experiment was run before figuring out what experiment should be run.
#
# ## Purpose
#
# The goal of this section is to learn how to setup, run and analyze a parameter estimation run.
#
# The example used is from Lesson 1 which is a simple Dextran pulse through a column. This lesson will cover the the common variable transforms, scores and search algorithms.
#
# ## Standard imports

# %%
#from IPython.core.display import display, HTML
from IPython.display import display, HTML, clear_output
display(HTML("<style>.container { width:100% !important; }</style>"))

#Python path library support
from pathlib import Path

#python numeric library
import numpy

#python math library
import math

#scientific library for python
import scipy

#pandas is python library for data analysis
import pandas

#addict is a library that makes it easier to create nested dictionaries
from addict import Dict

#json is a standard text based format and it used in CADETMatch for the configuration file
import json

#python plotting library
import matplotlib.pyplot as plt

#cadet python interface
from cadet import Cadet

#jupyter widget support
from ipywidgets import interact
import ipywidgets as widgets

from CADETMatch.jupyter import Match

#This is just a support function to make running the examples a bit easier later
def deleteResultDir(path):
    #This is to try and make sure that only an actual result directory can be removed
    #And only if no other files have been added to the directory, just in case
    if not path.exists():
        return
    allowed = {'evo', 'grad', 'log', 'mcmc', 'meta', 'misc', 'progress', 
               'space', 'error.csv', 'result.h5', 'progress.csv'}
    allowed.add(match.CSV)
    allowed.add(match_file.name)
    okayToRemove = False
    for child in path.iterdir():
        if child.name not in allowed:
            break
    else:
        okayToRemove = True
    if okayToRemove:
        import shutil
        shutil.rmtree(path)
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Setup CADET path

# %%
#put in the path to the bin folder
cadet_bin_path = Path(r"C:\Users\kosh_000\cadet_build\CADET\VCPKG\bin")

cadet_path = cadet_bin_path / "cadet-cli.exe"

if cadet_path.exists():
    print("CADET was found. Continue to the next step.")
    Cadet.cadet_path = cadet_path.as_posix()
else:
    print('CADET could not be found. Please check the bin path')
    
print(cadet_path.as_posix())
# Out:
# CADET was found. Continue to the next step.
# C:/Users/kosh_000/cadet_build/CADET/VCPKG/bin/cadet-cli.exe

# %% [markdown]
# ## Find the lesson folders and create the folder for lesson 4

# %%
#set this to a directory on your computer where the cadet tutorial files can be saved
cadet_tutorial = Path('F:/temp/cadet_tutorial')
lesson_1 = cadet_tutorial / "lesson_1"
lesson_2 = cadet_tutorial / "lesson_2"
lesson_3 = cadet_tutorial / "lesson_3"
lesson_4 = cadet_tutorial / "lesson_4"
lesson_4.mkdir(exist_ok = True, parents=True)

# %% [markdown]
# ## Load simple example from Lesson 1
# This code is pretty much the same as what we have looked at before. We open the file from Lesson 1 and then resave it to the Lesson 4 folder. We also run the simulation and save the output of the chromatogram as a CSV file to use in the matching process.

# %%
simple_example = lesson_1 / "simple_example"
simple_example.mkdir(exist_ok = True)

simple = Cadet()

#give a filename for where the simulation should be saved
simple.filename = (simple_example / 'example.h5').as_posix()

simple.load()

simple.filename = (lesson_4 / 'example.h5').as_posix()

#save the simulation
simple.save()

#run the simulation
data = simple.run()

print(data)

if data.returncode == 0:
    print("Simulation completed successfully")
    
    #load the data from the simulation so we can view the results
    simple.load()
    
    #plot the simulation
    plt.figure(figsize=[10,10])
    plt.plot(simple.root.output.solution.solution_times,
        simple.root.output.solution.unit_002.solution_outlet_comp_000)
    
    #write the chromatogram data out to a csv file
    data = pandas.DataFrame([simple.root.output.solution.solution_times,
                        simple.root.output.solution.unit_001.solution_outlet_comp_000]).transpose()
    data.to_csv((lesson_4 / 'example.csv').as_posix(), index=False, header=False)
    
else:
    print("Simulation failed")
# Out:
# CompletedProcess(args=['C:/Users/kosh_000/cadet_build/CADET/VCPKG/bin/cadet-cli.exe', 'F:/temp/cadet_tutorial/lesson_4/example.h5'], returncode=0, stdout=b'', stderr=b'')
# Simulation completed successfully

# %% [markdown]
# ## Create CADETMatch configuration
#
# ### Search Method
# There are 4 main search methods and only 3 of them are directly used.
# 1. NSGA3
#   This is the default evolutionary algorithm and the best choice to use when you don't know anything about your search space.
# 2. Multistart
#   This is a multistart gradient descent algorithm. If your problem can be solved with gradient descent then this can be a very good choice. It creates an initial population the same way that NSGA3 does so that you don't have to worry about starting point.
# 3. GraphSpace
#   This is not for optimization and instead it is just for sampling the space. If you have a new problem and you have no idea what the range of any of the parameters are you can use this with a very large population and it will just evaluate the entire starting population and then terminate. This allows you to figure out what are plausiable ranges for your variables before using one of the search algorithms. When dealing with many variables it is still possible to miss regions of viable solutions inside large non-viable regions but in practice this has rarely been a problem.
# 4. MCMC
#   This performans the error modeling and sampling. It is not an optimization algorithm and while it will probably find the optimum value while it runs it is very slow to do so and won't stop even if it finds the optimal value. This should also not be used directly. Normally NSGA3 is used and an option is set to continue with MCMC after NSGA3 has completed. This allows MCMC to be seeded with the best values from NSGA3 which dramatically improves convergence. If you have many variables and you run this directly it may never converge since it may never find high probability regions, much less sample from them effectively.

# %%
match = Dict()
match.CADETPath = cadet_path.as_posix()
match.baseDir = lesson_4.as_posix()
match.resultsDir = 'fit_nsga3'
match.CSV = 'fit_results.csv'
match.checkpointFile = "check"
match.stopAverage = 1.1
match.stopBest = 1.1
match.gradCheck = 1.1
match.gradVector = 1
match.searchMethod = 'NSGA3'
match.mutationRate = 1.0
match.crossoverRate = 1.0
match.generations = 1000
match.population = 12
match.minPopulation = 12
match.maxPopulation = 12
match.finalGradRefinement = 1
match.stallGenerations = 10

# %% [markdown]
# ### Variable transforms
# Search algorithms don't work well when the parameters have very different ranges. For example if one parmeter varies from 1e-5 to 1e-10 and the other varies from 1-10. Another problem is when parameters are tightly coupled together but presented to the optimizer as indepdent variables. This is true with kA and kD for the adsorption and desorption rates. The parameters kA and kD are coupled together but given as two different variables while they do not freely vary from each other. To solve this problem variable transforms are available. I will cover the most common and useful transformations. There are some other variable transforms available that you can see at https://github.com/modsim/CADET-Match/tree/master/CADETMatch/transform
#
# 1. norm
#
#   This is a simple transform that normalizes a variable from 0 to 1. This is best used when you have a variable that varies over less then 3 orders of magnitude.
#
#   ```json
# {
#       "transform": "norm",
#       "component": -1,
#       "bound": -1,
#       "location": "/input/model/unit_001/COL_POROSITY",
#       "min": 0.2,
#       "max": 0.5
#     }
# ```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm'
# parameter.component = -1
# parameter.bound = -1
# parameter.location = "/input/model/unit_001/COL_POROSITY"
# parameter.min = 0.2
# parameter.max = 0.5
# ```
#
# 2. norm_log
#
#   This transform takes the log before normalizing the variable from 0 to 1. Use this transform when your variable spans more than 3 orders of magnitude.
#
#     ```json
# {
#       "transform": "norm_log",
#       "component": -1,
#       "bound": -1,
#       "location": "/input/model/unit_001/COL_DISPERSION",
#       "min": 1e-12,
#       "max": 1e-5
#     }
# ```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_log'
# parameter.component = -1
# parameter.bound = -1
# parameter.location = "/input/model/unit_001/COL_DISPERSION"
# parameter.min = 1e-12
# parameter.max = 1e-5
# ```
#
# 3. norm_keq
#
#    This transform turns ka, kd in ka and keq=ka/kd and then takes a log transform and normalizes from 0 to 1.
#
#    ```json
# {
#     "transform": "norm_keq",
#     "component": 0,
#     "bound": 0,
#     "location": [
#         "/input/model/unit_001/adsorption/LIN_KA",
#         "/input/model/unit_001/adsorption/LIN_KD"
#     ],
#     "minKA": 1e-8,
#     "maxKA": 1e8,
#     "minKEQ": 1e-4,
#     "maxKEQ": 1e4
# }
# ```
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_keq'
# parameter.component = 0
# parameter.bound = 0
# parameter.location = ["/input/model/unit_001/adsorption/LIN_KA",
#                       "/input/model/unit_001/adsorption/LIN_KD"]
# parameter.minKA = 1e-8
# parameter.maxKA = 1e8
# parameter.minKEQ = 1e-4
# parameter.maxKEQ = 1e4
# ```
#
#
# 4. norm_volume_area
#
#     This transform and the following one where created to solve the same common problem. When fitting bypass data and you model the tubing you are fitting the length, crosssectional area and dispersion of the tubing. Dispersion though is tied to the length such that a shorter length can just be compensated for with a higher diffusion. Basically we have fewer degrees of freedom that we are fitting with and since this is not a fluid dynamics model it is not physically accurate. This transformation couples the length and area together through the volume since volume is an identfiable quantity (since water is incompressible). We don't actually care much about the parameters for the tubing, it is just there to fill in for the real tubing so that fewer errors are carried into the column. Use this version if it is easier to measure the diameter of the tubing and use the other transform if measuring the length is easier. I just depends on your experimental setup.
#
#
#
# ```json
# {
#   "transform": "norm_volume_area",
#   "area_location": "/input/model/unit_003/COL_DISPERSION",
#   "length_location": "/input/model/unit_004/COL_DISPERSION",
#   "component": -1,
#   "bound": -1,
#   "minVolume":1e-6,
#   "maxVolume":1e-5,
#   "minArea":1e-4,
#   "maxArea":1e-3
# }```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_volume_area'
# parameter.area_location = "/input/model/unit_003/COL_DISPERSION"
# parameter.length_location = "/input/model/unit_004/COL_DISPERSION"
# parameter.component = -1
# parameter.bound = -1
# parameter.minVolume = 1e-6
# parameter.maxVolume = 1e-5
# parameter.minArea = 1e-4
# parameter.maxArea = 1e-3
# ```
#
#
# 5. norm_volume_length
#
#     Use this transform if measuring the length accurately is easier than measuring the diameter of the tubing. If you are lumping together all the tubing in front of the column or after the column together and you have multiple diameters it doesn't matter which of these transforms you choose.
#
# ```json
# {
#   "transform": "norm_volume_length",
#   "area_location": "/input/model/unit_003/COL_DISPERSION",
#   "length_location": "/input/model/unit_004/COL_DISPERSION",
#   "component": -1,
#   "bound": -1,
#   "minVolume":1e-6,
#   "maxVolume":1e-5,
#   "minLength":0.25,
#   "maxLength":0.75
# }```
#
#   ```python
# parameter = Dict()
# parameter.transform = 'norm_volume_area'
# parameter.area_location = "/input/model/unit_003/COL_DISPERSION"
# parameter.length_location = "/input/model/unit_004/COL_DISPERSION"
# parameter.component = -1
# parameter.bound = -1
# parameter.minVolume = 1e-6
# parameter.maxVolume = 1e-5
# parameter.minLength = 0.25
# parameter.maxLength = 0.75
# ```
#
#
# 6. set_value
#
#     This is a different kind of transform. What it allows you to do is copy a value from place to another. This is important if you are estimating axial dispersion for identical tubing in front of and behind the column. You want the same axial dispersion for both pieces of tubing but you only want to estimate one variable. With this you can estimate axial dispersion for the first piece of tubing and then copy the value over to the other piece of tubing. This is also required if you want to estimate SMA_LAMDA. Whenever SMA_LAMBDA change the initial bound salt concentration also much change or electronuetrality would be violated.
#
# ```json
# {
#   "transform": "set_value",
#   "componentFrom": -1,
#   "boundFrom": -1,
#   "locationFrom": "/input/model/unit_003/COL_DISPERSION",
#   "componentTo": -1,
#   "boundTo": -1,
#   "locationTo": "/input/model/unit_004/COL_DISPERSION"
# }```
#
# ```python
# parameter = Dict()
# parameter.transform = 'set_value'
# parameter.componentFrom = -1
# parameter.boundFrom = -1
# parameter.locationFrom = "/input/model/unit_001/COL_DISPERSION"
# parameter.componentTo = -1
# parameter.boundTo = -1
# parameter.locationTo = "/input/model/unit_001/COL_DISPERSION"
# ```

# %%
parameter1 = Dict()
parameter1.transform = 'norm_log'
parameter1.component = -1
parameter1.bound = -1
parameter1.location = "/input/model/unit_001/COL_DISPERSION"
parameter1.min = 1e-10
parameter1.max = 1e-6

parameter2 = Dict()
parameter2.transform = 'norm'
parameter2.component = -1
parameter2.bound = -1
parameter2.location = "/input/model/unit_001/COL_POROSITY"
parameter2.min = 0.2
parameter2.max = 0.5

match.parameters = [parameter1, parameter2]

# %% [markdown]
# ### Scores
#
# Scores are how the search algorithm measures if a solution is better or worse than what it had before. Without a good score system an optimizer can't work. There are many scores available and I am going to cover the most commonly used ones and when you should use them. You can see all of them at https://github.com/modsim/CADET-Match/tree/master/CADETMatch/scores . Most of these scores are based on physical understanding of the problem and it is pretty easy to add new scores. If there is a feature you can identify in your problem that ties to one of the variables being estimated then go ahead and make a score for it. Maybe for your isotherm the width of the peak or some other feature reveals important information.
#
# 1. Shape
#
#   This is the default score used when fitting an isotherm. It looks at the shape, position, and height of the peak. It has a small initial penalty for the peak being out of position in time and increases as the peak gets further away. This is to deal with the problem of pump delays and other experimental errors. The best fit may not be and often is not the peak that is in exactly the right location but it is the one with the right shape. The shape is determined by the physics which is why it is so heavily emphasied in the score system.
#
# 2. ShapeDecay
#
#   This is the default score to use when fitting transport parameters. Transport experiments are more difficult because you MUST make sure that as few errors as possible happened in the physical experiment. On most AKTA type systems if there is an alarm the timer for data collection is also paused until the alarm is cleared and the system resumes. This results in data that has no gap in the time. However, the chemicals are still reacting and moving even if the pumps are off and data collection stops. Any such error that occurs will result in the diffusion being wrong and the longer the error persists before being fixed the more wrong the estimate for diffusion will be. Things like pump delays or other pauses in the system can cause problems with estimating volume or porosity. Any errors that occur in transport experiments will be carried through to isotherm parameters which harms scaleup later.
#
# 3. DextranShape
#
#   Dextran is a nice tracer overall but it has no ideal behavior in most systems. You normally see this in strange tailing behavior. What this means is that only the front side of the peak can be used. This score specifically looks only at the front side of the peak.
#
# 4. fractionationSlide
#
#   If you have a fractionation proble use this score. Internally it is a little complex. After each simulation for each species it numerically slides the chromatogram back and forward in time and refactionates at each time to find which location best matches the experimental data to find the time difference between the synthetic and experimental peak along with a shape comparison at that time.
#
# 5. SSE
#
#   This is the Sum of Squared Errors. This score can not be combined with any of the other scores since it does not range from 0 to 1.
#
# 6. AbsoluteHeight and AbsoluteTime
#
#   These scores are needed by the MCMC system. They are absolute measurements of height and time since the beginning of the simulation. They are used to capture the impact of errors that have an assymetric impact on the peaks.

# %%
experiment1 = Dict()
experiment1.CSV = "example.csv"
experiment1.isotherm = "/output/solution/unit_001/SOLUTION_OUTLET_COMP_000"
experiment1.HDF5 = "example.h5"
experiment1.name = "main"
experiment1.timeout = 30.0

feature1 = Dict()
feature1.name = "Pulse"
feature1.type = 'DextranShape'

experiment1.features = [feature1,]

match.experiments = [experiment1,]

match_file = lesson_4 / 'example_nsga3.json'

with (match_file).open('w') as json_file:
    json.dump(match.to_dict(), json_file, indent='\t')

# %% [markdown]
# ## Create match using jupyter interface
# This creates a simple Match object to use for parameter estimation. This is useful when running a match from inside Jupyter notebook. Most of the time this is only done for small matches or when you are running a jupyter notebook on a more powerful server. All of the same results are generated as when the matching software is run directly on the command line and the full results can still be viewed. The jupyter notebook interface just shows a few highlights.

# %%
sim = Match((lesson_4 / 'example_nsga3.json').as_posix())

# %% [markdown]
# ## Start parameter estimation
# Once the Match object has been created all that you need to use is call .start_sim() and the output will be written to the notebook as the matching process runs.
#
# The first few lines tell you what version of python is being used and how many workers are being used. After that the system provides some output at the end of each generation.
#
# > [2019-09-27 12:29:34,593] util      (b'127.0.0.1:61306') INFO    Generation: 0 	Population: 24 	Average Score: 0.968 	Best: 0.981 	Minimum Score: 0.942 	Best: 0.973 	Product Score: 0.967 	Best: 0.981
#
# The above line gives information for when the line was created, what generation the system is on, how long the population is and score information. For most scores the best value is 1.0. The Average, Minimum and Products scores are the values based on the entire population while the Best versions are the scores for only the items on the pareto front. When first starting out the normal scores are usually much lower then the best scores and as the system converges they also tend to get closer.

# %%
resultDir = Path(match.baseDir) / match.resultsDir
print("Your results are located at", resultDir.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDir)

sim.start_sim()
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_nsga3
#
#
# [2019-09-30 10:21:44,046] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-30 10:21:44,046] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-09-30 10:21:44,046] launcher  INFO    Worker distribution:
#
# [2019-09-30 10:21:44,046] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-09-30 10:21:49,213] util      (b'127.0.0.1:64603') INFO    Generation: -1 	Population: 24 	Average Score: 0.901 	Best: 0.991 	Minimum Score: 0.802 	Best: 0.984 	Product Score: 0.891 	Best: 0.991
#
# [2019-09-30 10:21:50,100] util      (b'127.0.0.1:64603') INFO    Generation: 0 	Population: 24 	Average Score: 0.922 	Best: 0.994 	Minimum Score: 0.845 	Best: 0.994 	Product Score: 0.914 	Best: 0.994
#
# [2019-09-30 10:21:51,049] util      (b'127.0.0.1:64603') INFO    Generation: 1 	Population: 24 	Average Score: 0.912 	Best: 0.994 	Minimum Score: 0.826 	Best: 0.994 	Product Score: 0.904 	Best: 0.994
#
# [2019-09-30 10:21:51,898] util      (b'127.0.0.1:64603') INFO    Generation: 2 	Population: 24 	Average Score: 0.916 	Best: 0.994 	Minimum Score: 0.834 	Best: 0.994 	Product Score: 0.909 	Best: 0.994
#
# [2019-09-30 10:21:52,999] util      (b'127.0.0.1:64603') INFO    Generation: 3 	Population: 24 	Average Score: 0.941 	Best: 0.996 	Minimum Score: 0.883 	Best: 0.994 	Product Score: 0.935 	Best: 0.996
#
# [2019-09-30 10:21:53,882] util      (b'127.0.0.1:64603') INFO    Generation: 4 	Population: 24 	Average Score: 0.988 	Best: 0.997 	Minimum Score: 0.977 	Best: 0.995 	Product Score: 0.988 	Best: 0.997
#
# [2019-09-30 10:21:54,668] util      (b'127.0.0.1:64603') INFO    Generation: 5 	Population: 24 	Average Score: 0.991 	Best: 0.997 	Minimum Score: 0.982 	Best: 0.995 	Product Score: 0.991 	Best: 0.997
#
# [2019-09-30 10:21:55,583] util      (b'127.0.0.1:64603') INFO    Generation: 6 	Population: 24 	Average Score: 0.993 	Best: 0.998 	Minimum Score: 0.987 	Best: 0.997 	Product Score: 0.993 	Best: 0.998
#
# [2019-09-30 10:21:56,341] util      (b'127.0.0.1:64603') INFO    Generation: 7 	Population: 24 	Average Score: 0.998 	Best: 0.998 	Minimum Score: 0.995 	Best: 0.997 	Product Score: 0.998 	Best: 0.998
#
# [2019-09-30 10:21:57,127] util      (b'127.0.0.1:64603') INFO    Generation: 8 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:21:57,940] util      (b'127.0.0.1:64603') INFO    Generation: 9 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:21:58,942] util      (b'127.0.0.1:64603') INFO    Generation: 10 	Population: 24 	Average Score: 0.997 	Best: 1 	Minimum Score: 0.993 	Best: 1 	Product Score: 0.997 	Best: 1
#
# [2019-09-30 10:21:59,837] util      (b'127.0.0.1:64603') INFO    Generation: 11 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:00,699] util      (b'127.0.0.1:64603') INFO    Generation: 12 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:01,623] util      (b'127.0.0.1:64603') INFO    Generation: 13 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:02,422] util      (b'127.0.0.1:64603') INFO    Generation: 14 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:03,241] util      (b'127.0.0.1:64603') INFO    Generation: 15 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:03,982] util      (b'127.0.0.1:64603') INFO    Generation: 16 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:04,723] util      (b'127.0.0.1:64603') INFO    Generation: 17 	Population: 24 	Average Score: 0.996 	Best: 1 	Minimum Score: 0.992 	Best: 1 	Product Score: 0.996 	Best: 1
#
# [2019-09-30 10:22:05,535] util      (b'127.0.0.1:64603') INFO    Generation: 18 	Population: 24 	Average Score: 0.996 	Best: 1 	Minimum Score: 0.991 	Best: 1 	Product Score: 0.996 	Best: 1
#
# [2019-09-30 10:22:06,474] util      (b'127.0.0.1:64603') INFO    Generation: 19 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:07,233] util      (b'127.0.0.1:64603') INFO    Generation: 20 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-09-30 10:22:08,100] util      (b'127.0.0.1:64603') INFO    Generation: 21 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:08,904] util      (b'127.0.0.1:64603') INFO    Generation: 22 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:09,739] util      (b'127.0.0.1:64603') INFO    Generation: 23 	Population: 24 	Average Score: 0.996 	Best: 1 	Minimum Score: 0.992 	Best: 1 	Product Score: 0.996 	Best: 1
#
# [2019-09-30 10:22:10,578] util      (b'127.0.0.1:64603') INFO    Generation: 24 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-09-30 10:22:11,396] util      (b'127.0.0.1:64603') INFO    Generation: 25 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-09-30 10:22:12,312] util      (b'127.0.0.1:64603') INFO    Generation: 26 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:13,134] util      (b'127.0.0.1:64603') INFO    Generation: 27 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:14,009] util      (b'127.0.0.1:64603') INFO    Generation: 28 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-09-30 10:22:14,877] util      (b'127.0.0.1:64603') INFO    Generation: 29 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.995 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:15,668] util      (b'127.0.0.1:64603') INFO    Generation: 30 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:16,480] util      (b'127.0.0.1:64603') INFO    Generation: 31 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:17,329] util      (b'127.0.0.1:64603') INFO    Generation: 32 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:18,197] util      (b'127.0.0.1:64603') INFO    Generation: 33 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:19,051] util      (b'127.0.0.1:64603') INFO    Generation: 34 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:19,888] util      (b'127.0.0.1:64603') INFO    Generation: 35 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
#
# [2019-09-30 10:22:20,656] util      (b'127.0.0.1:64603') INFO    Generation: 36 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-09-30 10:22:21,472] util      (b'127.0.0.1:64603') INFO    Generation: 37 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-09-30 10:22:22,310] util      (b'127.0.0.1:64603') INFO    Generation: 38 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-09-30 10:22:23,293] util      (b'127.0.0.1:64603') INFO    Generation: 39 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:22:24,104] util      (b'127.0.0.1:64603') INFO    Generation: 40 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-09-30 10:22:24,952] util      (b'127.0.0.1:64603') INFO    Generation: 41 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-09-30 10:22:25,753] util      (b'127.0.0.1:64603') INFO    Generation: 42 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-09-30 10:22:26,542] util      (b'127.0.0.1:64603') INFO    Generation: 43 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:27,336] util      (b'127.0.0.1:64603') INFO    Generation: 44 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:28,190] util      (b'127.0.0.1:64603') INFO    Generation: 45 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:29,116] util      (b'127.0.0.1:64603') INFO    Generation: 46 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:29,911] util      (b'127.0.0.1:64603') INFO    Generation: 47 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:30,737] util      (b'127.0.0.1:64603') INFO    Generation: 48 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:31,546] util      (b'127.0.0.1:64603') INFO    Generation: 49 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:32,426] util      (b'127.0.0.1:64603') INFO    Generation: 50 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:33,251] util      (b'127.0.0.1:64603') INFO    Generation: 51 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:34,119] util      (b'127.0.0.1:64603') INFO    Generation: 52 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:35,004] util      (b'127.0.0.1:64603') INFO    Generation: 53 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:35,898] util      (b'127.0.0.1:64603') INFO    Generation: 54 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:36,756] util      (b'127.0.0.1:64603') INFO    Generation: 55 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:37,751] util      (b'127.0.0.1:64603') INFO    Generation: 56 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:38,674] util      (b'127.0.0.1:64603') INFO    Generation: 57 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:39,565] util      (b'127.0.0.1:64603') INFO    Generation: 58 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:40,461] util      (b'127.0.0.1:64603') INFO    Generation: 59 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:41,347] util      (b'127.0.0.1:64603') INFO    Generation: 60 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:42,154] util      (b'127.0.0.1:64603') INFO    Generation: 61 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:42,973] util      (b'127.0.0.1:64603') INFO    Generation: 62 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:43,839] util      (b'127.0.0.1:64603') INFO    Generation: 63 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:44,747] util      (b'127.0.0.1:64603') INFO    Generation: 64 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:45,624] util      (b'127.0.0.1:64603') INFO    Generation: 65 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:46,540] util      (b'127.0.0.1:64603') INFO    Generation: 66 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:47,473] util      (b'127.0.0.1:64603') INFO    Generation: 67 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:48,364] util      (b'127.0.0.1:64603') INFO    Generation: 68 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:49,312] util      (b'127.0.0.1:64603') INFO    Generation: 69 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:50,143] util      (b'127.0.0.1:64603') INFO    Generation: 70 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:22:56,993] util      (b'127.0.0.1:64603') INFO    Generation: 71 	Population: 3 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
#
# [2019-09-30 10:23:03,524] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-30 10:23:03,524] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-09-30 10:23:03,524] launcher  INFO    Worker distribution:
#
# [2019-09-30 10:23:03,524] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-09-30 10:23:06,306] generate_corner_graphs (b'127.0.0.1:63882') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-09-30 10:23:06,306] generate_corner_graphs (b'127.0.0.1:63882') INFO    plotting corner plots
#
# [2019-09-30 10:23:06,313] generate_corner_graphs (b'127.0.0.1:63882') INFO    graphing remove 0 points
#
# [2019-09-30 10:23:24,414] launcher  (127.0.0.1:51620) INFO    Root process is done.
#
# [2019-09-30 10:23:24,414] launcher  (127.0.0.1:51620) INFO    Finished cleaning spawned subprocesses.
#
# [2019-09-30 10:23:24,429] match     (b'127.0.0.1:64603') INFO    altFeatures False
#
# [2019-09-30 10:23:24,429] match     (b'127.0.0.1:64603') INFO    altFeatureNames []
#
# [2019-09-30 10:23:24,429] match     (b'127.0.0.1:64603') INFO    Sysem has finished
#
# [2019-09-30 10:23:24,429] match     (b'127.0.0.1:64603') INFO    The total runtime was 96.94111394882202 seconds
#
# [2019-09-30 10:23:25,210] launcher  (127.0.0.1:51327) INFO    Root process is done.
#
# [2019-09-30 10:23:25,210] launcher  (127.0.0.1:51327) INFO    Finished cleaning spawned subprocesses.

# %% [markdown]
# ## Parameter estimation from the command line
# Most of the time paramter estimation is run from the command line. This makes it easy to run it on a remote computer and restart if something goes wrong. You can also run this under the control of a batch system and is how the software is typically used. Complex parameter estimation with multiple experiments and many variables can take a week or more to run to completion. The matching software peridically writes out graphs and other information as it runs. If you notice that the answer is good enough you can end matching early. I have seen systems get 99% of the final answer within a day and spend another week refining it with minor improvements. There is no absolute rule for this.
#
# For almost all cases what you want to run is
#
# > python -m CADETMatch --match -j /path/to/file.json
#
# It is possible that you will need to change python to python3 depending on your system
#
# If you want to force the system to generate graphs for all the simulations it has so far immediately you can run
#
# > python -m CADETMatch --generate_graphs -j /path/to/file.json
#
# If you have not passed the first generation some graphs won't be generated since the data won't be available yet.
#
# If you run this version from inside a jupyter notebook by use ! to run an external program the output won't show up until the whole estimation finishes. If you are going to run this from inside a jupyter notebok use the jupyter interface covered above. This is here as an example to show how to run the software from the command line.

# %%
#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDir)

json_path = (lesson_4 / 'example_nsga3.json').as_posix()

command = 'python -m CADETMatch --match -j "%s"' % json_path

print(command)

# !{command}
# Out:
# python -m CADETMatch --match -j "F:/temp/cadet_tutorial/lesson_4/example_nsga3.json"
# [2019-09-30 10:23:28,725] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
# [2019-09-30 10:23:28,725] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
# [2019-09-30 10:23:28,725] launcher  INFO    Worker distribution:
# [2019-09-30 10:23:28,725] launcher  INFO       127.0.0.1:	11 + origin
# [2019-09-30 10:23:33,800] util      (b'127.0.0.1:54532') INFO    Generation: -1 	Population: 24 	Average Score: 0.912 	Best: 0.979 	Minimum Score: 0.829 	Best: 0.97 	Product Score: 0.906 	Best: 0.979
# [2019-09-30 10:23:34,766] util      (b'127.0.0.1:54532') INFO    Generation: 0 	Population: 24 	Average Score: 0.933 	Best: 0.98 	Minimum Score: 0.87 	Best: 0.97 	Product Score: 0.93 	Best: 0.98
# [2019-09-30 10:23:35,730] util      (b'127.0.0.1:54532') INFO    Generation: 1 	Population: 24 	Average Score: 0.955 	Best: 0.989 	Minimum Score: 0.916 	Best: 0.987 	Product Score: 0.953 	Best: 0.989
# [2019-09-30 10:23:36,553] util      (b'127.0.0.1:54532') INFO    Generation: 2 	Population: 24 	Average Score: 0.943 	Best: 0.989 	Minimum Score: 0.89 	Best: 0.987 	Product Score: 0.94 	Best: 0.989
# [2019-09-30 10:23:37,531] util      (b'127.0.0.1:54532') INFO    Generation: 3 	Population: 24 	Average Score: 0.984 	Best: 0.996 	Minimum Score: 0.969 	Best: 0.994 	Product Score: 0.984 	Best: 0.996
# [2019-09-30 10:23:38,381] util      (b'127.0.0.1:54532') INFO    Generation: 4 	Population: 24 	Average Score: 0.991 	Best: 0.997 	Minimum Score: 0.984 	Best: 0.996 	Product Score: 0.991 	Best: 0.997
# [2019-09-30 10:23:39,171] util      (b'127.0.0.1:54532') INFO    Generation: 5 	Population: 24 	Average Score: 0.991 	Best: 0.997 	Minimum Score: 0.984 	Best: 0.996 	Product Score: 0.991 	Best: 0.997
# [2019-09-30 10:23:39,985] util      (b'127.0.0.1:54532') INFO    Generation: 6 	Population: 24 	Average Score: 0.992 	Best: 0.999 	Minimum Score: 0.984 	Best: 0.998 	Product Score: 0.992 	Best: 0.999
# [2019-09-30 10:23:40,894] util      (b'127.0.0.1:54532') INFO    Generation: 7 	Population: 24 	Average Score: 0.989 	Best: 1 	Minimum Score: 0.977 	Best: 1 	Product Score: 0.988 	Best: 1
# [2019-09-30 10:23:41,765] util      (b'127.0.0.1:54532') INFO    Generation: 8 	Population: 24 	Average Score: 0.989 	Best: 1 	Minimum Score: 0.977 	Best: 1 	Product Score: 0.988 	Best: 1
# [2019-09-30 10:23:42,589] util      (b'127.0.0.1:54532') INFO    Generation: 9 	Population: 24 	Average Score: 0.991 	Best: 1 	Minimum Score: 0.983 	Best: 1 	Product Score: 0.991 	Best: 1
# [2019-09-30 10:23:43,447] util      (b'127.0.0.1:54532') INFO    Generation: 10 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-09-30 10:23:44,313] util      (b'127.0.0.1:54532') INFO    Generation: 11 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-09-30 10:23:45,123] util      (b'127.0.0.1:54532') INFO    Generation: 12 	Population: 24 	Average Score: 0.991 	Best: 1 	Minimum Score: 0.981 	Best: 1 	Product Score: 0.991 	Best: 1
# [2019-09-30 10:23:45,937] util      (b'127.0.0.1:54532') INFO    Generation: 13 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-09-30 10:23:46,833] util      (b'127.0.0.1:54532') INFO    Generation: 14 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-09-30 10:23:47,625] util      (b'127.0.0.1:54532') INFO    Generation: 15 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-09-30 10:23:48,510] util      (b'127.0.0.1:54532') INFO    Generation: 16 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:23:49,352] util      (b'127.0.0.1:54532') INFO    Generation: 17 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:23:50,223] util      (b'127.0.0.1:54532') INFO    Generation: 18 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:23:51,070] util      (b'127.0.0.1:54532') INFO    Generation: 19 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:23:51,932] util      (b'127.0.0.1:54532') INFO    Generation: 20 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-09-30 10:23:52,821] util      (b'127.0.0.1:54532') INFO    Generation: 21 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-09-30 10:23:53,612] util      (b'127.0.0.1:54532') INFO    Generation: 22 	Population: 24 	Average Score: 0.998 	Best: 1 	Minimum Score: 0.997 	Best: 1 	Product Score: 0.998 	Best: 1
# [2019-09-30 10:23:54,521] util      (b'127.0.0.1:54532') INFO    Generation: 23 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:23:55,341] util      (b'127.0.0.1:54532') INFO    Generation: 24 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:23:56,196] util      (b'127.0.0.1:54532') INFO    Generation: 25 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:23:57,057] util      (b'127.0.0.1:54532') INFO    Generation: 26 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:23:57,881] util      (b'127.0.0.1:54532') INFO    Generation: 27 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:23:58,760] util      (b'127.0.0.1:54532') INFO    Generation: 28 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:23:59,688] util      (b'127.0.0.1:54532') INFO    Generation: 29 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:00,527] util      (b'127.0.0.1:54532') INFO    Generation: 30 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:01,378] util      (b'127.0.0.1:54532') INFO    Generation: 31 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:02,214] util      (b'127.0.0.1:54532') INFO    Generation: 32 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:24:03,123] util      (b'127.0.0.1:54532') INFO    Generation: 33 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:24:03,975] util      (b'127.0.0.1:54532') INFO    Generation: 34 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:24:04,813] util      (b'127.0.0.1:54532') INFO    Generation: 35 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:24:05,673] util      (b'127.0.0.1:54532') INFO    Generation: 36 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:24:06,499] util      (b'127.0.0.1:54532') INFO    Generation: 37 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:24:07,329] util      (b'127.0.0.1:54532') INFO    Generation: 38 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:24:08,171] util      (b'127.0.0.1:54532') INFO    Generation: 39 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:24:09,029] util      (b'127.0.0.1:54532') INFO    Generation: 40 	Population: 24 	Average Score: 0.999 	Best: 1 	Minimum Score: 0.998 	Best: 1 	Product Score: 0.999 	Best: 1
# [2019-09-30 10:24:09,826] util      (b'127.0.0.1:54532') INFO    Generation: 41 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:10,696] util      (b'127.0.0.1:54532') INFO    Generation: 42 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:11,605] util      (b'127.0.0.1:54532') INFO    Generation: 43 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:12,530] util      (b'127.0.0.1:54532') INFO    Generation: 44 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:13,410] util      (b'127.0.0.1:54532') INFO    Generation: 45 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:14,207] util      (b'127.0.0.1:54532') INFO    Generation: 46 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:15,014] util      (b'127.0.0.1:54532') INFO    Generation: 47 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:15,870] util      (b'127.0.0.1:54532') INFO    Generation: 48 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:16,702] util      (b'127.0.0.1:54532') INFO    Generation: 49 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:17,508] util      (b'127.0.0.1:54532') INFO    Generation: 50 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:18,311] util      (b'127.0.0.1:54532') INFO    Generation: 51 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:19,173] util      (b'127.0.0.1:54532') INFO    Generation: 52 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:19,998] util      (b'127.0.0.1:54532') INFO    Generation: 53 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:20,826] util      (b'127.0.0.1:54532') INFO    Generation: 54 	Population: 24 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:33,586] util      (b'127.0.0.1:54532') INFO    Generation: 55 	Population: 3 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
# [2019-09-30 10:24:39,919] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
# [2019-09-30 10:24:39,921] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
# [2019-09-30 10:24:39,921] launcher  INFO    Worker distribution:
# [2019-09-30 10:24:39,921] launcher  INFO       127.0.0.1:	0 + origin
# [2019-09-30 10:24:42,545] generate_corner_graphs (b'127.0.0.1:55851') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
# [2019-09-30 10:24:42,545] generate_corner_graphs (b'127.0.0.1:55851') INFO    plotting corner plots
# [2019-09-30 10:24:42,550] generate_corner_graphs (b'127.0.0.1:55851') INFO    graphing remove 0 points
# [2019-09-30 10:24:59,016] launcher  (127.0.0.1:51930) INFO    Root process is done.
# [2019-09-30 10:24:59,016] launcher  (127.0.0.1:51930) INFO    Finished cleaning spawned subprocesses.
# [2019-09-30 10:24:59,035] match     (b'127.0.0.1:54532') INFO    altFeatures False
# [2019-09-30 10:24:59,035] match     (b'127.0.0.1:54532') INFO    altFeatureNames []
# [2019-09-30 10:24:59,035] match     (b'127.0.0.1:54532') INFO    Sysem has finished
# [2019-09-30 10:24:59,036] match     (b'127.0.0.1:54532') INFO    The total runtime was 86.78399920463562 seconds
# [2019-09-30 10:24:59,748] launcher  (127.0.0.1:51654) INFO    Root process is done.
# [2019-09-30 10:24:59,750] launcher  (127.0.0.1:51654) INFO    Finished cleaning spawned subprocesses.

# %% [markdown]
# ## Complete results
# Sorry this next line only works on Windows. On your own system you can use whatever program you use for managing files to open up the result dir and see the same thing.
#
# The system creates a number of sub directories and depending on what settings are in the JSON file some will be empty.
#
# The import ones are
#
# 1. log
#   This contains all the log files from the system. If something goes wrong the information is usually here to find the problem and fix it. This is especialy useful for us to help with a problem.
# 2. meta
#   This contains all the results on the pareto front of meta scores. Your best results will be in this folder. There are simulations, images and results in csv and xlsx format to view.
# 3. progress
#   This folder watches the general progress of the algorithm. In this folder you can see if your variables are identifiable or the progress the search method is making.
# 4. space
#   This folder has plots for what the search space looks like. This is especially useful for debugging. Based on graphs in this folder you can expand or contract the search range for your variables which can improve the fits.
#
# There are also some important items in this folder
# 1. error.csv
#   If any simulation fails it will be recorded here
# 2. json file
#   This is the JSON used to create this simulation. It is a copy of the JSON file you started the matching process with
# 3. progress.csv
#   This file contains some information on algorithm progress. Of special interest are the last two columns that show the last generation where a new item was added to the pareto front of meta scores and how many generations in a row that progress has been made. If enough generations pass without progress the search will terminate.
# 4. result.h5
#   This is an HDF5 file that contains enormous information about the system. It has the entire population, the scores for all items, and other information. With HDFview you can easily view these files and with python you can read any information you want from these files.
# 5. csv file
#   There is one last csv file that is named based on the JSON configuration file and it shows every simulation the system has run along with the scores for that simulation.

# %%
# !explorer {resultDir}

# %% [markdown]
# ## Create corner plots
# These are frequency plots of each variable in your system along with their correlations. What you are looking for is a single peak and this indicates that your variable is identifiable. The peak may be more or less narrow depending on the ranges you gave to the optimizer. If you use an early stopping criteria these plots probably won't be accurate. What is happening is that as the system converges it searches around the best found values to try and find better ones. This means that there are many similar values and so the frequency goes up which shows up as a peak.

# %%
sim.plot_corner()
# Out:
# Corner plot in search space
# Corner plot in original space

# %% [markdown]
# ## Best plots
# This draws a selection of items from the meta folder. It will look in the folder and find the highest Product Root Score, Min Score and Mean Score and the lowest SSE and plot all of those entries. There may still be other items in those folders which are compromises between these scores. The plot will show the ID of the best found item, by what measurements it is the best and what its paramters are.

# %%
sim.plot_best()
# Out:
# Best item 00c37c8e6e81704e6ec0a724e17ff520 for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 1  Mon Sep 30 10:24:33 2019  00c37c8e6e81704e6ec0a724e17ff520   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 1               NaN                     1.999888e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_Shape  main_Pulse_Time  \
# 1                       0.369999               1.0              1.0
#
#    Product Root Score  Min Score  Mean Score           SSE
# 1                 1.0        1.0         1.0  5.193319e-13

# %% [markdown]
# ## Comparing to the correct answer
# After all of the fitting is done the results can be compared to the correct answer when doing synthetic experiments. In this case we can see the error is well under 0.1% for all variables which is very good. That would indicate that if we ran this experiment accurately in real life it could work. If a synthetic experiment can not recover the original value then the real experiment will not find those variables accurately either.

# %%
best ,score, best_score = sim.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0056%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.00025%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0056%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.00025%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0056%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.00025%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0056%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 0.00025%

# %% [markdown]
# ## Change the search method
# We can also take the exact same setup we just made and change the search method from NSGA3 to Multistart and store the results in a new folder. You can see how the different methods compare.

# %%
match_grad = match.copy()

match_grad.gradVector = 0
match_grad.resultsDir = 'fit_grad'
match_grad.searchMethod = 'Multistart'


match_file = lesson_4 / 'example_gradient.json'

with (match_file).open('w') as json_file:
    json.dump(match_grad.to_dict(), json_file, indent='\t')
    
sim_grad = Match(match_file.as_posix())

resultDirGrad = Path(match_grad.baseDir) / match_grad.resultsDir
print("Your results are located at", resultDirGrad.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDirGrad)

sim_grad.start_sim()

sim_grad.plot_best()
best ,score, best_score = sim_grad.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim_grad.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_grad
#
#
# [2019-09-30 10:25:01,210] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-30 10:25:01,210] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-09-30 10:25:01,210] launcher  INFO    Worker distribution:
#
# [2019-09-30 10:25:01,210] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-09-30 10:25:05,549] multistart (b'127.0.0.1:59287') INFO    Population [Individual('d', [0.977555495967982, 0.40141866004689375]), Individual('d', [0.751802378547881, 0.15035084981766877]), Individual('d', [0.25691172437285914, 0.4425994985631223]), Individual('d', [0.4657963246387592, 0.7278792956905135]), Individual('d', [0.19285088502043046, 0.6314981989686911]), Individual('d', [0.46162641191200704, 0.1822588929649266]), Individual('d', [0.2293839550508271, 0.8687830733645542]), Individual('d', [0.5730586742674747, 0.8536487339614902]), Individual('d', [0.0002968693501469444, 0.6229749204656181]), Individual('d', [0.25713346767558154, 0.7034546247225839]), Individual('d', [0.19648201964666845, 0.37176316887666216]), Individual('d', [0.33944198064091624, 0.6141921110632425]), Individual('d', [0.3817616592024551, 0.6776391045862242]), Individual('d', [0.19716948343238017, 0.4763843092469505]), Individual('d', [0.2572595484074538, 0.366414476679535]), Individual('d', [0.50562535963445, 0.8917788378055425]), Individual('d', [0.9418861543741823, 0.8294390832975057]), Individual('d', [0.9045685485526639, 0.29009534590615405]), Individual('d', [0.7086574326061568, 0.2160463761171978]), Individual('d', [0.4596576425500891, 0.19549375871354657]), Individual('d', [0.48055092006749023, 0.753636115846085]), Individual('d', [0.4509201189077773, 0.6046099179861932]), Individual('d', [0.6770869071658293, 0.8569125057740576]), Individual('d', [0.459036652396968, 0.6622989879157952])]
#
# [2019-09-30 10:25:52,093] multistart (b'127.0.0.1:59287') INFO    gradCheck 0.8988050986835476
#
# [2019-09-30 10:25:52,093] multistart (b'127.0.0.1:59287') INFO    newChildren [Individual('d', [0.9070658664179267, 0.3833275302290092]), Individual('d', [0.7529492813454997, 0.14928728319002607]), Individual('d', [0.25542563118902917, 0.4390453908915742]), Individual('d', [0.46572290331541666, 0.7279031359965931]), Individual('d', [0.4879530042590279, 0.502930340156182]), Individual('d', [0.46379403589295687, 0.18175457421399863]), Individual('d', [0.22937867069442658, 0.8687816774717645]), Individual('d', [0.0376505752505137, 0.27703028237682564]), Individual('d', [0.3035227307047788, 0.500874499484019]), Individual('d', [0.0003228113925290702, 0.5004529970547927]), Individual('d', [0.20244036568134172, 0.36958941128727824]), Individual('d', [0.7507979444297692, 0.5352084901394003]), Individual('d', [0.06911312140841602, 0.39262076941956636]), Individual('d', [0.1965253615665128, 0.4736189273942244]), Individual('d', [0.2610118443531812, 0.3658358845569492]), Individual('d', [0.9388066149753129, 0.648775773703819]), Individual('d', [0.861396613950351, 0.7460319701175211]), Individual('d', [0.7909867327409438, 0.31003773117949]), Individual('d', [0.7098389339287207, 0.215460818855055]), Individual('d', [0.46664042395457395, 0.1933683225687145]), Individual('d', [0.7262432205228644, 0.5169601663814279]), Individual('d', [0.628988960195669, 0.4513925342280735]), Individual('d', [0.9699377997837443, 0.9991154709121276]), Individual('d', [0.8872720004576123, 0.6153213316528526])]
#
# [2019-09-30 10:25:52,103] util      (b'127.0.0.1:59287') INFO    Generation: -1 	Population: 24 	Average Score: 0.957 	Best: 0.999 	Minimum Score: 0.914 	Best: 0.998 	Product Score: 0.955 	Best: 0.999
#
# [2019-09-30 10:25:58,511] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-30 10:25:58,511] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-09-30 10:25:58,511] launcher  INFO    Worker distribution:
#
# [2019-09-30 10:25:58,511] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-09-30 10:26:01,406] generate_corner_graphs (b'127.0.0.1:60291') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-09-30 10:26:01,406] generate_corner_graphs (b'127.0.0.1:60291') INFO    plotting corner plots
#
# [2019-09-30 10:26:01,410] generate_corner_graphs (b'127.0.0.1:60291') INFO    graphing remove 0 points
#
# [2019-09-30 10:26:01,457] loggerwriter (b'127.0.0.1:60291') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-30 10:26:03,444] loggerwriter (b'127.0.0.1:60291') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-30 10:26:05,260] loggerwriter (b'127.0.0.1:60291') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-30 10:26:07,188] loggerwriter (b'127.0.0.1:60291') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-30 10:26:08,981] loggerwriter (b'127.0.0.1:60291') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-30 10:26:10,710] loggerwriter (b'127.0.0.1:60291') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-30 10:26:13,028] launcher  (127.0.0.1:52459) INFO    Root process is done.
#
# [2019-09-30 10:26:13,028] launcher  (127.0.0.1:52459) INFO    Finished cleaning spawned subprocesses.
#
# [2019-09-30 10:26:13,043] match     (b'127.0.0.1:59287') INFO    altFeatures False
#
# [2019-09-30 10:26:13,043] match     (b'127.0.0.1:59287') INFO    altFeatureNames []
#
# [2019-09-30 10:26:13,043] match     (b'127.0.0.1:59287') INFO    Sysem has finished
#
# [2019-09-30 10:26:13,043] match     (b'127.0.0.1:59287') INFO    The total runtime was 67.60011148452759 seconds
#
# [2019-09-30 10:26:13,769] launcher  (127.0.0.1:52045) INFO    Root process is done.
#
# [2019-09-30 10:26:13,770] launcher  (127.0.0.1:52045) INFO    Finished cleaning spawned subprocesses.
#
# Best item 46b42b49e50b5230974f58b8ff9811e4 for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Mon Sep 30 10:25:45 2019  46b42b49e50b5230974f58b8ff9811e4   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     1.007376e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_Shape  main_Pulse_Time  \
# 0                       0.360563          0.997575         0.999771
#
#    Product Root Score  Min Score  Mean Score       SSE
# 0            0.998672   0.997575    0.998673  0.000101
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.01e-07   error: 99%
# COL_POROSITY Comp:-1 Bound:-1 = 3.61e-01   error: 2.6%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.01e-07   error: 99%
# COL_POROSITY Comp:-1 Bound:-1 = 3.61e-01   error: 2.6%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.01e-07   error: 99%
# COL_POROSITY Comp:-1 Bound:-1 = 3.61e-01   error: 2.6%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 1.01e-07   error: 99%
# COL_POROSITY Comp:-1 Bound:-1 = 3.61e-01   error: 2.6%

# %% [markdown]
# ## Change the population size
# Sometimes the population size is not large enough and needs to be increased to find better answers.

# %%
match_grad_large = match.copy()

match_grad_large.gradVector = 0
match_grad_large.resultsDir = 'fit_grad_large'
match_grad_large.searchMethod = 'Multistart'
match_grad_large.population = 24
match_grad_large.minPopulation = 24
match_grad_large.maxPopulation = 24


match_file_large = lesson_4 / 'example_gradient_large.json'

with (match_file_large).open('w') as json_file:
    json.dump(match_grad_large.to_dict(), json_file, indent='\t')
    
sim_grad_large = Match(match_file_large.as_posix())

resultDirGradLarge = Path(match_grad_large.baseDir) / match_grad_large.resultsDir
print("Your results are located at", resultDirGrad.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDirGradLarge)

sim_grad_large.start_sim()

sim_grad_large.plot_best()
best ,score, best_score = sim_grad_large.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim_grad_large.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_grad
#
#
# [2019-09-30 10:26:14,823] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-30 10:26:14,823] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-09-30 10:26:14,823] launcher  INFO    Worker distribution:
#
# [2019-09-30 10:26:14,824] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-09-30 10:26:18,884] multistart (b'127.0.0.1:62309') INFO    Population [Individual('d', [0.8364395134351982, 0.10858080321165298]), Individual('d', [0.549786073306922, 0.6850078135165029]), Individual('d', [0.6379628357682613, 0.14862062795847597]), Individual('d', [0.6235574165891128, 0.7874901728778194]), Individual('d', [0.7743849865268657, 0.47493610689316923]), Individual('d', [0.49047785630838436, 0.31176181407279335]), Individual('d', [0.06297973239224908, 0.9397460887554032]), Individual('d', [0.9929455145053817, 0.2967023953315666]), Individual('d', [0.5838749511866093, 0.7708084785259712]), Individual('d', [0.6109515841639991, 0.5710603981040979]), Individual('d', [0.42955991587035836, 0.12661295934957972]), Individual('d', [0.42151300849494244, 0.707819405876176]), Individual('d', [0.5868056212903863, 0.2604623824915272]), Individual('d', [0.5630527660356954, 0.5614160072894379]), Individual('d', [0.5985550851989329, 0.6884542418301798]), Individual('d', [0.427491259309279, 0.6666762226518833]), Individual('d', [0.6235471108891529, 0.06604235303337702]), Individual('d', [0.23850345502038417, 0.4226660984725269]), Individual('d', [0.3691229012049936, 0.2134395482487078]), Individual('d', [0.1748612177321308, 0.9851842340561071]), Individual('d', [0.3241331228192329, 0.5815611685695564]), Individual('d', [0.7493892714885986, 0.21370108330277426]), Individual('d', [0.15490964893120185, 0.9962645272864669]), Individual('d', [0.8858334877769746, 0.870919242859957]), Individual('d', [0.017031264242119093, 0.5078462980137428]), Individual('d', [0.20587413048539083, 0.840453443869008]), Individual('d', [0.41831899189275945, 0.5825384412764139]), Individual('d', [0.6172983136074144, 0.868722149801867]), Individual('d', [0.08126152228457961, 0.020223170939417168]), Individual('d', [0.2361260757039344, 0.8623014866729948]), Individual('d', [0.5400321635842598, 0.8882601195240967]), Individual('d', [0.868406936000042, 0.6258765614426793]), Individual('d', [0.28249223549931657, 0.3106965919668738]), Individual('d', [0.06420827242108851, 0.0018371245021308047]), Individual('d', [0.1618558449514479, 0.537268202923542]), Individual('d', [0.3209324392217453, 0.1914716955694561]), Individual('d', [0.20194612691723346, 0.6528898519916359]), Individual('d', [0.3988361358315109, 0.6071437420568406]), Individual('d', [0.35070649529729425, 0.3506174866490145]), Individual('d', [0.746623878261237, 0.566704744372991]), Individual('d', [0.8386823088943123, 0.2775811127147818]), Individual('d', [0.2694004525152003, 0.7227620813419473]), Individual('d', [0.918191343976999, 0.15551839592846362]), Individual('d', [0.6450307632483517, 0.6761271448058455]), Individual('d', [0.6804874084124629, 0.551207476602457]), Individual('d', [0.6051669879067922, 0.2085251778352457]), Individual('d', [0.2794546694002882, 0.2518363036827159]), Individual('d', [0.4278618288926498, 0.267157297918462])]
#
# [2019-09-30 10:28:00,472] multistart (b'127.0.0.1:62309') INFO    gradCheck 0.8999860124123807
#
# [2019-09-30 10:28:00,472] multistart (b'127.0.0.1:62309') INFO    newChildren [Individual('d', [0.8373992906381005, 0.10805447359118064]), Individual('d', [0.7733127297459472, 0.5420181414323235]), Individual('d', [0.6400014168970815, 0.1472908504799495]), Individual('d', [0.36041562521811316, 0.30063769966137455]), Individual('d', [0.972736822451099, 0.6901003720275743]), Individual('d', [0.49924718247418165, 0.30975770005226155]), Individual('d', [0.5127494988824264, 0.43001440201101915]), Individual('d', [0.9428903687880484, 0.6527533616008054]), Individual('d', [0.3128868579220401, 0.45465030498321807]), Individual('d', [0.6316049919724318, 0.5103868466351762]), Individual('d', [0.4425001581312558, 0.12367667088459304]), Individual('d', [0.8162224530028831, 0.5583798403633328]), Individual('d', [0.5888052037992947, 0.25794495837149034]), Individual('d', [0.4325109933930782, 0.5019090668538323]), Individual('d', [0.07120056415881627, 0.3579339327801697]), Individual('d', [0.890905348463078, 0.6179057403005487]), Individual('d', [0.6303389504770063, 0.06505155507911764]), Individual('d', [0.23390775657879023, 0.41973476979291874]), Individual('d', [0.3738810582738373, 0.2120119505860107]), Individual('d', [0.9968221560734364, 0.9999817851583418]), Individual('d', [0.4525863081154355, 0.5060846196683392]), Individual('d', [0.7501617213507109, 0.21285893195506325]), Individual('d', [0.99401942954726, 0.9999962285674748]), Individual('d', [0.8849390289974396, 0.871079232966028]), Individual('d', [0.017661233039471428, 0.5043080426539397]), Individual('d', [0.006430597843693409, 0.4503726154840994]), Individual('d', [0.42056636643230405, 0.5056162356468398]), Individual('d', [0.2965049188848731, 0.4700031475816564]), Individual('d', [0.21137726835282275, 0.01902633468539104]), Individual('d', [0.7314620464913874, 0.5181564804041224]), Individual('d', [0.001663675748530346, 0.21924639081427438]), Individual('d', [0.8093275988860908, 0.5554287761436443]), Individual('d', [0.2869670876148999, 0.3080882496485993]), Individual('d', [0.5562842488111042, 0.0012223947422660038]), Individual('d', [0.24825632300955602, 0.4891286825875592]), Individual('d', [0.32145497018279356, 0.18869985120786123]), Individual('d', [0.001592048011629007, 0.4734886620871509]), Individual('d', [0.17759173481412216, 0.4235019021710479]), Individual('d', [0.3529031413059491, 0.3468824031646773]), Individual('d', [0.7485085068200213, 0.5264809337618662]), Individual('d', [0.8004390455060244, 0.27170187266893214]), Individual('d', [0.8624889303859109, 0.5949104203600478]), Individual('d', [0.8179899927268164, 0.5466766525266208]), Individual('d', [0.5352702844869753, 0.5082323064765754]), Individual('d', [0.7122489231916476, 0.510005094974795]), Individual('d', [0.6060659532991175, 0.2080935749171437]), Individual('d', [0.28383946294316953, 0.25027224300890527]), Individual('d', [0.4262914050436616, 0.2663431935062146])]
#
# [2019-09-30 10:28:00,483] util      (b'127.0.0.1:62309') INFO    Generation: -1 	Population: 48 	Average Score: 1 	Best: 1 	Minimum Score: 1 	Best: 1 	Product Score: 1 	Best: 1
#
# [2019-09-30 10:28:06,565] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-30 10:28:06,565] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-09-30 10:28:06,565] launcher  INFO    Worker distribution:
#
# [2019-09-30 10:28:06,565] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-09-30 10:28:09,242] generate_corner_graphs (b'127.0.0.1:54095') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-09-30 10:28:09,243] generate_corner_graphs (b'127.0.0.1:54095') INFO    plotting corner plots
#
# [2019-09-30 10:28:09,246] generate_corner_graphs (b'127.0.0.1:54095') INFO    graphing remove 0 points
#
# [2019-09-30 10:28:20,184] launcher  (127.0.0.1:52770) INFO    Root process is done.
#
# [2019-09-30 10:28:20,184] launcher  (127.0.0.1:52770) INFO    Finished cleaning spawned subprocesses.
#
# [2019-09-30 10:28:20,199] match     (b'127.0.0.1:62309') INFO    altFeatures False
#
# [2019-09-30 10:28:20,199] match     (b'127.0.0.1:62309') INFO    altFeatureNames []
#
# [2019-09-30 10:28:20,199] match     (b'127.0.0.1:62309') INFO    Sysem has finished
#
# [2019-09-30 10:28:20,199] match     (b'127.0.0.1:62309') INFO    The total runtime was 121.42099952697754 seconds
#
# [2019-09-30 10:28:20,970] launcher  (127.0.0.1:52489) INFO    Root process is done.
#
# [2019-09-30 10:28:20,971] launcher  (127.0.0.1:52489) INFO    Finished cleaning spawned subprocesses.
#
# Best item 14daa607af8e406c0d4b490815b43e81 for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 1  Mon Sep 30 10:27:13 2019  14daa607af8e406c0d4b490815b43e81   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 1               NaN                     1.840305e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_Shape  main_Pulse_Time  \
# 1                       0.367514          0.999984         0.999985
#
#    Product Root Score  Min Score  Mean Score       SSE
# 1            0.999984   0.999984    0.999984  0.000108
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.84e-07   error: 8.7%
# COL_POROSITY Comp:-1 Bound:-1 = 3.68e-01   error: 0.68%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.84e-07   error: 8.7%
# COL_POROSITY Comp:-1 Bound:-1 = 3.68e-01   error: 0.68%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 1.84e-07   error: 8.7%
# COL_POROSITY Comp:-1 Bound:-1 = 3.68e-01   error: 0.68%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 1.84e-07   error: 8.7%
# COL_POROSITY Comp:-1 Bound:-1 = 3.68e-01   error: 0.68%

# %% [markdown]
# ## Changing the score
# You can also change to an SSE based score and use gradient descent. For this problem it should provide very good results.

# %%
match_sse = match.copy()

match_sse.resultsDir = 'fit_sse'
match_sse.searchMethod = 'Multistart'
match_sse.experiments[0].features[0].type = 'DextranSSE'


match_file = lesson_4 / 'example_sse.json'

with (match_file).open('w') as json_file:
    json.dump(match_sse.to_dict(), json_file, indent='\t')

sim_sse = Match(match_file.as_posix())

resultDirSSE = Path(match_sse.baseDir) / match_sse.resultsDir
print("Your results are located at", resultDirSSE.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDirSSE)

sim_sse.start_sim()

sim_sse.plot_best()
best ,score, best_score = sim_sse.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim_sse.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_sse
#
#
# [2019-09-30 10:28:22,017] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-30 10:28:22,017] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-09-30 10:28:22,017] launcher  INFO    Worker distribution:
#
# [2019-09-30 10:28:22,017] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-09-30 10:28:25,673] multistart (b'127.0.0.1:54471') INFO    Population [Individual('d', [0.05157277180663533, 0.6825405857160062]), Individual('d', [0.997213727090361, 0.5959916542036877]), Individual('d', [0.05950327444496073, 0.7776228061597495]), Individual('d', [0.5586022032003357, 0.3389744459465044]), Individual('d', [0.44784910200386585, 0.5971281316140467]), Individual('d', [0.9119696208343365, 0.0682099087256629]), Individual('d', [0.9153499985640943, 0.7357439412372632]), Individual('d', [0.04927783313065204, 0.11167431046536225]), Individual('d', [0.7962431992142571, 0.19142888975655903]), Individual('d', [0.2680314242609473, 0.5490700824199145]), Individual('d', [0.5744657357794016, 0.967399220202282]), Individual('d', [0.3822350237315292, 0.6799168081367446]), Individual('d', [0.08469305596843923, 0.09292481182414447]), Individual('d', [0.5277101998122735, 0.6267297316006364]), Individual('d', [0.1976964217891889, 0.9815605868545545]), Individual('d', [0.6894976618028905, 0.04660643398874598]), Individual('d', [0.3376290258594786, 0.3671165982519188]), Individual('d', [0.22297316032783876, 0.18052812049122313]), Individual('d', [0.3885898763722756, 0.10976113821360112]), Individual('d', [0.9804434544151269, 0.9138299136999597]), Individual('d', [0.9013595352581918, 0.4422279194490285]), Individual('d', [0.5871237769792603, 0.7988412257030022]), Individual('d', [0.6871280611321517, 0.3142456303209842]), Individual('d', [0.7554161959692962, 0.9489467363267431])]
#
# [2019-09-30 10:28:26,184] gradFD    (b'127.0.0.1:54471') INFO    removed [0.05157277180663533, 0.6825405857160062] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,184] gradFD    (b'127.0.0.1:54471') INFO    removed [0.997213727090361, 0.5959916542036877] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,184] gradFD    (b'127.0.0.1:54471') INFO    removed [0.05950327444496073, 0.7776228061597495] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,184] gradFD    (b'127.0.0.1:54471') INFO    removed [0.5586022032003357, 0.3389744459465044] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,184] gradFD    (b'127.0.0.1:54471') INFO    removed [0.44784910200386585, 0.5971281316140467] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,185] gradFD    (b'127.0.0.1:54471') INFO    removed [0.9119696208343365, 0.0682099087256629] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,493] gradFD    (b'127.0.0.1:54471') INFO    removed [0.04927783313065204, 0.11167431046536225] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,493] gradFD    (b'127.0.0.1:54471') INFO    removed [0.7962431992142571, 0.19142888975655903] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,494] gradFD    (b'127.0.0.1:54471') INFO    removed [0.2680314242609473, 0.5490700824199145] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,494] gradFD    (b'127.0.0.1:54471') INFO    removed [0.5744657357794016, 0.967399220202282] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,494] gradFD    (b'127.0.0.1:54471') INFO    removed [0.3822350237315292, 0.6799168081367446] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,494] gradFD    (b'127.0.0.1:54471') INFO    removed [0.08469305596843923, 0.09292481182414447] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,494] gradFD    (b'127.0.0.1:54471') INFO    removed [0.5277101998122735, 0.6267297316006364] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,495] gradFD    (b'127.0.0.1:54471') INFO    removed [0.1976964217891889, 0.9815605868545545] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,495] gradFD    (b'127.0.0.1:54471') INFO    removed [0.6894976618028905, 0.04660643398874598] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,495] gradFD    (b'127.0.0.1:54471') INFO    removed [0.3376290258594786, 0.3671165982519188] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,495] gradFD    (b'127.0.0.1:54471') INFO    removed [0.22297316032783876, 0.18052812049122313] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,495] gradFD    (b'127.0.0.1:54471') INFO    removed [0.3885898763722756, 0.10976113821360112] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,495] gradFD    (b'127.0.0.1:54471') INFO    removed [0.9804434544151269, 0.9138299136999597] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,496] gradFD    (b'127.0.0.1:54471') INFO    removed [0.9013595352581918, 0.4422279194490285] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,496] gradFD    (b'127.0.0.1:54471') INFO    removed [0.5871237769792603, 0.7988412257030022] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,513] gradFD    (b'127.0.0.1:54471') INFO    removed [0.6871280611321517, 0.3142456303209842] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,513] gradFD    (b'127.0.0.1:54471') INFO    removed [0.7554161959692962, 0.9489467363267431] for insufficient overlap in gradient descent
#
# [2019-09-30 10:28:26,513] gradFD    (b'127.0.0.1:54471') INFO    overlap okay offspring [[0.9153499985640943, 0.7357439412372632]]
#
# [2019-09-30 10:29:30,896] multistart (b'127.0.0.1:54471') INFO    gradCheck -0.009831314852548945
#
# [2019-09-30 10:29:30,896] multistart (b'127.0.0.1:54471') INFO    newChildren [Individual('d', [0.9138611736295719, 0.7354411471522901])]
#
# [2019-09-30 10:29:30,904] util      (b'127.0.0.1:54471') INFO    Generation: -1 	Population: 1 	Average Score: -0.0109 	Best: -0.0109 	Minimum Score: -0.0109 	Best: -0.0109 	Product Score: -0.0109 	Best: -0.0109
#
# [2019-09-30 10:29:37,197] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-30 10:29:37,197] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-09-30 10:29:37,197] launcher  INFO    Worker distribution:
#
# [2019-09-30 10:29:37,197] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-09-30 10:29:39,913] generate_corner_graphs (b'127.0.0.1:62814') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-09-30 10:29:39,913] generate_corner_graphs (b'127.0.0.1:62814') INFO    plotting corner plots
#
# [2019-09-30 10:29:40,443] launcher  (127.0.0.1:53079) INFO    Root process is done.
#
# [2019-09-30 10:29:40,444] launcher  (127.0.0.1:53079) INFO    Finished cleaning spawned subprocesses.
#
# [2019-09-30 10:29:40,464] match     (b'127.0.0.1:54471') INFO    altFeatures False
#
# [2019-09-30 10:29:40,465] match     (b'127.0.0.1:54471') INFO    altFeatureNames []
#
# [2019-09-30 10:29:40,465] match     (b'127.0.0.1:54471') INFO    Sysem has finished
#
# [2019-09-30 10:29:40,465] match     (b'127.0.0.1:54471') INFO    The total runtime was 74.88500142097473 seconds
#
# [2019-09-30 10:29:41,185] launcher  (127.0.0.1:52798) INFO    Root process is done.
#
# [2019-09-30 10:29:41,187] launcher  (127.0.0.1:52798) INFO    Finished cleaning spawned subprocesses.
#
# Best item 65b1b4ac6dc4675dee32faaa61a62617 for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Mon Sep 30 10:29:30 2019  65b1b4ac6dc4675dee32faaa61a62617   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     4.523189e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_SSE  Product Root Score  \
# 0                       0.420632       -0.010924           -0.010924
#
#    Min Score  Mean Score       SSE
# 0  -0.010924   -0.010924  0.010924
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 4.52e-07   error: 56%
# COL_POROSITY Comp:-1 Bound:-1 = 4.21e-01   error: 12%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 4.52e-07   error: 56%
# COL_POROSITY Comp:-1 Bound:-1 = 4.21e-01   error: 12%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 4.52e-07   error: 56%
# COL_POROSITY Comp:-1 Bound:-1 = 4.21e-01   error: 12%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 4.52e-07   error: 56%
# COL_POROSITY Comp:-1 Bound:-1 = 4.21e-01   error: 12%

# %% [markdown]
# ## A large population can still help
# Partial Differential Equations are complex and a different start location can provide a better result. The best way to deal with this is to increase the population size.

# %%
match_sse_large = match.copy()

match_sse_large.resultsDir = 'fit_sse_large'
match_sse_large.searchMethod = 'Multistart'
match_sse_large.population = 24
match_sse_large.minPopulation = 24
match_sse_large.maxPopulation = 24
match_sse_large.experiments[0].features[0].type = 'DextranSSE'


match_file = lesson_4 / 'example_sse_large.json'

with (match_file).open('w') as json_file:
    json.dump(match_sse_large.to_dict(), json_file, indent='\t')

sim_sse_large = Match(match_file.as_posix())

resultDirSSELarge = Path(match_sse_large.baseDir) / match_sse_large.resultsDir
print("Your results are located at", resultDirSSELarge.as_posix(), '\n\n')

#If you want to delete the fitting process to start over remove the # from the next line and re-run this cell
deleteResultDir(resultDirSSELarge)

sim_sse_large.start_sim()

sim_sse_large.plot_best()
best ,score, best_score = sim_sse_large.get_best()
true_values = numpy.array([simple.root.input.model.unit_001.col_dispersion, 
                           simple.root.input.model.unit_001.col_porosity])
for key,value in best_score.items():
    print("Method: %s" % key)
    for name, val, true_value in zip(sim_sse_large.cache.parameter_headers, value, true_values):
        print("%s = %.2e   error: %.2g%%" % (name, val, numpy.abs(val-true_value)/val*100))
    print('\n')
# Out:
# Your results are located at F:/temp/cadet_tutorial/lesson_4/fit_sse_large
#
#
# [2019-09-30 10:29:42,248] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-30 10:29:42,248] launcher  INFO    Deploying 12 worker(s) over 1 host(s).
#
# [2019-09-30 10:29:42,248] launcher  INFO    Worker distribution:
#
# [2019-09-30 10:29:42,248] launcher  INFO       127.0.0.1:	11 + origin
#
# [2019-09-30 10:29:46,155] multistart (b'127.0.0.1:57825') INFO    Population [Individual('d', [0.9539471364648509, 0.08140253824356147]), Individual('d', [0.851670663170161, 0.3663214389571099]), Individual('d', [0.6691626591262305, 0.6224032777336099]), Individual('d', [0.6781920844452168, 0.45464482356475244]), Individual('d', [0.9915436507191101, 0.49747389770284267]), Individual('d', [0.18694873185182204, 0.26398126596501714]), Individual('d', [0.7537781842951174, 0.7151823895557128]), Individual('d', [0.9600443108758369, 0.43722641642955495]), Individual('d', [0.22738969728790515, 0.06537143325515826]), Individual('d', [0.5163489137719871, 0.8973368894057685]), Individual('d', [0.9208728922928752, 0.2247692104974658]), Individual('d', [0.5918793846408424, 0.7019243490010884]), Individual('d', [0.9373691136934916, 0.6824151804500258]), Individual('d', [0.06871378781820747, 0.517362753606939]), Individual('d', [0.6512431020282297, 0.822111287897039]), Individual('d', [0.6751432162468238, 0.15696563293618238]), Individual('d', [0.8159705514043425, 0.9122254923490504]), Individual('d', [0.44149632016850726, 0.4272919805689426]), Individual('d', [0.5438850807051668, 0.4958720944065882]), Individual('d', [0.8390946678261969, 0.2983484168798839]), Individual('d', [0.9579603220607327, 0.7856868372964437]), Individual('d', [0.224780198296603, 0.7722226534235468]), Individual('d', [0.8943658199513629, 0.37305424034726986]), Individual('d', [0.11138255721015589, 0.1947969103038082]), Individual('d', [0.2442035459309696, 0.9982998190720248]), Individual('d', [0.8593344758514299, 0.5127662814555695]), Individual('d', [0.8530333246210926, 0.10013851333215162]), Individual('d', [0.9001304275231949, 0.6194450859476407]), Individual('d', [0.5624054049121903, 0.2151651085132037]), Individual('d', [0.9924249914405924, 0.021621533265317128]), Individual('d', [0.5238823738731488, 0.9699294447500749]), Individual('d', [0.7669836421726057, 0.576263346574008]), Individual('d', [0.14429988271668237, 0.9778609523910731]), Individual('d', [0.9692544202148433, 0.6770676321189268]), Individual('d', [0.0328214674998637, 0.673669898860162]), Individual('d', [0.18777309146478893, 0.406396727366521]), Individual('d', [0.028759156183150725, 0.6888498321968344]), Individual('d', [0.2409981699029593, 0.9013589667114676]), Individual('d', [0.17120330064239875, 0.40410330010928197]), Individual('d', [0.6239217899223202, 0.8646365956906864]), Individual('d', [0.7066333153573033, 0.5966587670453618]), Individual('d', [0.35630016094465167, 0.545197808198605]), Individual('d', [0.7417636935947454, 0.18349781888671868]), Individual('d', [0.1312019777498301, 0.7346474105904928]), Individual('d', [0.06298142437212706, 0.3808107399595829]), Individual('d', [0.48912940300159, 0.2450278934233373]), Individual('d', [0.4176783227784364, 0.11172615468490765]), Individual('d', [0.6261246752173582, 0.09125495494512947])]
#
# [2019-09-30 10:29:46,708] gradFD    (b'127.0.0.1:57825') INFO    removed [0.9539471364648509, 0.08140253824356147] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:46,709] gradFD    (b'127.0.0.1:57825') INFO    removed [0.851670663170161, 0.3663214389571099] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:46,709] gradFD    (b'127.0.0.1:57825') INFO    removed [0.6691626591262305, 0.6224032777336099] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:46,709] gradFD    (b'127.0.0.1:57825') INFO    removed [0.6781920844452168, 0.45464482356475244] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:46,709] gradFD    (b'127.0.0.1:57825') INFO    removed [0.9915436507191101, 0.49747389770284267] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,048] gradFD    (b'127.0.0.1:57825') INFO    removed [0.18694873185182204, 0.26398126596501714] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,048] gradFD    (b'127.0.0.1:57825') INFO    removed [0.7537781842951174, 0.7151823895557128] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,048] gradFD    (b'127.0.0.1:57825') INFO    removed [0.9600443108758369, 0.43722641642955495] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,048] gradFD    (b'127.0.0.1:57825') INFO    removed [0.22738969728790515, 0.06537143325515826] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,049] gradFD    (b'127.0.0.1:57825') INFO    removed [0.5163489137719871, 0.8973368894057685] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,049] gradFD    (b'127.0.0.1:57825') INFO    removed [0.9208728922928752, 0.2247692104974658] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,049] gradFD    (b'127.0.0.1:57825') INFO    removed [0.5918793846408424, 0.7019243490010884] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,049] gradFD    (b'127.0.0.1:57825') INFO    removed [0.6512431020282297, 0.822111287897039] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,050] gradFD    (b'127.0.0.1:57825') INFO    removed [0.6751432162468238, 0.15696563293618238] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,050] gradFD    (b'127.0.0.1:57825') INFO    removed [0.8159705514043425, 0.9122254923490504] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,050] gradFD    (b'127.0.0.1:57825') INFO    removed [0.44149632016850726, 0.4272919805689426] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,051] gradFD    (b'127.0.0.1:57825') INFO    removed [0.8390946678261969, 0.2983484168798839] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,435] gradFD    (b'127.0.0.1:57825') INFO    removed [0.224780198296603, 0.7722226534235468] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,436] gradFD    (b'127.0.0.1:57825') INFO    removed [0.8943658199513629, 0.37305424034726986] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,436] gradFD    (b'127.0.0.1:57825') INFO    removed [0.11138255721015589, 0.1947969103038082] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,437] gradFD    (b'127.0.0.1:57825') INFO    removed [0.2442035459309696, 0.9982998190720248] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,437] gradFD    (b'127.0.0.1:57825') INFO    removed [0.8593344758514299, 0.5127662814555695] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,437] gradFD    (b'127.0.0.1:57825') INFO    removed [0.8530333246210926, 0.10013851333215162] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,437] gradFD    (b'127.0.0.1:57825') INFO    removed [0.5624054049121903, 0.2151651085132037] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,437] gradFD    (b'127.0.0.1:57825') INFO    removed [0.9924249914405924, 0.021621533265317128] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,438] gradFD    (b'127.0.0.1:57825') INFO    removed [0.5238823738731488, 0.9699294447500749] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,438] gradFD    (b'127.0.0.1:57825') INFO    removed [0.14429988271668237, 0.9778609523910731] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,685] gradFD    (b'127.0.0.1:57825') INFO    removed [0.0328214674998637, 0.673669898860162] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,686] gradFD    (b'127.0.0.1:57825') INFO    removed [0.18777309146478893, 0.406396727366521] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,686] gradFD    (b'127.0.0.1:57825') INFO    removed [0.028759156183150725, 0.6888498321968344] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,686] gradFD    (b'127.0.0.1:57825') INFO    removed [0.2409981699029593, 0.9013589667114676] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,686] gradFD    (b'127.0.0.1:57825') INFO    removed [0.17120330064239875, 0.40410330010928197] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,686] gradFD    (b'127.0.0.1:57825') INFO    removed [0.6239217899223202, 0.8646365956906864] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,687] gradFD    (b'127.0.0.1:57825') INFO    removed [0.7066333153573033, 0.5966587670453618] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,687] gradFD    (b'127.0.0.1:57825') INFO    removed [0.7417636935947454, 0.18349781888671868] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,687] gradFD    (b'127.0.0.1:57825') INFO    removed [0.1312019777498301, 0.7346474105904928] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,687] gradFD    (b'127.0.0.1:57825') INFO    removed [0.06298142437212706, 0.3808107399595829] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,688] gradFD    (b'127.0.0.1:57825') INFO    removed [0.48912940300159, 0.2450278934233373] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,803] gradFD    (b'127.0.0.1:57825') INFO    removed [0.4176783227784364, 0.11172615468490765] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,803] gradFD    (b'127.0.0.1:57825') INFO    removed [0.6261246752173582, 0.09125495494512947] for insufficient overlap in gradient descent
#
# [2019-09-30 10:29:47,803] gradFD    (b'127.0.0.1:57825') INFO    overlap okay offspring [[0.9373691136934916, 0.6824151804500258], [0.06871378781820747, 0.517362753606939], [0.5438850807051668, 0.4958720944065882], [0.9579603220607327, 0.7856868372964437], [0.9001304275231949, 0.6194450859476407], [0.7669836421726057, 0.576263346574008], [0.9692544202148433, 0.6770676321189268], [0.35630016094465167, 0.545197808198605]]
# [2019-09-30 10:30:21,486] multistart (b'127.0.0.1:57825') INFO    gradCheck -1.697844138055901e-14
#
# [2019-09-30 10:30:21,486] multistart (b'127.0.0.1:57825') INFO    newChildren [Individual('d', [0.9355935611828887, 0.6827441747221976]), Individual('d', [0.05806956944032042, 0.5197304220909451]), Individual('d', [0.8252563446582883, 0.5666660800610035]), Individual('d', [0.9566411729030968, 0.7859924338000469]), Individual('d', [0.8994643645506246, 0.6197593478435779]), Individual('d', [0.766473049052916, 0.5765750324291793]), Individual('d', [0.9665078983656334, 0.6779530582893152]), Individual('d', [0.3562271873320946, 0.5590070408542278])]
#
# [2019-09-30 10:30:21,493] util      (b'127.0.0.1:57825') INFO    Generation: -1 	Population: 8 	Average Score: -1.89e-14 	Best: -1.89e-14 	Minimum Score: -1.89e-14 	Best: -1.89e-14 	Product Score: -1.89e-14 	Best: -1.89e-14
#
# [2019-09-30 10:30:30,586] launcher  INFO    SCOOP 0.7 1.1 on win32 using Python 3.7.3 | packaged by conda-forge | (default, Jul  1 2019, 22:01:29) [MSC v.1900 64 bit (AMD64)], API: 1013
#
# [2019-09-30 10:30:30,586] launcher  INFO    Deploying 1 worker(s) over 1 host(s).
#
# [2019-09-30 10:30:30,586] launcher  INFO    Worker distribution:
#
# [2019-09-30 10:30:30,586] launcher  INFO       127.0.0.1:	0 + origin
#
# [2019-09-30 10:30:33,300] generate_corner_graphs (b'127.0.0.1:60173') INFO    graphing directory F:\temp\cadet_tutorial\lesson_4
#
# [2019-09-30 10:30:33,300] generate_corner_graphs (b'127.0.0.1:60173') INFO    plotting corner plots
#
# [2019-09-30 10:30:33,347] loggerwriter (b'127.0.0.1:60173') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-30 10:30:35,175] loggerwriter (b'127.0.0.1:60173') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-30 10:30:36,808] loggerwriter (b'127.0.0.1:60173') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-30 10:30:38,391] loggerwriter (b'127.0.0.1:60173') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-30 10:30:40,067] loggerwriter (b'127.0.0.1:60173') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-30 10:30:41,695] loggerwriter (b'127.0.0.1:60173') WARNING WARNING:root:Too few points to create valid contours
#
#
#
# [2019-09-30 10:30:43,792] launcher  (127.0.0.1:53399) INFO    Root process is done.
#
# [2019-09-30 10:30:43,792] launcher  (127.0.0.1:53399) INFO    Finished cleaning spawned subprocesses.
#
# [2019-09-30 10:30:43,807] match     (b'127.0.0.1:57825') INFO    altFeatures False
#
# [2019-09-30 10:30:43,807] match     (b'127.0.0.1:57825') INFO    altFeatureNames []
#
# [2019-09-30 10:30:43,807] match     (b'127.0.0.1:57825') INFO    Sysem has finished
#
# [2019-09-30 10:30:43,807] match     (b'127.0.0.1:57825') INFO    The total runtime was 57.7451536655426 seconds
#
# [2019-09-30 10:30:44,576] launcher  (127.0.0.1:53111) INFO    Root process is done.
#
# [2019-09-30 10:30:44,576] launcher  (127.0.0.1:53111) INFO    Finished cleaning spawned subprocesses.
#
# Best item 11981cda3a7bcc6b3b27701d923a5552 for meta score(s) Product Root Score , Min Score , Mean Score , SSE
#                        Time                              Name Method  \
# 0  Mon Sep 30 10:30:20 2019  11981cda3a7bcc6b3b27701d923a5552   GRAD
#
#    Condition Number  COL_DISPERSION Comp:-1 Bound:-1  \
# 0               NaN                     1.999979e-07
#
#    COL_POROSITY Comp:-1 Bound:-1  main_Pulse_SSE  Product Root Score  \
# 0                           0.37   -1.886493e-14       -1.886493e-14
#
#       Min Score    Mean Score           SSE
# 0 -1.886493e-14 -1.886493e-14  1.886493e-14
# Method: Product Root Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0011%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 4.8e-05%
#
#
# Method: Min Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0011%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 4.8e-05%
#
#
# Method: Mean Score
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0011%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 4.8e-05%
#
#
# Method: SSE
# COL_DISPERSION Comp:-1 Bound:-1 = 2.00e-07   error: 0.0011%
# COL_POROSITY Comp:-1 Bound:-1 = 3.70e-01   error: 4.8e-05%
